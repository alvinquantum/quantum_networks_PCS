# %%
#!/usr/bin/env python3
import qiskit
from qiskit import (
    QuantumCircuit,
    QuantumRegister,
    ClassicalRegister,
    transpile
)
from qiskit.quantum_info import (
    Kraus, 
    SuperOp,
)
from qiskit_aer.noise import(
    depolarizing_error,
    phase_damping_error,
    NoiseModel,
    QuantumError,
    amplitude_damping_error,
)
# from qiskit_ibm_provider import IBMProvider
from qiskit import Aer
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np
import math
import sys
sys.path.append('../')
import utilities as utl
import importlib
import json
importlib.reload(utl)

SHOTS=20000
def _graph_pcsZ(qc, qreg):
    for idx in list(range(qreg.size)):
        qc.h(qreg[idx])
    qc.cz(qreg[1],qreg[2])
    qc.cz(qreg[0],qreg[1])
    qc.cx(qreg[3],qreg[1])
    qc.barrier()
    qc.id(qreg)
    qc.barrier()
    qc.cx(qreg[3],qreg[1])
    qc.cz(qreg[2],qreg[1])
    qc.h([qreg[3], qreg[2]])
    return qc

# %%
tot_pcs_ancillas=4
a_qreg=QuantumRegister(4, "a")
b_qreg=QuantumRegister(4, "b")
pcs_creg=ClassicalRegister(4,"pcs")
bsm_creg=ClassicalRegister(2, "bsm")
epr_creg=ClassicalRegister(2, "epr")
junk_creg=ClassicalRegister(4, "junk") #for removing and connecting nodes
qc=QuantumCircuit(a_qreg, b_qreg, epr_creg, bsm_creg, pcs_creg, junk_creg)
qc=_graph_pcsZ(qc, a_qreg)
qc=_graph_pcsZ(qc, b_qreg)
# # x and z measurement to connect and remove nodes, respectively.
# qc.barrier()
# qc.measure(a_qreg[2], junk_creg[0])
# qc.measure(b_qreg[2], junk_creg[1])
# qc.measure(a_qreg[4], junk_creg[2])
# qc.measure(b_qreg[4], junk_creg[3])

# PCS measurements.
qc.barrier()
qc.measure(a_qreg[2], pcs_creg[0])
qc.measure(b_qreg[2], pcs_creg[1])
qc.measure(a_qreg[3], pcs_creg[2])
qc.measure(b_qreg[3], pcs_creg[3])
# Convert 2 qubit graph states to bell States.
qc.h(a_qreg[0])
qc.h(b_qreg[0])

#BSM measurement.
qc.barrier()
qc.cx(a_qreg[1], b_qreg[1])
qc.h(a_qreg[1])
qc.measure(a_qreg[1], bsm_creg[0])
qc.measure(b_qreg[1], bsm_creg[1])
utl._add_fixing_gates(qc, a_qreg, bsm_creg, 0)
print(qc)
# Out:
#         ┌───┐            ░ ┌───┐ ░                      ░       ░           »
#    a_0: ┤ H ├────■───────░─┤ I ├─░──────────────────────░───────░───────────»
#         ├───┤    │ ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░           »
#    a_1: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │    └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░           »
#    b_0: ─────────────────░───────░─┤ H ├───────■────────░─┤ I ├─░───────────»
#                          ░       ░ ├───┤       │  ┌───┐ ░ ├───┤ ░ ┌───┐     »
#    b_1: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │       └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘
# «   a_1: ──────────────────────────────────────────────────────────
# «
# «   a_2: ──────────────────────────────────────────────────────────
# «
# «   a_3: ──────────────────────────────────────────────────────────
# «
# «   b_0: ──────────────────────────────────────────────────────────
# «
# «   b_1: ──────────────────────────────────────────────────────────
# «
# «   b_2: ──────────────────────────────────────────────────────────
# «
# «   b_3: ──────────────────────────────────────────────────────────
# «
# « epr: 2/══════════════════════════════════════════════════════════
# «
# « bsm: 2/══════════════════════════════════════════════════════════
# «
# « pcs: 4/══════════════════════════════════════════════════════════
# «
# «junk: 4/══════════════════════════════════════════════════════════
# «

# %%
pcs_all_fidelities=[]
pcs_post_select_rates=[]
errors=np.linspace(0.0, stop=0.5, num=11, endpoint=True)
error_gate1=0.001
for error in errors:
        noise_model=utl.get_noise_model(error_gate1)
        print(f"depolarizing error: {error}")
        depol1=depolarizing_error(error, 1)
        noise_model.add_all_qubit_quantum_error(depol1, ["id"])
        print(noise_model)

        backend=AerSimulator(noise_model=noise_model)
        pcs_ancillas_pos=1 # the position of the classical registers that contain the pcs measurements.
        result_xx=utl.meas_xx(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_yy=utl.meas_yy(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_zz=utl.meas_zz(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)

        xx_counts=utl.post_select(result_xx.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        yy_counts=utl.post_select(result_yy.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        zz_counts=utl.post_select(result_zz.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        pcs_post_select_rates.append(min([sum(xx_counts.values()),sum(yy_counts.values()),sum(zz_counts.values())])/SHOTS)
        epr_idx=-1 #the position of the classical registers that contain measurements of the 
                #epr pair.
        expect_xx=utl.expect_of_vals(utl.to_percent(utl.collect_meas(xx_counts, epr_idx)))
        expect_yy=utl.expect_of_vals(utl.to_percent(utl.collect_meas(yy_counts, epr_idx)))
        expect_zz=utl.expect_of_vals(utl.to_percent(utl.collect_meas(zz_counts, epr_idx)))
        pcs_fidelity=utl.fidelity_phip(expect_xx, expect_yy, expect_zz)
        print(pcs_fidelity)
        pcs_all_fidelities.append(pcs_fidelity)
# Out:
# depolarizing error: 0.0
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['ccx', 'x', 'z', 'measure', 'cz', 'y', 'h', 'cx', 'rz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure']
# xx circ:
#         ┌───┐            ░ ┌───┐ ░                      ░       ░           »
#    a_0: ┤ H ├────■───────░─┤ I ├─░──────────────────────░───────░───────────»
#         ├───┤    │ ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░           »
#    a_1: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │    └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░           »
#    b_0: ─────────────────░───────░─┤ H ├───────■────────░─┤ I ├─░───────────»
#                          ░       ░ ├───┤       │  ┌───┐ ░ ├───┤ ░ ┌───┐     »
#    b_1: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │       └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐   ┌─┐
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ H ├───┤M├
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘   └╥┘
# «   a_1: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_2: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_3: ───────────────────────────────────────────────────────────────────╫─
# «                                                                  ┌───┐┌─┐ ║
# «   b_0: ──────────────────────────────────────────────────────────┤ H ├┤M├─╫─
# «                                                                  └───┘└╥┘ ║
# «   b_1: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_2: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_3: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# « epr: 2/════════════════════════════════════════════════════════════════╩══╩═
# «                                                                        1  0
# « bsm: 2/═════════════════════════════════════════════════════════════════════
# «
# « pcs: 4/═════════════════════════════════════════════════════════════════════
# «
# «junk: 4/═════════════════════════════════════════════════════════════════════
# «
# xx circ:  OrderedDict([('h', 17), ('id', 8), ('measure', 8), ('barrier', 7), ('cz', 6), ('cx', 5), ('switch_case', 1)])
# yy circ:
#         ┌───┐            ░ ┌───┐ ░                      ░       ░           »
#    a_0: ┤ H ├────■───────░─┤ I ├─░──────────────────────░───────░───────────»
#         ├───┤    │ ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░           »
#    a_1: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │    └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░           »
#    b_0: ─────────────────░───────░─┤ H ├───────■────────░─┤ I ├─░───────────»
#                          ░       ░ ├───┤       │  ┌───┐ ░ ├───┤ ░ ┌───┐     »
#    b_1: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │       └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐┌───┐»
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ S ├┤ H ├»
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘└───┘»
# «   a_1: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   a_2: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   a_3: ────────────────────────────────────────────────────────────────────»
# «                                                                  ┌───┐┌───┐»
# «   b_0: ──────────────────────────────────────────────────────────┤ S ├┤ H ├»
# «                                                                  └───┘└───┘»
# «   b_1: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   b_2: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   b_3: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « epr: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# « bsm: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# « pcs: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «junk: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «           ┌─┐
# «   a_0: ───┤M├
# «           └╥┘
# «   a_1: ────╫─
# «            ║
# «   a_2: ────╫─
# «            ║
# «   a_3: ────╫─
# «        ┌─┐ ║
# «   b_0: ┤M├─╫─
# «        └╥┘ ║
# «   b_1: ─╫──╫─
# «         ║  ║
# «   b_2: ─╫──╫─
# «         ║  ║
# «   b_3: ─╫──╫─
# «         ║  ║
# « epr: 2/═╩══╩═
# «         1  0
# « bsm: 2/══════
# «
# « pcs: 4/══════
# «
# «junk: 4/══════
# «
# yy circ:  OrderedDict([('h', 17), ('id', 8), ('measure', 8), ('barrier', 7), ('cz', 6), ('cx', 5), ('s', 2), ('switch_case', 1)])
# zz circ:
#         ┌───┐            ░ ┌───┐ ░                      ░       ░           »
#    a_0: ┤ H ├────■───────░─┤ I ├─░──────────────────────░───────░───────────»
#         ├───┤    │ ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░           »
#    a_1: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │    └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░           »
#    b_0: ─────────────────░───────░─┤ H ├───────■────────░─┤ I ├─░───────────»
#                          ░       ░ ├───┤       │  ┌───┐ ░ ├───┤ ░ ┌───┐     »
#    b_1: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │       └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐    ┌─┐
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├────┤M├
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘    └╥┘
# «   a_1: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_2: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_3: ──────────────────────────────────────────────────────────────╫─
# «                                                                  ┌─┐ ║
# «   b_0: ──────────────────────────────────────────────────────────┤M├─╫─
# «                                                                  └╥┘ ║
# «   b_1: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_2: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_3: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# « epr: 2/═══════════════════════════════════════════════════════════╩══╩═
# «                                                                   1  0
# « bsm: 2/════════════════════════════════════════════════════════════════
# «
# « pcs: 4/════════════════════════════════════════════════════════════════
# «
# «junk: 4/════════════════════════════════════════════════════════════════
# «
# zz circ:  OrderedDict([('h', 15), ('id', 8), ('measure', 8), ('barrier', 7), ('cz', 6), ('cx', 5), ('switch_case', 1)])
# raw key value: 0000 0000 00 01: 91
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91}
# raw key value: 0000 1010 10 00: 6
# pcs key: 1010
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 30
# pcs key: 0010
# raw key value: 0000 0100 01 11: 10
# pcs key: 0100
# raw key value: 0000 0000 10 00: 2289
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289}
# raw key value: 0000 1010 10 01: 4
# pcs key: 1010
# raw key value: 0000 0000 00 00: 2303
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303}
# raw key value: 0000 0010 00 11: 32
# pcs key: 0010
# raw key value: 0000 0011 11 01: 2
# pcs key: 0011
# raw key value: 0000 0000 11 00: 2273
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273}
# raw key value: 0000 0100 01 01: 3
# pcs key: 0100
# raw key value: 0000 0010 11 00: 22
# pcs key: 0010
# raw key value: 0000 0000 00 11: 2266
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266}
# raw key value: 0000 0000 01 11: 2174
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174}
# raw key value: 0000 0011 00 11: 1
# pcs key: 0011
# raw key value: 0000 0010 11 01: 23
# pcs key: 0010
# raw key value: 0000 0000 01 00: 2271
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271}
# raw key value: 0000 0011 01 01: 2
# pcs key: 0011
# raw key value: 0000 0010 10 11: 24
# pcs key: 0010
# raw key value: 0000 0000 00 10: 63
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63}
# raw key value: 0000 0111 10 10: 1
# pcs key: 0111
# raw key value: 0000 0100 01 00: 17
# pcs key: 0100
# raw key value: 0000 0010 01 10: 16
# pcs key: 0010
# raw key value: 0000 0000 11 11: 2321
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321}
# raw key value: 0000 0010 00 10: 26
# pcs key: 0010
# raw key value: 0000 0000 10 11: 2251
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321, '0000 0000 10 11': 2251}
# raw key value: 0000 0010 00 01: 15
# pcs key: 0010
# raw key value: 0000 0000 10 10: 72
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321, '0000 0000 10 11': 2251, '0000 0000 10 10': 72}
# raw key value: 0000 0001 10 11: 33
# pcs key: 0001
# raw key value: 0000 0100 10 01: 11
# pcs key: 0100
# raw key value: 0000 0100 00 00: 14
# pcs key: 0100
# raw key value: 0000 0000 01 10: 81
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321, '0000 0000 10 11': 2251, '0000 0000 10 10': 72, '0000 0000 01 10': 81}
# raw key value: 0000 0010 11 11: 36
# pcs key: 0010
# raw key value: 0000 0100 11 00: 14
# pcs key: 0100
# raw key value: 0000 0000 11 10: 67
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321, '0000 0000 10 11': 2251, '0000 0000 10 10': 72, '0000 0000 01 10': 81, '0000 0000 11 10': 67}
# raw key value: 0000 0010 01 01: 22
# pcs key: 0010
# raw key value: 0000 0101 00 00: 5
# pcs key: 0101
# raw key value: 0000 0001 00 00: 31
# pcs key: 0001
# raw key value: 0000 1010 00 00: 2
# pcs key: 1010
# raw key value: 0000 0000 10 01: 79
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321, '0000 0000 10 11': 2251, '0000 0000 10 10': 72, '0000 0000 01 10': 81, '0000 0000 11 10': 67, '0000 0000 10 01': 79}
# raw key value: 0000 0010 11 10: 25
# pcs key: 0010
# raw key value: 0000 0000 01 01: 70
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321, '0000 0000 10 11': 2251, '0000 0000 10 10': 72, '0000 0000 01 10': 81, '0000 0000 11 10': 67, '0000 0000 10 01': 79, '0000 0000 01 01': 70}
# raw key value: 0000 0010 10 01: 22
# pcs key: 0010
# raw key value: 0000 0001 01 01: 26
# pcs key: 0001
# raw key value: 0000 0001 01 10: 29
# pcs key: 0001
# raw key value: 0000 1000 11 00: 14
# pcs key: 1000
# raw key value: 0000 0001 10 00: 22
# pcs key: 0001
# raw key value: 0000 1011 10 10: 1
# pcs key: 1011
# raw key value: 0000 0101 01 00: 8
# pcs key: 0101
# raw key value: 0000 0001 11 00: 34
# pcs key: 0001
# raw key value: 0000 0100 10 10: 4
# pcs key: 0100
# raw key value: 0000 0010 01 11: 24
# pcs key: 0010
# raw key value: 0000 0001 11 11: 18
# pcs key: 0001
# raw key value: 0000 0010 01 00: 23
# pcs key: 0010
# raw key value: 0000 0000 11 01: 74
# pcs key: 0000
# filtered results: {'0000 0000 00 01': 91, '0000 0000 10 00': 2289, '0000 0000 00 00': 2303, '0000 0000 11 00': 2273, '0000 0000 00 11': 2266, '0000 0000 01 11': 2174, '0000 0000 01 00': 2271, '0000 0000 00 10': 63, '0000 0000 11 11': 2321, '0000 0000 10 11': 2251, '0000 0000 10 10': 72, '0000 0000 01 10': 81, '0000 0000 11 10': 67, '0000 0000 10 01': 79, '0000 0000 01 01': 70, '0000 0000 11 01': 74}
# raw key value: 0000 0001 11 01: 28
# pcs key: 0001
# raw key value: 0000 1010 11 00: 6
# pcs key: 1010
# raw key value: 0000 1000 01 00: 4
# pcs key: 1000
# raw key value: 0000 1000 10 11: 14
# pcs key: 1000
# raw key value: 0000 0001 01 00: 27
# pcs key: 0001
# raw key value: 0000 0101 11 01: 4
# pcs key: 0101
# raw key value: 0000 1000 00 11: 10
# pcs key: 1000
# raw key value: 0000 0001 00 01: 15
# pcs key: 0001
# raw key value: 0000 1010 10 11: 3
# pcs key: 1010
# raw key value: 0000 0101 11 10: 7
# pcs key: 0101
# raw key value: 0000 0010 00 00: 25
# pcs key: 0010
# raw key value: 0000 1000 01 11: 11
# pcs key: 1000
# raw key value: 0000 0001 11 10: 24
# pcs key: 0001
# raw key value: 0000 0001 00 10: 18
# pcs key: 0001
# raw key value: 0000 1000 11 10: 5
# pcs key: 1000
# raw key value: 0000 0101 10 01: 7
# pcs key: 0101
# raw key value: 0000 0001 10 01: 19
# pcs key: 0001
# raw key value: 0000 0101 01 01: 10
# pcs key: 0101
# raw key value: 0000 1010 01 00: 8
# pcs key: 1010
# raw key value: 0000 0101 10 11: 6
# pcs key: 0101
# raw key value: 0000 1101 01 10: 1
# pcs key: 1101
# raw key value: 0000 1000 00 10: 6
# pcs key: 1000
# raw key value: 0000 0001 00 11: 28
# pcs key: 0001
# raw key value: 0000 0101 10 00: 7
# pcs key: 0101
# raw key value: 0000 0100 10 00: 13
# pcs key: 0100
# raw key value: 0000 1010 00 11: 7
# pcs key: 1010
# raw key value: 0000 0001 10 10: 25
# pcs key: 0001
# raw key value: 0000 1010 11 11: 5
# pcs key: 1010
# raw key value: 0000 1010 11 01: 6
# pcs key: 1010
# raw key value: 0000 0010 10 00: 28
# pcs key: 0010
# raw key value: 0000 0001 01 11: 19
# pcs key: 0001
# raw key value: 0000 1000 11 01: 11
# pcs key: 1000
# raw key value: 0000 0101 11 11: 2
# pcs key: 0101
# raw key value: 0000 0100 01 10: 7
# pcs key: 0100
# raw key value: 0000 1000 00 00: 14
# pcs key: 1000
# raw key value: 0000 0100 00 01: 3
# pcs key: 0100
# raw key value: 0000 1000 01 10: 8
# pcs key: 1000
# raw key value: 0000 1000 10 01: 6
# pcs key: 1000
# raw key value: 0000 0100 10 11: 13
# pcs key: 0100
# raw key value: 0000 0100 00 11: 16
# pcs key: 0100
# raw key value: 0000 1010 00 10: 5
# pcs key: 1010
# raw key value: 0000 0101 00 10: 5
# pcs key: 0101
# raw key value: 0000 1000 11 11: 11
# pcs key: 1000
# raw key value: 0000 1000 10 10: 9
# pcs key: 1000
# raw key value: 0000 1010 01 01: 5
# pcs key: 1010
# raw key value: 0000 1010 01 10: 5
# pcs key: 1010
# raw key value: 0000 0011 00 00: 1
# pcs key: 0011
# raw key value: 0000 0100 11 01: 8
# pcs key: 0100
# raw key value: 0000 0101 01 10: 5
# pcs key: 0101
# raw key value: 0000 0111 00 11: 1
# pcs key: 0111
# raw key value: 0000 0100 11 11: 6
# pcs key: 0100
# raw key value: 0000 0100 11 10: 5
# pcs key: 0100
# raw key value: 0000 1000 10 00: 9
# pcs key: 1000
# raw key value: 0000 1010 10 10: 8
# pcs key: 1010
# raw key value: 0000 1000 01 01: 5
# pcs key: 1000
# raw key value: 0000 1000 00 01: 4
# pcs key: 1000
# raw key value: 0000 0011 01 11: 1
# pcs key: 0011
# raw key value: 0000 1010 01 11: 2
# pcs key: 1010
# raw key value: 0000 0101 11 00: 3
# pcs key: 0101
# raw key value: 0000 0101 00 11: 4
# pcs key: 0101
# raw key value: 0000 0101 10 10: 4
# pcs key: 0101
# raw key value: 0000 0100 00 10: 4
# pcs key: 0100
# raw key value: 0000 0110 00 00: 1
# pcs key: 0110
# raw key value: 0000 1010 11 10: 5
# pcs key: 1010
# raw key value: 0000 0101 00 01: 1
# pcs key: 0101
# raw key value: 0000 1110 10 01: 1
# pcs key: 1110
# raw key value: 0000 0110 11 01: 1
# pcs key: 0110
# raw key value: 0000 1001 11 11: 1
# pcs key: 1001
# raw key value: 0000 0110 10 11: 1
# pcs key: 0110
# raw key value: 0000 1001 00 11: 1
# pcs key: 1001
# raw key value: 0000 0101 01 11: 1
# pcs key: 0101
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 0111 10 01: 1
# pcs key: 0111
# raw key value: 0000 1110 00 00: 1
# pcs key: 1110
# raw key value: 0000 0100 00 11: 7
# pcs key: 0100
# raw key value: 0000 0011 00 10: 1
# pcs key: 0011
# raw key value: 0000 0010 11 10: 25
# pcs key: 0010
# raw key value: 0000 0000 01 01: 2241
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241}
# raw key value: 0000 0011 11 11: 1
# pcs key: 0011
# raw key value: 0000 0010 00 01: 23
# pcs key: 0010
# raw key value: 0000 0000 10 10: 2339
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339}
# raw key value: 0000 1010 00 00: 3
# pcs key: 1010
# raw key value: 0000 0000 10 01: 2252
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252}
# raw key value: 0000 0010 10 11: 14
# pcs key: 0010
# raw key value: 0000 0100 01 00: 7
# pcs key: 0100
# raw key value: 0000 0000 00 10: 2205
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205}
# raw key value: 0000 0100 10 11: 3
# pcs key: 0100
# raw key value: 0000 0010 01 00: 26
# pcs key: 0010
# raw key value: 0000 0000 11 01: 2223
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223}
# raw key value: 0000 0010 01 10: 33
# pcs key: 0010
# raw key value: 0000 0000 11 11: 80
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80}
# raw key value: 0000 0100 00 00: 11
# pcs key: 0100
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0010 11 11: 27
# pcs key: 0010
# raw key value: 0000 0000 01 10: 2230
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230}
# raw key value: 0000 0000 10 00: 90
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90}
# raw key value: 0000 1010 00 01: 7
# pcs key: 1010
# raw key value: 0000 0100 11 00: 10
# pcs key: 0100
# raw key value: 0000 0010 01 01: 31
# pcs key: 0010
# raw key value: 0000 0000 11 10: 2276
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276}
# raw key value: 0000 0010 11 01: 28
# pcs key: 0010
# raw key value: 0000 0000 01 00: 87
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276, '0000 0000 01 00': 87}
# raw key value: 0000 0000 00 01: 2306
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276, '0000 0000 01 00': 87, '0000 0000 00 01': 2306}
# raw key value: 0000 1010 10 00: 9
# pcs key: 1010
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 33
# pcs key: 0010
# raw key value: 0000 0011 00 00: 2
# pcs key: 0011
# raw key value: 0000 0000 01 11: 77
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276, '0000 0000 01 00': 87, '0000 0000 00 01': 2306, '0000 0000 01 11': 77}
# raw key value: 0000 0100 11 10: 11
# pcs key: 0100
# raw key value: 0000 0010 00 11: 26
# pcs key: 0010
# raw key value: 0000 0000 11 00: 82
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276, '0000 0000 01 00': 87, '0000 0000 00 01': 2306, '0000 0000 01 11': 77, '0000 0000 11 00': 82}
# raw key value: 0000 0010 00 00: 27
# pcs key: 0010
# raw key value: 0000 0100 01 10: 11
# pcs key: 0100
# raw key value: 0000 0000 00 00: 81
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276, '0000 0000 01 00': 87, '0000 0000 00 01': 2306, '0000 0000 01 11': 77, '0000 0000 11 00': 82, '0000 0000 00 00': 81}
# raw key value: 0000 1010 10 01: 4
# pcs key: 1010
# raw key value: 0000 0001 00 00: 29
# pcs key: 0001
# raw key value: 0000 0010 01 11: 22
# pcs key: 0010
# raw key value: 0000 0001 10 10: 31
# pcs key: 0001
# raw key value: 0000 0010 00 10: 29
# pcs key: 0010
# raw key value: 0000 0011 11 10: 2
# pcs key: 0011
# raw key value: 0000 0000 10 11: 90
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276, '0000 0000 01 00': 87, '0000 0000 00 01': 2306, '0000 0000 01 11': 77, '0000 0000 11 00': 82, '0000 0000 00 00': 81, '0000 0000 10 11': 90}
# raw key value: 0000 1000 01 01: 8
# pcs key: 1000
# raw key value: 0000 1010 01 00: 6
# pcs key: 1010
# raw key value: 0000 0101 00 01: 5
# pcs key: 0101
# raw key value: 0000 1000 11 11: 10
# pcs key: 1000
# raw key value: 0000 0001 00 10: 29
# pcs key: 0001
# raw key value: 0000 0001 00 01: 26
# pcs key: 0001
# raw key value: 0000 0100 10 00: 10
# pcs key: 0100
# raw key value: 0000 1010 01 11: 5
# pcs key: 1010
# raw key value: 0000 0001 11 01: 26
# pcs key: 0001
# raw key value: 0000 0010 11 00: 27
# pcs key: 0010
# raw key value: 0000 0000 00 11: 67
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 2241, '0000 0000 10 10': 2339, '0000 0000 10 01': 2252, '0000 0000 00 10': 2205, '0000 0000 11 01': 2223, '0000 0000 11 11': 80, '0000 0000 01 10': 2230, '0000 0000 10 00': 90, '0000 0000 11 10': 2276, '0000 0000 01 00': 87, '0000 0000 00 01': 2306, '0000 0000 01 11': 77, '0000 0000 11 00': 82, '0000 0000 00 00': 81, '0000 0000 10 11': 90, '0000 0000 00 11': 67}
# raw key value: 0000 0010 10 00: 19
# pcs key: 0010
# raw key value: 0000 0001 00 11: 19
# pcs key: 0001
# raw key value: 0000 1000 10 10: 12
# pcs key: 1000
# raw key value: 0000 0001 11 11: 18
# pcs key: 0001
# raw key value: 0000 0001 01 01: 30
# pcs key: 0001
# raw key value: 0000 0101 10 01: 5
# pcs key: 0101
# raw key value: 0000 1000 10 00: 10
# pcs key: 1000
# raw key value: 0000 0010 10 01: 16
# pcs key: 0010
# raw key value: 0000 0001 01 11: 19
# pcs key: 0001
# raw key value: 0000 0001 10 11: 23
# pcs key: 0001
# raw key value: 0000 1000 00 10: 16
# pcs key: 1000
# raw key value: 0000 0001 01 00: 25
# pcs key: 0001
# raw key value: 0000 0001 11 00: 20
# pcs key: 0001
# raw key value: 0000 1001 00 11: 1
# pcs key: 1001
# raw key value: 0000 0100 01 01: 11
# pcs key: 0100
# raw key value: 0000 0101 01 11: 8
# pcs key: 0101
# raw key value: 0000 0101 01 01: 6
# pcs key: 0101
# raw key value: 0000 0001 10 01: 23
# pcs key: 0001
# raw key value: 0000 0111 01 00: 1
# pcs key: 0111
# raw key value: 0000 0100 10 10: 9
# pcs key: 0100
# raw key value: 0000 0100 00 01: 11
# pcs key: 0100
# raw key value: 0000 0101 11 00: 7
# pcs key: 0101
# raw key value: 0000 1000 01 00: 5
# pcs key: 1000
# raw key value: 0000 0001 11 10: 29
# pcs key: 0001
# raw key value: 0000 0101 11 01: 5
# pcs key: 0101
# raw key value: 0000 1010 00 11: 10
# pcs key: 1010
# raw key value: 0000 1000 00 01: 8
# pcs key: 1000
# raw key value: 0000 1010 10 10: 7
# pcs key: 1010
# raw key value: 0000 0001 10 00: 19
# pcs key: 0001
# raw key value: 0000 0101 10 10: 8
# pcs key: 0101
# raw key value: 0000 0100 10 01: 8
# pcs key: 0100
# raw key value: 0000 1010 01 01: 7
# pcs key: 1010
# raw key value: 0000 1010 01 10: 8
# pcs key: 1010
# raw key value: 0000 0101 00 00: 9
# pcs key: 0101
# raw key value: 0000 1000 00 11: 7
# pcs key: 1000
# raw key value: 0000 0001 01 10: 29
# pcs key: 0001
# raw key value: 0000 0101 11 10: 6
# pcs key: 0101
# raw key value: 0000 1000 11 01: 11
# pcs key: 1000
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 0100 00 10: 9
# pcs key: 0100
# raw key value: 0000 1000 10 01: 9
# pcs key: 1000
# raw key value: 0000 0100 11 11: 10
# pcs key: 0100
# raw key value: 0000 1000 11 00: 7
# pcs key: 1000
# raw key value: 0000 1000 01 11: 3
# pcs key: 1000
# raw key value: 0000 1010 10 11: 6
# pcs key: 1010
# raw key value: 0000 1010 11 10: 4
# pcs key: 1010
# raw key value: 0000 1100 10 10: 1
# pcs key: 1100
# raw key value: 0000 0100 11 01: 4
# pcs key: 0100
# raw key value: 0000 0101 01 00: 6
# pcs key: 0101
# raw key value: 0000 0101 10 00: 6
# pcs key: 0101
# raw key value: 0000 0101 00 10: 4
# pcs key: 0101
# raw key value: 0000 1010 11 01: 6
# pcs key: 1010
# raw key value: 0000 1010 00 10: 4
# pcs key: 1010
# raw key value: 0000 1011 11 11: 1
# pcs key: 1011
# raw key value: 0000 0101 00 11: 3
# pcs key: 0101
# raw key value: 0000 1000 10 11: 4
# pcs key: 1000
# raw key value: 0000 0101 10 11: 6
# pcs key: 0101
# raw key value: 0000 1000 11 10: 8
# pcs key: 1000
# raw key value: 0000 1000 01 10: 7
# pcs key: 1000
# raw key value: 0000 1010 11 11: 5
# pcs key: 1010
# raw key value: 0000 0101 01 10: 5
# pcs key: 0101
# raw key value: 0000 0101 11 11: 4
# pcs key: 0101
# raw key value: 0000 1010 11 00: 5
# pcs key: 1010
# raw key value: 0000 0100 01 11: 6
# pcs key: 0100
# raw key value: 0000 1000 00 00: 3
# pcs key: 1000
# raw key value: 0000 1100 10 00: 1
# pcs key: 1100
# raw key value: 0000 1011 10 00: 1
# pcs key: 1011
# raw key value: 0000 0011 10 01: 1
# pcs key: 0011
# raw key value: 0000 1001 01 11: 1
# pcs key: 1001
# raw key value: 0000 0111 10 01: 1
# pcs key: 0111
# raw key value: 0000 0000 01 11: 2280
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280}
# raw key value: 0000 0011 11 10: 1
# pcs key: 0011
# raw key value: 0000 0010 00 10: 22
# pcs key: 0010
# raw key value: 0000 0000 10 11: 2284
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284}
# raw key value: 0000 0011 01 00: 1
# pcs key: 0011
# raw key value: 0000 0010 11 00: 23
# pcs key: 0010
# raw key value: 0000 0000 00 11: 2308
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308}
# raw key value: 0000 0000 10 01: 39
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39}
# raw key value: 0000 0000 10 10: 57
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57}
# raw key value: 0000 0010 00 01: 28
# pcs key: 0010
# raw key value: 0000 0010 01 10: 23
# pcs key: 0010
# raw key value: 0000 0000 11 11: 2247
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247}
# raw key value: 0000 0011 00 11: 1
# pcs key: 0011
# raw key value: 0000 0010 11 01: 18
# pcs key: 0010
# raw key value: 0000 0000 01 00: 2362
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362}
# raw key value: 0000 1010 10 01: 6
# pcs key: 1010
# raw key value: 0000 0000 00 00: 2265
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265}
# raw key value: 0000 0011 11 01: 2
# pcs key: 0011
# raw key value: 0000 0010 00 11: 22
# pcs key: 0010
# raw key value: 0000 0000 11 00: 2293
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293}
# raw key value: 0000 0100 10 11: 19
# pcs key: 0100
# raw key value: 0000 0010 01 00: 30
# pcs key: 0010
# raw key value: 0000 0000 11 01: 40
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293, '0000 0000 11 01': 40}
# raw key value: 0000 0000 10 00: 2361
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293, '0000 0000 11 01': 40, '0000 0000 10 00': 2361}
# raw key value: 0000 1010 00 01: 10
# pcs key: 1010
# raw key value: 0000 0001 10 11: 32
# pcs key: 0001
# raw key value: 0000 0101 01 01: 11
# pcs key: 0101
# raw key value: 0000 0001 10 01: 25
# pcs key: 0001
# raw key value: 0000 0000 11 10: 54
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293, '0000 0000 11 01': 40, '0000 0000 10 00': 2361, '0000 0000 11 10': 54}
# raw key value: 0000 0001 11 11: 33
# pcs key: 0001
# raw key value: 0000 0001 00 10: 20
# pcs key: 0001
# raw key value: 0000 0000 01 10: 43
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293, '0000 0000 11 01': 40, '0000 0000 10 00': 2361, '0000 0000 11 10': 54, '0000 0000 01 10': 43}
# raw key value: 0000 0111 11 10: 1
# pcs key: 0111
# raw key value: 0000 0100 00 00: 20
# pcs key: 0100
# raw key value: 0000 0010 10 01: 20
# pcs key: 0010
# raw key value: 0000 1010 00 10: 15
# pcs key: 1010
# raw key value: 0000 0100 11 11: 17
# pcs key: 0100
# raw key value: 0000 0010 00 00: 34
# pcs key: 0010
# raw key value: 0000 0101 01 10: 10
# pcs key: 0101
# raw key value: 0000 0001 01 01: 33
# pcs key: 0001
# raw key value: 0000 0101 10 01: 15
# pcs key: 0101
# raw key value: 0000 0010 10 10: 18
# pcs key: 0010
# raw key value: 0000 1010 10 00: 1
# pcs key: 1010
# raw key value: 0000 0000 00 01: 47
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293, '0000 0000 11 01': 40, '0000 0000 10 00': 2361, '0000 0000 11 10': 54, '0000 0000 01 10': 43, '0000 0000 00 01': 47}
# raw key value: 0000 1000 01 00: 14
# pcs key: 1000
# raw key value: 0000 1000 00 00: 13
# pcs key: 1000
# raw key value: 0000 0000 01 01: 39
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293, '0000 0000 11 01': 40, '0000 0000 10 00': 2361, '0000 0000 11 10': 54, '0000 0000 01 10': 43, '0000 0000 00 01': 47, '0000 0000 01 01': 39}
# raw key value: 0000 0100 00 11: 17
# pcs key: 0100
# raw key value: 0000 1001 11 01: 1
# pcs key: 1001
# raw key value: 0000 0010 11 10: 30
# pcs key: 0010
# raw key value: 0000 0001 00 01: 23
# pcs key: 0001
# raw key value: 0000 0101 11 10: 9
# pcs key: 0101
# raw key value: 0000 0001 00 11: 29
# pcs key: 0001
# raw key value: 0000 1010 11 10: 9
# pcs key: 1010
# raw key value: 0000 0001 11 01: 26
# pcs key: 0001
# raw key value: 0000 1010 11 01: 15
# pcs key: 1010
# raw key value: 0000 1000 00 11: 11
# pcs key: 1000
# raw key value: 0000 0000 00 10: 42
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 2280, '0000 0000 10 11': 2284, '0000 0000 00 11': 2308, '0000 0000 10 01': 39, '0000 0000 10 10': 57, '0000 0000 11 11': 2247, '0000 0000 01 00': 2362, '0000 0000 00 00': 2265, '0000 0000 11 00': 2293, '0000 0000 11 01': 40, '0000 0000 10 00': 2361, '0000 0000 11 10': 54, '0000 0000 01 10': 43, '0000 0000 00 01': 47, '0000 0000 01 01': 39, '0000 0000 00 10': 42}
# raw key value: 0000 0100 10 00: 20
# pcs key: 0100
# raw key value: 0000 1010 10 10: 8
# pcs key: 1010
# raw key value: 0000 0010 10 00: 22
# pcs key: 0010
# raw key value: 0000 0001 10 10: 29
# pcs key: 0001
# raw key value: 0000 0001 11 10: 15
# pcs key: 0001
# raw key value: 0000 0001 11 00: 15
# pcs key: 0001
# raw key value: 0000 1010 01 10: 14
# pcs key: 1010
# raw key value: 0000 0001 10 00: 20
# pcs key: 0001
# raw key value: 0000 0001 01 00: 27
# pcs key: 0001
# raw key value: 0000 0101 00 10: 13
# pcs key: 0101
# raw key value: 0000 0001 00 00: 38
# pcs key: 0001
# raw key value: 0000 1011 01 11: 1
# pcs key: 1011
# raw key value: 0000 0010 01 11: 34
# pcs key: 0010
# raw key value: 0000 0100 01 11: 11
# pcs key: 0100
# raw key value: 0000 1000 11 11: 10
# pcs key: 1000
# raw key value: 0000 0011 10 11: 1
# pcs key: 0011
# raw key value: 0000 0010 01 01: 23
# pcs key: 0010
# raw key value: 0000 0011 01 01: 1
# pcs key: 0011
# raw key value: 0000 0010 10 11: 25
# pcs key: 0010
# raw key value: 0000 1000 10 11: 12
# pcs key: 1000
# raw key value: 0000 0010 11 11: 27
# pcs key: 0010
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 1001 00 00: 1
# pcs key: 1001
# raw key value: 0000 1000 10 00: 7
# pcs key: 1000
# raw key value: 0000 1000 11 00: 11
# pcs key: 1000
# raw key value: 0000 0001 01 11: 28
# pcs key: 0001
# raw key value: 0000 1000 10 10: 1
# pcs key: 1000
# raw key value: 0000 0001 01 10: 18
# pcs key: 0001
# raw key value: 0000 0101 11 00: 1
# pcs key: 0101
# raw key value: 0000 1001 00 01: 1
# pcs key: 1001
# raw key value: 0000 0100 01 00: 18
# pcs key: 0100
# raw key value: 0000 0101 11 01: 15
# pcs key: 0101
# raw key value: 0000 1000 01 11: 9
# pcs key: 1000
# raw key value: 0000 0101 00 01: 5
# pcs key: 0101
# raw key value: 0000 1010 01 01: 12
# pcs key: 1010
# raw key value: 0000 0100 01 01: 1
# pcs key: 0100
# raw key value: 0000 0101 10 10: 7
# pcs key: 0101
# raw key value: 0000 1100 01 11: 1
# pcs key: 1100
# raw key value: 0000 1010 01 00: 2
# pcs key: 1010
# raw key value: 0000 0111 01 10: 1
# pcs key: 0111
# raw key value: 0000 0100 11 00: 10
# pcs key: 0100
# raw key value: 0000 1101 00 10: 1
# pcs key: 1101
# raw key value: 0000 0110 01 00: 1
# pcs key: 0110
# raw key value: 0000 1010 10 11: 1
# pcs key: 1010
# raw key value: 0000 1010 00 11: 1
# pcs key: 1010
# raw key value: 0000 0101 00 11: 1
# pcs key: 0101
# raw key value: 0000 0110 11 01: 1
# pcs key: 0110
# raw key value: 0000 0101 00 00: 1
# pcs key: 0101
# raw key value: 0000 0110 01 10: 1
# pcs key: 0110
# raw key value: 0000 1001 10 00: 1
# pcs key: 1001
# raw key value: 0000 1010 11 00: 1
# pcs key: 1010
# raw key value: 0000 0100 01 10: 1
# pcs key: 0100
# raw key value: 0000 0111 11 00: 1
# pcs key: 0111
# raw key value: 0000 0110 11 11: 1
# pcs key: 0110
# raw key value: 0000 0110 10 11: 1
# pcs key: 0110
# raw key value: 0000 0111 10 01: 1
# pcs key: 0111
# collected vals:  {'01': 314, '00': 9136, '11': 9012, '10': 283}
# collected vals:  {'01': 9022, '10': 9050, '11': 314, '00': 340}
# collected vals:  {'11': 9119, '01': 165, '10': 196, '00': 9281}
# 0.9569923793903943
# depolarizing error: 0.05
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
# ...
# raw key value: 0000 0011 11 01: 80
# pcs key: 0011
# raw key value: 0000 0010 00 11: 105
# pcs key: 0010
# raw key value: 0000 0100 11 10: 100
# pcs key: 0100
# raw key value: 0000 0111 00 00: 53
# pcs key: 0111
# raw key value: 0000 0001 00 10: 117
# pcs key: 0001
# raw key value: 0000 0010 10 01: 109
# pcs key: 0010
# raw key value: 0000 0101 00 00: 72
# pcs key: 0101
# raw key value: 0000 1011 11 10: 58
# pcs key: 1011
# raw key value: 0000 0001 11 01: 120
# pcs key: 0001
# raw key value: 0000 0110 00 01: 64
# pcs key: 0110
# raw key value: 0000 0001 01 01: 133
# pcs key: 0001
# raw key value: 0000 0101 10 01: 98
# pcs key: 0101
# raw key value: 0000 0111 11 10: 56
# pcs key: 0111
# raw key value: 0000 0100 00 00: 90
# pcs key: 0100
# raw key value: 0000 0000 01 10: 148
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148}
# raw key value: 0000 0001 01 11: 124
# pcs key: 0001
# raw key value: 0000 0111 01 01: 59
# pcs key: 0111
# raw key value: 0000 0000 11 11: 186
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186}
# raw key value: 0000 0011 11 00: 77
# pcs key: 0011
# raw key value: 0000 0010 01 00: 160
# pcs key: 0010
# raw key value: 0000 0000 11 01: 124
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124}
# raw key value: 0000 0111 01 11: 62
# pcs key: 0111
# raw key value: 0000 0100 10 11: 120
# pcs key: 0100
# raw key value: 0000 1011 10 01: 65
# pcs key: 1011
# raw key value: 0000 1111 11 10: 43
# pcs key: 1111
# raw key value: 0000 1001 11 01: 46
# pcs key: 1001
# raw key value: 0000 1100 10 11: 44
# pcs key: 1100
# raw key value: 0000 1110 00 00: 36
# pcs key: 1110
# raw key value: 0000 1010 00 00: 81
# pcs key: 1010
# raw key value: 0000 0000 10 01: 172
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172}
# raw key value: 0000 1000 01 00: 86
# pcs key: 1000
# raw key value: 0000 1000 11 00: 111
# pcs key: 1000
# raw key value: 0000 1001 10 01: 64
# pcs key: 1001
# raw key value: 0000 1010 10 10: 86
# pcs key: 1010
# raw key value: 0000 0010 00 01: 112
# pcs key: 0010
# raw key value: 0000 0011 11 11: 72
# pcs key: 0011
# raw key value: 0000 1001 00 00: 55
# pcs key: 1001
# raw key value: 0000 1010 11 11: 69
# pcs key: 1010
# raw key value: 0000 0001 10 01: 116
# pcs key: 0001
# raw key value: 0000 1000 10 11: 91
# pcs key: 1000
# raw key value: 0000 0010 01 11: 119
# pcs key: 0010
# raw key value: 0000 0100 10 10: 76
# pcs key: 0100
# raw key value: 0000 0111 01 00: 61
# pcs key: 0111
# raw key value: 0000 0110 11 11: 63
# pcs key: 0110
# raw key value: 0000 0001 00 11: 107
# pcs key: 0001
# raw key value: 0000 1000 00 01: 70
# pcs key: 1000
# raw key value: 0000 0011 00 11: 85
# pcs key: 0011
# raw key value: 0000 0010 11 01: 127
# pcs key: 0010
# raw key value: 0000 0111 10 00: 65
# pcs key: 0111
# raw key value: 0000 1100 10 01: 51
# pcs key: 1100
# raw key value: 0000 1010 00 01: 106
# pcs key: 1010
# raw key value: 0000 0000 10 00: 207
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207}
# raw key value: 0000 0010 01 01: 129
# pcs key: 0010
# raw key value: 0000 0011 10 11: 63
# pcs key: 0011
# raw key value: 0000 0111 01 10: 52
# pcs key: 0111
# raw key value: 0000 0100 11 00: 81
# pcs key: 0100
# raw key value: 0000 1010 10 00: 76
# pcs key: 1010
# raw key value: 0000 0000 00 01: 130
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130}
# raw key value: 0000 0011 01 00: 81
# pcs key: 0011
# raw key value: 0000 0010 11 00: 108
# pcs key: 0010
# raw key value: 0000 1101 11 10: 45
# pcs key: 1101
# raw key value: 0000 0100 01 01: 100
# pcs key: 0100
# raw key value: 0000 0111 00 11: 57
# pcs key: 0111
# raw key value: 0000 0100 11 11: 96
# pcs key: 0100
# raw key value: 0000 1111 10 00: 33
# pcs key: 1111
# raw key value: 0000 1000 11 11: 101
# pcs key: 1000
# raw key value: 0000 0100 01 10: 77
# pcs key: 0100
# raw key value: 0000 0111 11 00: 69
# pcs key: 0111
# raw key value: 0000 0000 00 00: 197
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197}
# raw key value: 0000 1010 10 01: 88
# pcs key: 1010
# raw key value: 0000 1001 10 10: 66
# pcs key: 1001
# raw key value: 0000 1011 10 00: 70
# pcs key: 1011
# raw key value: 0000 0000 00 10: 140
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140}
# raw key value: 0000 0010 10 11: 125
# pcs key: 0010
# raw key value: 0000 0011 01 01: 74
# pcs key: 0011
# raw key value: 0000 0100 10 00: 104
# pcs key: 0100
# raw key value: 0000 0101 01 11: 89
# pcs key: 0101
# raw key value: 0000 1011 10 11: 75
# pcs key: 1011
# raw key value: 0000 1011 01 00: 50
# pcs key: 1011
# raw key value: 0000 0101 10 10: 93
# pcs key: 0101
# raw key value: 0000 0010 10 10: 140
# pcs key: 0010
# raw key value: 0000 0011 01 10: 83
# pcs key: 0011
# raw key value: 0000 0000 01 11: 186
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140, '0000 0000 01 11': 186}
# raw key value: 0000 1110 01 01: 42
# pcs key: 1110
# raw key value: 0000 1011 10 10: 69
# pcs key: 1011
# raw key value: 0000 0101 01 00: 87
# pcs key: 0101
# raw key value: 0000 1000 11 10: 72
# pcs key: 1000
# raw key value: 0000 1011 00 00: 54
# pcs key: 1011
# raw key value: 0000 0101 11 10: 92
# pcs key: 0101
# raw key value: 0000 0000 01 01: 152
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140, '0000 0000 01 11': 186, '0000 0000 01 01': 152}
# raw key value: 0000 1001 00 11: 62
# pcs key: 1001
# raw key value: 0000 0001 00 00: 110
# pcs key: 0001
# raw key value: 0000 1010 10 11: 69
# pcs key: 1010
# raw key value: 0000 1011 01 11: 59
# pcs key: 1011
# raw key value: 0000 0101 10 11: 77
# pcs key: 0101
# raw key value: 0000 1001 01 11: 60
# pcs key: 1001
# raw key value: 0000 1000 00 00: 109
# pcs key: 1000
# raw key value: 0000 1100 00 10: 43
# pcs key: 1100
# raw key value: 0000 1010 01 11: 75
# pcs key: 1010
# raw key value: 0000 0100 01 00: 100
# pcs key: 0100
# raw key value: 0000 0111 10 10: 51
# pcs key: 0111
# raw key value: 0000 1111 10 11: 56
# pcs key: 1111
# raw key value: 0000 0101 00 10: 114
# pcs key: 0101
# raw key value: 0000 1010 11 10: 86
# pcs key: 1010
# raw key value: 0000 1111 11 01: 41
# pcs key: 1111
# raw key value: 0000 1000 01 10: 77
# pcs key: 1000
# raw key value: 0000 1001 11 10: 71
# pcs key: 1001
# raw key value: 0000 1100 00 11: 39
# pcs key: 1100
# raw key value: 0000 1110 10 10: 38
# pcs key: 1110
# raw key value: 0000 1010 11 01: 89
# pcs key: 1010
# raw key value: 0000 1000 01 01: 74
# pcs key: 1000
# raw key value: 0000 0111 10 11: 46
# pcs key: 0111
# raw key value: 0000 0100 01 11: 108
# pcs key: 0100
# raw key value: 0000 1001 01 00: 67
# pcs key: 1001
# raw key value: 0000 1011 00 11: 61
# pcs key: 1011
# raw key value: 0000 0101 11 11: 79
# pcs key: 0101
# raw key value: 0000 1000 01 11: 93
# pcs key: 1000
# raw key value: 0000 0000 01 00: 202
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140, '0000 0000 01 11': 186, '0000 0000 01 01': 152, '0000 0000 01 00': 202}
# raw key value: 0000 1010 11 00: 84
# pcs key: 1010
# raw key value: 0000 1010 00 10: 94
# pcs key: 1010
# raw key value: 0000 0000 00 11: 210
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140, '0000 0000 01 11': 186, '0000 0000 01 01': 152, '0000 0000 01 00': 202, '0000 0000 00 11': 210}
# raw key value: 0000 0011 10 10: 76
# pcs key: 0011
# raw key value: 0000 0010 01 10: 113
# pcs key: 0010
# raw key value: 0000 1011 11 01: 62
# pcs key: 1011
# raw key value: 0000 0101 00 01: 85
# pcs key: 0101
# raw key value: 0000 1101 00 11: 36
# pcs key: 1101
# raw key value: 0000 1100 10 00: 47
# pcs key: 1100
# raw key value: 0000 1111 00 01: 34
# pcs key: 1111
# raw key value: 0000 0001 10 10: 129
# pcs key: 0001
# raw key value: 0000 1100 11 10: 45
# pcs key: 1100
# raw key value: 0000 1110 01 11: 48
# pcs key: 1110
# raw key value: 0000 0111 11 11: 51
# pcs key: 0111
# raw key value: 0000 0100 00 11: 103
# pcs key: 0100
# raw key value: 0000 1100 01 11: 45
# pcs key: 1100
# raw key value: 0000 1110 11 10: 54
# pcs key: 1110
# raw key value: 0000 1100 01 01: 43
# pcs key: 1100
# raw key value: 0000 1111 00 00: 43
# pcs key: 1111
# raw key value: 0000 1101 00 10: 58
# pcs key: 1101
# raw key value: 0000 0110 00 00: 63
# pcs key: 0110
# raw key value: 0000 0001 11 00: 98
# pcs key: 0001
# raw key value: 0000 0001 11 11: 112
# pcs key: 0001
# raw key value: 0000 1010 01 10: 92
# pcs key: 1010
# raw key value: 0000 1011 11 00: 63
# pcs key: 1011
# raw key value: 0000 0101 01 10: 80
# pcs key: 0101
# raw key value: 0000 1110 00 11: 46
# pcs key: 1110
# raw key value: 0000 1100 10 10: 37
# pcs key: 1100
# raw key value: 0000 1001 11 00: 54
# pcs key: 1001
# raw key value: 0000 0011 00 10: 66
# pcs key: 0011
# raw key value: 0000 0010 11 10: 126
# pcs key: 0010
# raw key value: 0000 0110 00 11: 51
# pcs key: 0110
# raw key value: 0000 1001 10 00: 46
# pcs key: 1001
# raw key value: 0000 1111 00 11: 42
# pcs key: 1111
# raw key value: 0000 0011 00 00: 76
# pcs key: 0011
# raw key value: 0000 1111 10 10: 50
# pcs key: 1111
# raw key value: 0000 1001 11 11: 52
# pcs key: 1001
# raw key value: 0000 1011 01 10: 69
# pcs key: 1011
# raw key value: 0000 0101 11 00: 80
# pcs key: 0101
# raw key value: 0000 0010 00 00: 122
# pcs key: 0010
# raw key value: 0000 0000 10 11: 190
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140, '0000 0000 01 11': 186, '0000 0000 01 01': 152, '0000 0000 01 00': 202, '0000 0000 00 11': 210, '0000 0000 10 11': 190}
# raw key value: 0000 0000 10 10: 135
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140, '0000 0000 01 11': 186, '0000 0000 01 01': 152, '0000 0000 01 00': 202, '0000 0000 00 11': 210, '0000 0000 10 11': 190, '0000 0000 10 10': 135}
# raw key value: 0000 0001 11 10: 113
# pcs key: 0001
# raw key value: 0000 1000 10 00: 91
# pcs key: 1000
# raw key value: 0000 1000 00 11: 89
# pcs key: 1000
# raw key value: 0000 0110 10 10: 62
# pcs key: 0110
# raw key value: 0000 1111 10 01: 42
# pcs key: 1111
# raw key value: 0000 0110 11 10: 63
# pcs key: 0110
# raw key value: 0000 1101 10 10: 45
# pcs key: 1101
# raw key value: 0000 0010 11 11: 111
# pcs key: 0010
# raw key value: 0000 0011 00 01: 64
# pcs key: 0011
# raw key value: 0000 1101 01 10: 63
# pcs key: 1101
# raw key value: 0000 1101 00 01: 34
# pcs key: 1101
# raw key value: 0000 1100 11 00: 51
# pcs key: 1100
# raw key value: 0000 1110 00 01: 49
# pcs key: 1110
# raw key value: 0000 0100 00 10: 94
# pcs key: 0100
# raw key value: 0000 0010 10 00: 108
# pcs key: 0010
# raw key value: 0000 0010 00 10: 134
# pcs key: 0010
# raw key value: 0000 0011 11 10: 95
# pcs key: 0011
# raw key value: 0000 0101 01 01: 109
# pcs key: 0101
# raw key value: 0000 0110 00 10: 60
# pcs key: 0110
# raw key value: 0000 1001 00 10: 64
# pcs key: 1001
# raw key value: 0000 0110 10 11: 62
# pcs key: 0110
# raw key value: 0000 0100 10 01: 79
# pcs key: 0100
# raw key value: 0000 0001 10 11: 105
# pcs key: 0001
# raw key value: 0000 0000 11 10: 149
# pcs key: 0000
# filtered results: {'0000 0000 11 00': 165, '0000 0000 01 10': 148, '0000 0000 11 11': 186, '0000 0000 11 01': 124, '0000 0000 10 01': 172, '0000 0000 10 00': 207, '0000 0000 00 01': 130, '0000 0000 00 00': 197, '0000 0000 00 10': 140, '0000 0000 01 11': 186, '0000 0000 01 01': 152, '0000 0000 01 00': 202, '0000 0000 00 11': 210, '0000 0000 10 11': 190, '0000 0000 10 10': 135, '0000 0000 11 10': 149}
# raw key value: 0000 1001 10 11: 49
# pcs key: 1001
# raw key value: 0000 0110 10 00: 50
# pcs key: 0110
# raw key value: 0000 1010 00 11: 86
# pcs key: 1010
# raw key value: 0000 0110 01 00: 56
# pcs key: 0110
# raw key value: 0000 0001 01 10: 127
# pcs key: 0001
# raw key value: 0000 1010 01 01: 108
# pcs key: 1010
# raw key value: 0000 1111 01 01: 42
# pcs key: 1111
# raw key value: 0000 1000 10 10: 62
# pcs key: 1000
# raw key value: 0000 0110 01 01: 52
# pcs key: 0110
# raw key value: 0000 1100 00 01: 40
# pcs key: 1100
# raw key value: 0000 1110 11 00: 39
# pcs key: 1110
# raw key value: 0000 0011 01 11: 94
# pcs key: 0011
# raw key value: 0000 1110 11 11: 32
# pcs key: 1110
# raw key value: 0000 1100 01 00: 44
# pcs key: 1100
# raw key value: 0000 1111 11 11: 58
# pcs key: 1111
# raw key value: 0000 1110 01 10: 38
# pcs key: 1110
# raw key value: 0000 1100 11 01: 44
# pcs key: 1100
# raw key value: 0000 1001 01 10: 66
# pcs key: 1001
# raw key value: 0000 0011 10 00: 84
# pcs key: 0011
# raw key value: 0000 0110 11 00: 59
# pcs key: 0110
# raw key value: 0000 1110 00 10: 42
# pcs key: 1110
# raw key value: 0000 0001 01 00: 112
# pcs key: 0001
# raw key value: 0000 1110 10 11: 42
# pcs key: 1110
# raw key value: 0000 1100 00 00: 43
# pcs key: 1100
# raw key value: 0000 1001 00 01: 61
# pcs key: 1001
# raw key value: 0000 0001 10 00: 121
# pcs key: 0001
# raw key value: 0000 1110 10 00: 40
# pcs key: 1110
# raw key value: 0000 1101 11 00: 45
# pcs key: 1101
# raw key value: 0000 1111 01 10: 55
# pcs key: 1111
# raw key value: 0000 1001 01 01: 58
# pcs key: 1001
# raw key value: 0000 1111 01 00: 36
# pcs key: 1111
# raw key value: 0000 1011 00 01: 73
# pcs key: 1011
# raw key value: 0000 0101 11 01: 75
# pcs key: 0101
# raw key value: 0000 1000 00 10: 92
# pcs key: 1000
# raw key value: 0000 0110 10 01: 47
# pcs key: 0110
# raw key value: 0000 0001 00 01: 116
# pcs key: 0001
# raw key value: 0000 0101 10 00: 80
# pcs key: 0101
# raw key value: 0000 1111 11 00: 44
# pcs key: 1111
# raw key value: 0000 1000 10 01: 72
# pcs key: 1000
# raw key value: 0000 1101 01 00: 45
# pcs key: 1101
# raw key value: 0000 0100 00 01: 68
# pcs key: 0100
# raw key value: 0000 0111 11 01: 56
# pcs key: 0111
# raw key value: 0000 1111 01 11: 44
# pcs key: 1111
# raw key value: 0000 1101 10 00: 46
# pcs key: 1101
# raw key value: 0000 1010 01 00: 68
# pcs key: 1010
# raw key value: 0000 0011 10 01: 76
# pcs key: 0011
# raw key value: 0000 1011 01 01: 53
# pcs key: 1011
# raw key value: 0000 0110 11 01: 59
# pcs key: 0110
# raw key value: 0000 1101 10 01: 50
# pcs key: 1101
# raw key value: 0000 1110 01 00: 43
# pcs key: 1110
# raw key value: 0000 1100 11 11: 61
# pcs key: 1100
# raw key value: 0000 1110 11 01: 51
# pcs key: 1110
# raw key value: 0000 1100 01 10: 39
# pcs key: 1100
# raw key value: 0000 0111 00 10: 56
# pcs key: 0111
# raw key value: 0000 1011 00 10: 56
# pcs key: 1011
# raw key value: 0000 0110 01 10: 64
# pcs key: 0110
# raw key value: 0000 1101 11 01: 47
# pcs key: 1101
# raw key value: 0000 1101 00 00: 40
# pcs key: 1101
# raw key value: 0000 1101 10 11: 36
# pcs key: 1101
# raw key value: 0000 1110 10 01: 51
# pcs key: 1110
# raw key value: 0000 1111 00 10: 48
# pcs key: 1111
# raw key value: 0000 0110 01 11: 47
# pcs key: 0110
# raw key value: 0000 1101 01 01: 64
# pcs key: 1101
# raw key value: 0000 1101 11 11: 44
# pcs key: 1101
# raw key value: 0000 1101 01 11: 36
# pcs key: 1101
# collected vals:  {'01': 649, '11': 732, '10': 658, '00': 706}
# collected vals:  {'00': 667, '11': 660, '01': 768, '10': 722}
# collected vals:  {'00': 771, '10': 572, '11': 772, '01': 578}
# 0.312880002618912

# %%
print(pcs_fidelity)
print(pcs_post_select_rates)
# reps=2
with open(f"json\\graph_pcsXZ_flyingq_unbiased.json", "w") as fxz:
        json.dump({"errors": errors.tolist(), "fidelities": pcs_all_fidelities, "postselectRates": pcs_post_select_rates}, fxz)
with open("json\\raw_unbiased.json") as fRaw:
        dataRaw=json.load(fRaw)
nopcs_all_fidelities=dataRaw["fidelities"]
plt.plot(errors, pcs_all_fidelities, label="PCS X&Z Fidelity", marker='o')
plt.plot(errors, nopcs_all_fidelities, label="No PCS Fidelity", marker='o')
plt.plot(errors, pcs_post_select_rates, label="PCS X&Z Postselection rate",  marker='^', linestyle="--")
plt.ylabel('Probability')
plt.xlabel(f"Depolarizing Error Rate")
plt.text(0.25, .75, f"Single qubit gate error: {error_gate1}\nTwo qubit gate error: {round(error_gate1*10, 4)}", color = "red")
plt.title(f"Entanglement Swapping: PCS X&Z on Flying Qubits")
plt.legend()
plt.savefig(f"images\\graph_pcsXZ_flyingq_equal_depol.png")
plt.show()
# Out:
# 0.312880002618912
# [0.9363, 0.76255, 0.62415, 0.5108, 0.41705, 0.34425, 0.2811, 0.23355, 0.1946, 0.1609, 0.13465]
