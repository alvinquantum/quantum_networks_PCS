# %%
#!/usr/bin/env python3
import qiskit
from qiskit import (
    QuantumCircuit,
    QuantumRegister,
    ClassicalRegister,
    transpile
)
from qiskit.quantum_info import (
    Kraus, 
    SuperOp,
)
from qiskit_aer.noise import(
    depolarizing_error,
    phase_damping_error,
    NoiseModel,
    QuantumError,
    amplitude_damping_error,
)
# from qiskit_ibm_provider import IBMProvider
from qiskit import Aer
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np
import math
import sys
sys.path.append('../')
import utilities as utl
import importlib
import json
importlib.reload(utl)

SHOTS=40000
def _graph_pcsZ(qc, qreg):
    for idx in list(range(qreg.size)):
        if idx==1:
            continue
        qc.h(qreg[idx])
    qc.cz(qreg[2],qreg[0])
    qc.cx(qreg[0],qreg[1])
    qc.cx(qreg[3],qreg[0])
    qc.barrier()
    qc.id(qreg)
    qc.barrier()
    qc.cx(qreg[3],qreg[0])
    qc.cz(qreg[2],qreg[0])
    qc.h([qreg[3], qreg[2]])
    return qc

# %%
tot_pcs_ancillas=4
a_qreg=QuantumRegister(4, "a")
b_qreg=QuantumRegister(4, "b")
pcs_creg=ClassicalRegister(4,"pcs")
bsm_creg=ClassicalRegister(2, "bsm")
epr_creg=ClassicalRegister(2, "epr")
junk_creg=ClassicalRegister(4, "junk") #for removing and connecting nodes
qc=QuantumCircuit(a_qreg, b_qreg, epr_creg, bsm_creg, pcs_creg, junk_creg)
qc=_graph_pcsZ(qc, a_qreg)
qc=_graph_pcsZ(qc, b_qreg)
# # x and z measurement to connect and remove nodes, respectively.
# qc.barrier()
# qc.measure(a_qreg[2], junk_creg[0])
# qc.measure(b_qreg[2], junk_creg[1])
# qc.measure(a_qreg[4], junk_creg[2])
# qc.measure(b_qreg[4], junk_creg[3])

# PCS measurements.
qc.barrier()
qc.measure(a_qreg[2], pcs_creg[0])
qc.measure(b_qreg[2], pcs_creg[1])
qc.measure(a_qreg[3], pcs_creg[2])
qc.measure(b_qreg[3], pcs_creg[3])
# Convert 2 qubit graph states to bell States.
# qc.h(a_qreg[0])
# qc.h(b_qreg[0])

#BSM measurement.
qc.barrier()
qc.cx(a_qreg[1], b_qreg[1])
qc.h(a_qreg[1])
qc.measure(a_qreg[1], bsm_creg[0])
qc.measure(b_qreg[1], bsm_creg[1])
utl._add_fixing_gates(qc, a_qreg, bsm_creg, 0)
qc.draw(fold=-1)
# Out:
#         ┌───┐        ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░                 ░              ░               ░ ┌────────── ┌──────────── ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐
#    a_0: ┤ H ├─■───■──┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░─────────────────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─
#         └───┘ │ ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░                 ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘
#    a_1: ──────┼─┤ X ├──┼───░─┤ I ├─░───┼────┼─────────────░───────░─────────────────░──────────────░───■──┤ H ├┤M├─░──────╫──────────────────────────────────────────────────────────────────────────────
#         ┌───┐ │ └───┘  │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░                 ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║
#    a_2: ┤ H ├─■────────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░─────────────────░─┤M├──────────░───┼────────╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░                 ░ └╥┘   ┌─┐    ░   │        ║  ░      ║
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░─────────────────░──╫────┤M├────░───┼────────╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#         └───┘              ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐           ░  ║    └╥┘    ░   │        ║  ░      ║
#    b_0: ───────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■────────░──╫─────╫─────░───┼────────╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ └───┘  │  ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │        ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║
#    b_1: ───────────────────░───────░────────┼──┤ X ├──┼───░─┤ I ├─░───┼────┼────────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ ┌───┐  │  └───┘  │   ░ ├───┤ ░   │    │  ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║
#    b_2: ───────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐└───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘      ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║
#  epr: 2/═══════════════════════════════════════════════════════════════════════════════╬══╬══╬══╬═══════════╬═══╬═════════╬══════════════════════════════════════════════════════════════════════════════
#                                                                                        ║  ║  ║  ║           ║   ║      ┌──╨──┐
#  bsm: 2/═══════════════════════════════════════════════════════════════════════════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═══════════════════════════════════════════════════════════════════════════
#                                                                                        ║  ║  ║  ║           1   0      └─────┘
#  pcs: 4/═══════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩════════════════════════════════════════════════════════════════════════════════════════════════════════
#                                                                                        0  1  2  3
# junk: 4/═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════

# %%
pcs_all_fidelities=[]
pcs_post_select_rates=[]
errors=np.linspace(0.0, stop=0.5, num=11, endpoint=True)
error_gate1=0.001
for error in errors:
        noise_model=utl.get_noise_model(error_gate1)
        print(f"depolarizing error: {error}")
        depol1=depolarizing_error(error, 1)
        noise_model.add_all_qubit_quantum_error(depol1, ["id"])
        print(noise_model)

        backend=AerSimulator(noise_model=noise_model)
        pcs_ancillas_pos=1 # the position of the classical registers that contain the pcs measurements.
        result_xx=utl.meas_xx(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_yy=utl.meas_yy(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_zz=utl.meas_zz(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)

        xx_counts=utl.post_select(result_xx.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        yy_counts=utl.post_select(result_yy.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        zz_counts=utl.post_select(result_zz.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        pcs_post_select_rates.append(min([sum(xx_counts.values()),sum(yy_counts.values()),sum(zz_counts.values())])/SHOTS)
        epr_idx=-1 #the position of the classical registers that contain measurements of the 
                #epr pair.
        expect_xx=utl.expect_of_vals(utl.to_percent(utl.collect_meas(xx_counts, epr_idx)))
        expect_yy=utl.expect_of_vals(utl.to_percent(utl.collect_meas(yy_counts, epr_idx)))
        expect_zz=utl.expect_of_vals(utl.to_percent(utl.collect_meas(zz_counts, epr_idx)))
        pcs_fidelity=utl.fidelity_phip(expect_xx, expect_yy, expect_zz)
        print(pcs_fidelity)
        pcs_all_fidelities.append(pcs_fidelity)
# Out:
# depolarizing error: 0.0
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cz', 'rz', 'measure', 'ccx', 'cx', 'y', 'h', 'x', 'z']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure']
# xx circ:
#         ┌───┐        ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░           »
#    a_0: ┤ H ├─■───■──┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         └───┘ │ ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░           »
#    a_1: ──────┼─┤ X ├──┼───░─┤ I ├─░───┼────┼─────────────░───────░───────────»
#         ┌───┐ │ └───┘  │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■────────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘              ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐     »
#    b_0: ───────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                            ░       ░ └───┘  │  ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_1: ───────────────────░───────░────────┼──┤ X ├──┼───░─┤ I ├─░───┼────┼──»
#                            ░       ░ ┌───┐  │  └───┘  │   ░ ├───┤ ░   │    │  »
#    b_2: ───────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  bsm: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  pcs: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# junk: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «              ░              ░               ░ ┌────────── ┌──────────── ┌───┐»
# «   a_0: ──────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├»
# «              ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘»
# «   a_1: ──────░──────────────░───■──┤ H ├┤M├─░──────╫─────────────────────────»
# «              ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║                         »
# «   a_2: ──────░─┤M├──────────░───┼────────╫──░──────╫─────────────────────────»
# «              ░ └╥┘   ┌─┐    ░   │        ║  ░      ║                         »
# «   a_3: ──────░──╫────┤M├────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║    └╥┘    ░   │        ║  ░      ║                         »
# «   b_0: ──────░──╫─────╫─────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                         »
# «   b_1: ──────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫─────────────────────────»
# «        ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║                         »
# «   b_2: ┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫─────────────────────────»
# «        └───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║                         »
# «   b_3: ──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫─────────────────────────»
# «              ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║                         »
# « epr: 2/═════════╬══╬══╬══╬═══════════╬═══╬═════════╬═════════════════════════»
# «                 ║  ║  ║  ║           ║   ║      ┌──╨──┐                      »
# « bsm: 2/═════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞══════════════════════»
# «                 ║  ║  ║  ║           1   0      └─────┘                      »
# « pcs: 4/═════════╩══╩══╩══╩═══════════════════════════════════════════════════»
# «                 0  1  2  3                                                   »
# «junk: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐   ┌─┐
# «   a_0: ┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ H ├───┤M├
# «        └──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘   └╥┘
# «   a_1: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_2: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_3: ──────────────────────────────────────────────────────────────╫─
# «                                                             ┌───┐┌─┐ ║
# «   b_0: ─────────────────────────────────────────────────────┤ H ├┤M├─╫─
# «                                                             └───┘└╥┘ ║
# «   b_1: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_2: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_3: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# « epr: 2/═══════════════════════════════════════════════════════════╩══╩═
# «                                                                   1  0
# « bsm: 2/════════════════════════════════════════════════════════════════
# «
# « pcs: 4/════════════════════════════════════════════════════════════════
# «
# «junk: 4/════════════════════════════════════════════════════════════════
# «
# xx circ:  OrderedDict([('h', 13), ('id', 8), ('measure', 8), ('cx', 7), ('barrier', 7), ('cz', 4), ('switch_case', 1)])
# yy circ:
#         ┌───┐        ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░           »
#    a_0: ┤ H ├─■───■──┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         └───┘ │ ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░           »
#    a_1: ──────┼─┤ X ├──┼───░─┤ I ├─░───┼────┼─────────────░───────░───────────»
#         ┌───┐ │ └───┘  │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■────────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘              ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐     »
#    b_0: ───────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                            ░       ░ └───┘  │  ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_1: ───────────────────░───────░────────┼──┤ X ├──┼───░─┤ I ├─░───┼────┼──»
#                            ░       ░ ┌───┐  │  └───┘  │   ░ ├───┤ ░   │    │  »
#    b_2: ───────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  bsm: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  pcs: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# junk: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «              ░              ░               ░ ┌────────── ┌──────────── ┌───┐»
# «   a_0: ──────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├»
# «              ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘»
# «   a_1: ──────░──────────────░───■──┤ H ├┤M├─░──────╫─────────────────────────»
# «              ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║                         »
# «   a_2: ──────░─┤M├──────────░───┼────────╫──░──────╫─────────────────────────»
# «              ░ └╥┘   ┌─┐    ░   │        ║  ░      ║                         »
# «   a_3: ──────░──╫────┤M├────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║    └╥┘    ░   │        ║  ░      ║                         »
# «   b_0: ──────░──╫─────╫─────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                         »
# «   b_1: ──────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫─────────────────────────»
# «        ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║                         »
# «   b_2: ┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫─────────────────────────»
# «        └───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║                         »
# «   b_3: ──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫─────────────────────────»
# «              ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║                         »
# « epr: 2/═════════╬══╬══╬══╬═══════════╬═══╬═════════╬═════════════════════════»
# «                 ║  ║  ║  ║           ║   ║      ┌──╨──┐                      »
# « bsm: 2/═════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞══════════════════════»
# «                 ║  ║  ║  ║           1   0      └─────┘                      »
# « pcs: 4/═════════╩══╩══╩══╩═══════════════════════════════════════════════════»
# «                 0  1  2  3                                                   »
# «junk: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐┌───┐   ┌─┐
# «   a_0: ┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ S ├┤ H ├───┤M├
# «        └──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘└───┘   └╥┘
# «   a_1: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_2: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_3: ───────────────────────────────────────────────────────────────────╫─
# «                                                             ┌───┐┌───┐┌─┐ ║
# «   b_0: ─────────────────────────────────────────────────────┤ S ├┤ H ├┤M├─╫─
# «                                                             └───┘└───┘└╥┘ ║
# «   b_1: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_2: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_3: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# « epr: 2/════════════════════════════════════════════════════════════════╩══╩═
# «                                                                        1  0
# « bsm: 2/═════════════════════════════════════════════════════════════════════
# «
# « pcs: 4/═════════════════════════════════════════════════════════════════════
# «
# «junk: 4/═════════════════════════════════════════════════════════════════════
# «
# yy circ:  OrderedDict([('h', 13), ('id', 8), ('measure', 8), ('cx', 7), ('barrier', 7), ('cz', 4), ('s', 2), ('switch_case', 1)])
# zz circ:
#         ┌───┐        ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░           »
#    a_0: ┤ H ├─■───■──┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         └───┘ │ ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░           »
#    a_1: ──────┼─┤ X ├──┼───░─┤ I ├─░───┼────┼─────────────░───────░───────────»
#         ┌───┐ │ └───┘  │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■────────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘              ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐     »
#    b_0: ───────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                            ░       ░ └───┘  │  ┌─┴─┐└─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_1: ───────────────────░───────░────────┼──┤ X ├──┼───░─┤ I ├─░───┼────┼──»
#                            ░       ░ ┌───┐  │  └───┘  │   ░ ├───┤ ░   │    │  »
#    b_2: ───────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  bsm: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  pcs: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# junk: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «              ░              ░               ░ ┌────────── ┌──────────── ┌───┐»
# «   a_0: ──────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├»
# «              ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘»
# «   a_1: ──────░──────────────░───■──┤ H ├┤M├─░──────╫─────────────────────────»
# «              ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║                         »
# «   a_2: ──────░─┤M├──────────░───┼────────╫──░──────╫─────────────────────────»
# «              ░ └╥┘   ┌─┐    ░   │        ║  ░      ║                         »
# «   a_3: ──────░──╫────┤M├────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║    └╥┘    ░   │        ║  ░      ║                         »
# «   b_0: ──────░──╫─────╫─────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                         »
# «   b_1: ──────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫─────────────────────────»
# «        ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║                         »
# «   b_2: ┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫─────────────────────────»
# «        └───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║                         »
# «   b_3: ──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫─────────────────────────»
# «              ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║                         »
# « epr: 2/═════════╬══╬══╬══╬═══════════╬═══╬═════════╬═════════════════════════»
# «                 ║  ║  ║  ║           ║   ║      ┌──╨──┐                      »
# « bsm: 2/═════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞══════════════════════»
# «                 ║  ║  ║  ║           1   0      └─────┘                      »
# « pcs: 4/═════════╩══╩══╩══╩═══════════════════════════════════════════════════»
# «                 0  1  2  3                                                   »
# «junk: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐    ┌─┐
# «   a_0: ┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├────┤M├
# «        └──────────── └───┘└──────────── └───┘└───┘ ───────┘    └╥┘
# «   a_1: ─────────────────────────────────────────────────────────╫─
# «                                                                 ║
# «   a_2: ─────────────────────────────────────────────────────────╫─
# «                                                                 ║
# «   a_3: ─────────────────────────────────────────────────────────╫─
# «                                                             ┌─┐ ║
# «   b_0: ─────────────────────────────────────────────────────┤M├─╫─
# «                                                             └╥┘ ║
# «   b_1: ──────────────────────────────────────────────────────╫──╫─
# «                                                              ║  ║
# «   b_2: ──────────────────────────────────────────────────────╫──╫─
# «                                                              ║  ║
# «   b_3: ──────────────────────────────────────────────────────╫──╫─
# «                                                              ║  ║
# « epr: 2/══════════════════════════════════════════════════════╩══╩═
# «                                                              1  0
# « bsm: 2/═══════════════════════════════════════════════════════════
# «
# « pcs: 4/═══════════════════════════════════════════════════════════
# «
# «junk: 4/═══════════════════════════════════════════════════════════
# «
# zz circ:  OrderedDict([('h', 11), ('id', 8), ('measure', 8), ('cx', 7), ('barrier', 7), ('cz', 4), ('switch_case', 1)])
# raw key value: 0000 0011 01 00: 2
# pcs key: 0011
# raw key value: 0000 0010 11 00: 51
# pcs key: 0010
# raw key value: 0000 0000 00 11: 4465
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465}
# raw key value: 0000 0011 11 01: 1
# pcs key: 0011
# raw key value: 0000 0010 00 11: 47
# pcs key: 0010
# raw key value: 0000 0000 11 00: 4497
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497}
# raw key value: 0000 0000 11 11: 4609
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609}
# raw key value: 0000 0000 00 00: 4532
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532}
# raw key value: 0000 1010 10 01: 16
# pcs key: 1010
# raw key value: 0000 1010 00 01: 9
# pcs key: 1010
# raw key value: 0000 0000 10 00: 4599
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599}
# raw key value: 0000 0100 00 10: 15
# pcs key: 0100
# raw key value: 0000 0000 01 00: 4540
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540}
# raw key value: 0000 0010 01 11: 56
# pcs key: 0010
# raw key value: 0000 0100 11 01: 15
# pcs key: 0100
# raw key value: 0000 0000 10 11: 4546
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546}
# raw key value: 0000 0000 01 11: 4672
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672}
# raw key value: 0000 0011 11 11: 3
# pcs key: 0011
# raw key value: 0000 0010 00 01: 43
# pcs key: 0010
# raw key value: 0000 0000 10 10: 135
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135}
# raw key value: 0000 1011 00 01: 2
# pcs key: 1011
# raw key value: 0000 0101 11 01: 13
# pcs key: 0101
# raw key value: 0000 1000 00 11: 18
# pcs key: 1000
# raw key value: 0000 0011 00 10: 1
# pcs key: 0011
# raw key value: 0000 0010 11 10: 33
# pcs key: 0010
# raw key value: 0000 0000 01 01: 116
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135, '0000 0000 01 01': 116}
# raw key value: 0000 0011 01 01: 2
# pcs key: 0011
# raw key value: 0000 0010 10 11: 59
# pcs key: 0010
# raw key value: 0000 0000 00 10: 104
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135, '0000 0000 01 01': 116, '0000 0000 00 10': 104}
# raw key value: 0000 0111 11 10: 2
# pcs key: 0111
# raw key value: 0000 0100 00 00: 16
# pcs key: 0100
# raw key value: 0000 0000 01 10: 151
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135, '0000 0000 01 01': 116, '0000 0000 00 10': 104, '0000 0000 01 10': 151}
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0010 11 11: 45
# pcs key: 0010
# raw key value: 0000 0010 00 00: 63
# pcs key: 0010
# raw key value: 0000 0001 00 01: 43
# pcs key: 0001
# raw key value: 0000 0010 10 00: 67
# pcs key: 0010
# raw key value: 0000 1010 10 10: 9
# pcs key: 1010
# raw key value: 0000 0011 11 00: 1
# pcs key: 0011
# raw key value: 0000 0010 01 00: 72
# pcs key: 0010
# raw key value: 0000 0000 11 01: 126
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135, '0000 0000 01 01': 116, '0000 0000 00 10': 104, '0000 0000 01 10': 151, '0000 0000 11 01': 126}
# raw key value: 0000 0011 10 11: 1
# pcs key: 0011
# raw key value: 0000 0010 01 01: 45
# pcs key: 0010
# raw key value: 0000 0000 11 10: 141
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135, '0000 0000 01 01': 116, '0000 0000 00 10': 104, '0000 0000 01 10': 151, '0000 0000 11 01': 126, '0000 0000 11 10': 141}
# raw key value: 0000 1010 00 00: 10
# pcs key: 1010
# raw key value: 0000 0000 10 01: 147
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135, '0000 0000 01 01': 116, '0000 0000 00 10': 104, '0000 0000 01 10': 151, '0000 0000 11 01': 126, '0000 0000 11 10': 141, '0000 0000 10 01': 147}
# raw key value: 0000 0100 01 11: 18
# pcs key: 0100
# raw key value: 0000 0010 10 10: 51
# pcs key: 0010
# raw key value: 0000 1010 10 00: 6
# pcs key: 1010
# raw key value: 0000 0000 00 01: 124
# pcs key: 0000
# filtered results: {'0000 0000 00 11': 4465, '0000 0000 11 00': 4497, '0000 0000 11 11': 4609, '0000 0000 00 00': 4532, '0000 0000 10 00': 4599, '0000 0000 01 00': 4540, '0000 0000 10 11': 4546, '0000 0000 01 11': 4672, '0000 0000 10 10': 135, '0000 0000 01 01': 116, '0000 0000 00 10': 104, '0000 0000 01 10': 151, '0000 0000 11 01': 126, '0000 0000 11 10': 141, '0000 0000 10 01': 147, '0000 0000 00 01': 124}
# raw key value: 0000 1010 01 10: 10
# pcs key: 1010
# raw key value: 0000 0001 11 11: 52
# pcs key: 0001
# raw key value: 0000 0001 11 01: 46
# pcs key: 0001
# raw key value: 0000 0001 01 10: 53
# pcs key: 0001
# raw key value: 0000 0100 10 00: 18
# pcs key: 0100
# raw key value: 0000 0010 10 01: 42
# pcs key: 0010
# raw key value: 0000 1000 01 10: 16
# pcs key: 1000
# raw key value: 0000 0001 01 00: 46
# pcs key: 0001
# raw key value: 0000 0101 10 00: 12
# pcs key: 0101
# raw key value: 0000 0001 01 11: 52
# pcs key: 0001
# raw key value: 0000 0001 00 11: 53
# pcs key: 0001
# raw key value: 0000 0101 00 00: 12
# pcs key: 0101
# raw key value: 0000 1000 10 00: 21
# pcs key: 1000
# raw key value: 0000 0101 11 00: 13
# pcs key: 0101
# raw key value: 0000 0001 10 11: 49
# pcs key: 0001
# raw key value: 0000 0001 00 00: 57
# pcs key: 0001
# raw key value: 0000 1000 11 11: 23
# pcs key: 1000
# raw key value: 0000 1010 00 11: 19
# pcs key: 1010
# raw key value: 0000 1000 10 10: 13
# pcs key: 1000
# raw key value: 0000 0001 10 10: 42
# pcs key: 0001
# raw key value: 0000 0101 10 11: 6
# pcs key: 0101
# raw key value: 0000 0101 10 01: 12
# pcs key: 0101
# raw key value: 0000 1000 01 11: 25
# pcs key: 1000
# raw key value: 0000 1000 00 10: 15
# pcs key: 1000
# raw key value: 0000 0001 10 00: 52
# pcs key: 0001
# raw key value: 0000 1000 00 00: 22
# pcs key: 1000
# raw key value: 0000 1010 11 01: 7
# pcs key: 1010
# raw key value: 0000 0001 00 10: 43
# pcs key: 0001
# raw key value: 0000 0101 11 10: 16
# pcs key: 0101
# raw key value: 0000 0101 11 11: 12
# pcs key: 0101
# raw key value: 0000 0101 00 10: 15
# pcs key: 0101
# raw key value: 0000 0101 01 01: 10
# pcs key: 0101
# raw key value: 0000 0100 01 10: 10
# pcs key: 0100
# raw key value: 0000 0010 01 10: 42
# pcs key: 0010
# raw key value: 0000 0100 11 11: 15
# pcs key: 0100
# raw key value: 0000 1000 00 01: 10
# pcs key: 1000
# raw key value: 0000 0011 11 10: 2
# pcs key: 0011
# raw key value: 0000 0010 00 10: 44
# pcs key: 0010
# raw key value: 0000 0100 00 11: 17
# pcs key: 0100
# raw key value: 0000 0011 00 11: 1
# pcs key: 0011
# raw key value: 0000 0010 11 01: 46
# pcs key: 0010
# raw key value: 0000 0100 10 01: 13
# pcs key: 0100
# raw key value: 0000 0101 00 01: 17
# pcs key: 0101
# raw key value: 0000 1010 11 11: 11
# pcs key: 1010
# raw key value: 0000 0001 10 01: 53
# pcs key: 0001
# raw key value: 0000 1000 01 00: 16
# pcs key: 1000
# raw key value: 0000 1000 10 11: 12
# pcs key: 1000
# raw key value: 0000 0001 11 10: 55
# pcs key: 0001
# raw key value: 0000 0111 00 00: 1
# pcs key: 0111
# raw key value: 0000 0100 11 10: 11
# pcs key: 0100
# raw key value: 0000 1101 11 11: 1
# pcs key: 1101
# raw key value: 0000 0111 01 11: 1
# pcs key: 0111
# raw key value: 0000 0100 10 11: 18
# pcs key: 0100
# raw key value: 0000 0001 11 00: 48
# pcs key: 0001
# raw key value: 0000 1011 11 11: 1
# pcs key: 1011
# raw key value: 0000 0101 00 11: 18
# pcs key: 0101
# raw key value: 0000 0001 01 01: 44
# pcs key: 0001
# raw key value: 0000 0101 10 10: 10
# pcs key: 0101
# raw key value: 0000 1000 11 00: 15
# pcs key: 1000
# raw key value: 0000 1010 01 00: 12
# pcs key: 1010
# raw key value: 0000 1000 10 01: 17
# pcs key: 1000
# raw key value: 0000 0100 01 01: 17
# pcs key: 0100
# raw key value: 0000 1101 10 10: 1
# pcs key: 1101
# raw key value: 0000 1000 11 10: 10
# pcs key: 1000
# raw key value: 0000 1010 10 11: 17
# pcs key: 1010
# raw key value: 0000 1011 10 11: 1
# pcs key: 1011
# raw key value: 0000 0101 01 11: 13
# pcs key: 0101
# raw key value: 0000 1010 01 11: 13
# pcs key: 1010
# raw key value: 0000 0100 00 01: 11
# pcs key: 0100
# raw key value: 0000 1101 11 00: 1
# pcs key: 1101
# raw key value: 0000 0100 10 10: 7
# pcs key: 0100
# raw key value: 0000 1010 00 10: 15
# pcs key: 1010
# raw key value: 0000 1000 11 01: 12
# pcs key: 1000
# raw key value: 0000 1000 01 01: 10
# pcs key: 1000
# raw key value: 0000 0110 01 10: 1
# pcs key: 0110
# raw key value: 0000 0100 11 00: 19
# pcs key: 0100
# raw key value: 0000 1010 11 10: 8
# pcs key: 1010
# raw key value: 0000 1010 11 00: 10
# pcs key: 1010
# raw key value: 0000 0101 01 00: 10
# pcs key: 0101
# raw key value: 0000 1100 00 11: 1
# pcs key: 1100
# raw key value: 0000 0100 01 00: 10
# pcs key: 0100
# raw key value: 0000 1010 01 01: 8
# pcs key: 1010
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 0011 00 00: 4
# pcs key: 0011
# raw key value: 0000 1001 11 00: 1
# pcs key: 1001
# raw key value: 0000 0011 01 11: 1
# pcs key: 0011
# raw key value: 0000 1011 00 10: 1
# pcs key: 1011
# raw key value: 0000 1111 11 00: 1
# pcs key: 1111
# raw key value: 0000 1100 10 00: 1
# pcs key: 1100
# raw key value: 0000 0101 01 10: 5
# pcs key: 0101
# raw key value: 0000 0110 01 01: 1
# pcs key: 0110
# raw key value: 0000 1101 01 11: 1
# pcs key: 1101
# raw key value: 0000 0110 11 10: 1
# pcs key: 0110
# raw key value: 0000 0111 00 10: 1
# pcs key: 0111
# raw key value: 0000 0110 11 11: 1
# pcs key: 0110
# raw key value: 0000 0001 11 01: 58
# pcs key: 0001
# raw key value: 0000 0011 00 10: 1
# pcs key: 0011
# raw key value: 0000 0010 11 10: 42
# pcs key: 0010
# raw key value: 0000 0000 01 01: 4581
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581}
# raw key value: 0000 0011 11 10: 1
# pcs key: 0011
# raw key value: 0000 0010 00 10: 46
# pcs key: 0010
# raw key value: 0000 0000 10 11: 152
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152}
# raw key value: 0000 0010 10 11: 47
# pcs key: 0010
# raw key value: 0000 0000 00 10: 4511
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511}
# raw key value: 0000 0010 01 00: 42
# pcs key: 0010
# raw key value: 0000 0000 11 01: 4581
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581}
# raw key value: 0000 1001 00 00: 1
# pcs key: 1001
# raw key value: 0000 0010 00 01: 69
# pcs key: 0010
# raw key value: 0000 0000 10 10: 4417
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417}
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 50
# pcs key: 0010
# raw key value: 0000 0100 01 11: 10
# pcs key: 0100
# raw key value: 0000 1010 10 00: 10
# pcs key: 1010
# raw key value: 0000 0000 00 01: 4523
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523}
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0010 11 11: 47
# pcs key: 0010
# raw key value: 0000 0000 01 10: 4675
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675}
# raw key value: 0000 0010 01 01: 48
# pcs key: 0010
# raw key value: 0000 0000 11 10: 4517
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517}
# raw key value: 0000 1010 00 00: 17
# pcs key: 1010
# raw key value: 0000 0000 10 01: 4672
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672}
# raw key value: 0000 0001 00 11: 38
# pcs key: 0001
# raw key value: 0000 0001 11 11: 39
# pcs key: 0001
# raw key value: 0000 0001 10 11: 47
# pcs key: 0001
# raw key value: 0000 1000 10 01: 16
# pcs key: 1000
# raw key value: 0000 1000 11 10: 16
# pcs key: 1000
# raw key value: 0000 0001 10 00: 44
# pcs key: 0001
# raw key value: 0000 1000 10 10: 22
# pcs key: 1000
# raw key value: 0000 0010 11 01: 56
# pcs key: 0010
# raw key value: 0000 0000 01 00: 132
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672, '0000 0000 01 00': 132}
# raw key value: 0000 0100 00 10: 23
# pcs key: 0100
# raw key value: 0000 0000 00 11: 130
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672, '0000 0000 01 00': 132, '0000 0000 00 11': 130}
# raw key value: 0000 0011 01 00: 1
# pcs key: 0011
# raw key value: 0000 0010 11 00: 44
# pcs key: 0010
# raw key value: 0000 0010 00 00: 54
# pcs key: 0010
# raw key value: 0000 0100 00 01: 16
# pcs key: 0100
# raw key value: 0000 0000 01 11: 152
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672, '0000 0000 01 00': 132, '0000 0000 00 11': 130, '0000 0000 01 11': 152}
# raw key value: 0000 0001 00 00: 44
# pcs key: 0001
# raw key value: 0000 0010 01 11: 48
# pcs key: 0010
# raw key value: 0000 0001 11 00: 42
# pcs key: 0001
# raw key value: 0000 0001 01 01: 46
# pcs key: 0001
# raw key value: 0000 0101 10 01: 17
# pcs key: 0101
# raw key value: 0000 0101 11 01: 16
# pcs key: 0101
# raw key value: 0000 0010 10 01: 50
# pcs key: 0010
# raw key value: 0000 0100 11 10: 26
# pcs key: 0100
# raw key value: 0000 0000 11 00: 148
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672, '0000 0000 01 00': 132, '0000 0000 00 11': 130, '0000 0000 01 11': 152, '0000 0000 11 00': 148}
# raw key value: 0000 0001 11 10: 51
# pcs key: 0001
# raw key value: 0000 0111 11 00: 1
# pcs key: 0111
# raw key value: 0000 0100 01 10: 22
# pcs key: 0100
# raw key value: 0000 1010 10 01: 15
# pcs key: 1010
# raw key value: 0000 0000 00 00: 121
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672, '0000 0000 01 00': 132, '0000 0000 00 11': 130, '0000 0000 01 11': 152, '0000 0000 11 00': 148, '0000 0000 00 00': 121}
# raw key value: 0000 0101 00 00: 7
# pcs key: 0101
# raw key value: 0000 1000 01 10: 24
# pcs key: 1000
# raw key value: 0000 1010 00 01: 9
# pcs key: 1010
# raw key value: 0000 0000 10 00: 138
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672, '0000 0000 01 00': 132, '0000 0000 00 11': 130, '0000 0000 01 11': 152, '0000 0000 11 00': 148, '0000 0000 00 00': 121, '0000 0000 10 00': 138}
# raw key value: 0000 0001 01 11: 44
# pcs key: 0001
# raw key value: 0000 0001 10 10: 55
# pcs key: 0001
# raw key value: 0000 0001 01 00: 49
# pcs key: 0001
# raw key value: 0000 0011 10 10: 2
# pcs key: 0011
# raw key value: 0000 0010 01 10: 60
# pcs key: 0010
# raw key value: 0000 0000 11 11: 133
# pcs key: 0000
# filtered results: {'0000 0000 01 01': 4581, '0000 0000 10 11': 152, '0000 0000 00 10': 4511, '0000 0000 11 01': 4581, '0000 0000 10 10': 4417, '0000 0000 00 01': 4523, '0000 0000 01 10': 4675, '0000 0000 11 10': 4517, '0000 0000 10 01': 4672, '0000 0000 01 00': 132, '0000 0000 00 11': 130, '0000 0000 01 11': 152, '0000 0000 11 00': 148, '0000 0000 00 00': 121, '0000 0000 10 00': 138, '0000 0000 11 11': 133}
# raw key value: 0000 1010 11 11: 15
# pcs key: 1010
# raw key value: 0000 0001 00 10: 55
# pcs key: 0001
# raw key value: 0000 0001 01 10: 41
# pcs key: 0001
# raw key value: 0000 0001 00 01: 44
# pcs key: 0001
# raw key value: 0000 0010 10 00: 46
# pcs key: 0010
# raw key value: 0000 0001 10 01: 42
# pcs key: 0001
# raw key value: 0000 0101 01 01: 12
# pcs key: 0101
# raw key value: 0000 1000 10 11: 15
# pcs key: 1000
# raw key value: 0000 0101 10 11: 13
# pcs key: 0101
# raw key value: 0000 0100 00 11: 12
# pcs key: 0100
# raw key value: 0000 1000 01 00: 9
# pcs key: 1000
# raw key value: 0000 0100 11 00: 13
# pcs key: 0100
# raw key value: 0000 1000 11 00: 11
# pcs key: 1000
# raw key value: 0000 1000 00 11: 14
# pcs key: 1000
# raw key value: 0000 1010 01 11: 7
# pcs key: 1010
# raw key value: 0000 0101 01 00: 21
# pcs key: 0101
# raw key value: 0000 1000 10 00: 9
# pcs key: 1000
# raw key value: 0000 0101 00 01: 14
# pcs key: 0101
# raw key value: 0000 0010 00 11: 44
# pcs key: 0010
# raw key value: 0000 0101 11 11: 16
# pcs key: 0101
# raw key value: 0000 1000 01 11: 16
# pcs key: 1000
# raw key value: 0000 1010 01 00: 12
# pcs key: 1010
# raw key value: 0000 1010 11 01: 11
# pcs key: 1010
# raw key value: 0000 0101 00 11: 8
# pcs key: 0101
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 0100 10 00: 10
# pcs key: 0100
# raw key value: 0000 0101 01 10: 13
# pcs key: 0101
# raw key value: 0000 1010 10 10: 9
# pcs key: 1010
# raw key value: 0000 0100 10 11: 20
# pcs key: 0100
# raw key value: 0000 1001 10 00: 1
# pcs key: 1001
# raw key value: 0000 0100 01 01: 12
# pcs key: 0100
# raw key value: 0000 1010 11 10: 10
# pcs key: 1010
# raw key value: 0000 1000 00 01: 21
# pcs key: 1000
# raw key value: 0000 0100 10 10: 15
# pcs key: 0100
# raw key value: 0000 1010 01 10: 16
# pcs key: 1010
# raw key value: 0000 1010 11 00: 15
# pcs key: 1010
# raw key value: 0000 1000 00 10: 26
# pcs key: 1000
# raw key value: 0000 0101 10 10: 8
# pcs key: 0101
# raw key value: 0000 0101 00 10: 12
# pcs key: 0101
# raw key value: 0000 1010 10 11: 7
# pcs key: 1010
# raw key value: 0000 0100 11 11: 10
# pcs key: 0100
# raw key value: 0000 0101 11 00: 8
# pcs key: 0101
# raw key value: 0000 0101 01 11: 13
# pcs key: 0101
# raw key value: 0000 1010 00 11: 6
# pcs key: 1010
# raw key value: 0000 0100 00 00: 5
# pcs key: 0100
# raw key value: 0000 1000 00 00: 7
# pcs key: 1000
# raw key value: 0000 1000 01 01: 13
# pcs key: 1000
# raw key value: 0000 0100 11 01: 20
# pcs key: 0100
# raw key value: 0000 1000 11 01: 20
# pcs key: 1000
# raw key value: 0000 1010 00 10: 10
# pcs key: 1010
# raw key value: 0000 0100 01 00: 6
# pcs key: 0100
# raw key value: 0000 0101 11 10: 13
# pcs key: 0101
# raw key value: 0000 1001 00 10: 1
# pcs key: 1001
# raw key value: 0000 1010 01 01: 10
# pcs key: 1010
# raw key value: 0000 0101 10 00: 9
# pcs key: 0101
# raw key value: 0000 0100 10 01: 14
# pcs key: 0100
# raw key value: 0000 0111 01 01: 1
# pcs key: 0111
# raw key value: 0000 1000 11 11: 11
# pcs key: 1000
# raw key value: 0000 1101 11 11: 1
# pcs key: 1101
# raw key value: 0000 0011 00 00: 2
# pcs key: 0011
# raw key value: 0000 1011 10 01: 1
# pcs key: 1011
# raw key value: 0000 1101 10 10: 1
# pcs key: 1101
# raw key value: 0000 1011 10 00: 1
# pcs key: 1011
# raw key value: 0000 1001 01 01: 1
# pcs key: 1001
# raw key value: 0000 1001 01 00: 1
# pcs key: 1001
# raw key value: 0000 0011 01 11: 1
# pcs key: 0011
# raw key value: 0000 0011 10 10: 1
# pcs key: 0011
# raw key value: 0000 0010 01 10: 43
# pcs key: 0010
# raw key value: 0000 0000 11 11: 4596
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596}
# raw key value: 0000 0000 10 11: 4598
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598}
# raw key value: 0000 1000 00 11: 34
# pcs key: 1000
# raw key value: 0000 0101 11 01: 21
# pcs key: 0101
# raw key value: 0000 0000 10 00: 4689
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689}
# raw key value: 0000 1010 00 01: 28
# pcs key: 1010
# raw key value: 0000 1010 10 01: 19
# pcs key: 1010
# raw key value: 0000 0000 00 00: 4590
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590}
# raw key value: 0000 0011 11 01: 2
# pcs key: 0011
# raw key value: 0000 0010 00 11: 37
# pcs key: 0010
# raw key value: 0000 0000 11 00: 4698
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698}
# raw key value: 0000 0011 01 00: 1
# pcs key: 0011
# raw key value: 0000 0010 11 00: 46
# pcs key: 0010
# raw key value: 0000 0000 00 11: 4466
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466}
# raw key value: 0000 0000 01 11: 4593
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593}
# raw key value: 0000 1010 00 00: 1
# pcs key: 1010
# raw key value: 0000 0000 10 01: 66
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66}
# raw key value: 0000 0010 11 01: 51
# pcs key: 0010
# raw key value: 0000 0000 01 00: 4629
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629}
# raw key value: 0000 0011 10 11: 2
# pcs key: 0011
# raw key value: 0000 0010 01 01: 46
# pcs key: 0010
# raw key value: 0000 0000 11 10: 104
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629, '0000 0000 11 10': 104}
# raw key value: 0000 0101 01 10: 26
# pcs key: 0101
# raw key value: 0000 0100 11 11: 31
# pcs key: 0100
# raw key value: 0000 0010 00 00: 51
# pcs key: 0010
# raw key value: 0000 0001 11 11: 51
# pcs key: 0001
# raw key value: 0000 0001 10 11: 50
# pcs key: 0001
# raw key value: 0000 0010 10 01: 51
# pcs key: 0010
# raw key value: 0000 0001 00 10: 52
# pcs key: 0001
# raw key value: 0000 0001 01 11: 40
# pcs key: 0001
# raw key value: 0000 0000 00 10: 73
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629, '0000 0000 11 10': 104, '0000 0000 00 10': 73}
# raw key value: 0000 0011 01 01: 2
# pcs key: 0011
# raw key value: 0000 0010 10 11: 39
# pcs key: 0010
# raw key value: 0000 1010 00 10: 15
# pcs key: 1010
# raw key value: 0000 1000 10 00: 34
# pcs key: 1000
# raw key value: 0000 0001 11 00: 48
# pcs key: 0001
# raw key value: 0000 0000 01 01: 83
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629, '0000 0000 11 10': 104, '0000 0000 00 10': 73, '0000 0000 01 01': 83}
# raw key value: 0000 0010 11 10: 58
# pcs key: 0010
# raw key value: 0000 0000 10 10: 83
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629, '0000 0000 11 10': 104, '0000 0000 00 10': 73, '0000 0000 01 01': 83, '0000 0000 10 10': 83}
# raw key value: 0000 0011 11 11: 2
# pcs key: 0011
# raw key value: 0000 0010 00 01: 50
# pcs key: 0010
# raw key value: 0000 0100 01 11: 31
# pcs key: 0100
# raw key value: 0000 1010 10 00: 2
# pcs key: 1010
# raw key value: 0000 0000 00 01: 76
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629, '0000 0000 11 10': 104, '0000 0000 00 10': 73, '0000 0000 01 01': 83, '0000 0000 10 10': 83, '0000 0000 00 01': 76}
# raw key value: 0000 0011 01 10: 2
# pcs key: 0011
# raw key value: 0000 0010 10 10: 56
# pcs key: 0010
# raw key value: 0000 0001 10 01: 60
# pcs key: 0001
# raw key value: 0000 0101 01 01: 27
# pcs key: 0101
# raw key value: 0000 0001 01 00: 63
# pcs key: 0001
# raw key value: 0000 1000 11 11: 30
# pcs key: 1000
# raw key value: 0000 0101 00 01: 29
# pcs key: 0101
# raw key value: 0000 0010 11 11: 52
# pcs key: 0010
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0100 00 00: 36
# pcs key: 0100
# raw key value: 0000 0000 01 10: 88
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629, '0000 0000 11 10': 104, '0000 0000 00 10': 73, '0000 0000 01 01': 83, '0000 0000 10 10': 83, '0000 0000 00 01': 76, '0000 0000 01 10': 88}
# raw key value: 0000 0001 10 10: 43
# pcs key: 0001
# raw key value: 0000 1010 11 01: 23
# pcs key: 1010
# raw key value: 0000 0001 10 00: 64
# pcs key: 0001
# raw key value: 0000 0001 00 11: 53
# pcs key: 0001
# raw key value: 0000 0010 01 11: 58
# pcs key: 0010
# raw key value: 0000 0111 01 00: 1
# pcs key: 0111
# raw key value: 0000 0100 10 10: 1
# pcs key: 0100
# raw key value: 0000 0010 10 00: 58
# pcs key: 0010
# raw key value: 0000 0001 00 01: 44
# pcs key: 0001
# raw key value: 0000 1010 11 10: 23
# pcs key: 1010
# raw key value: 0000 0001 11 01: 48
# pcs key: 0001
# raw key value: 0000 0101 11 10: 27
# pcs key: 0101
# raw key value: 0000 0001 01 01: 46
# pcs key: 0001
# raw key value: 0000 1010 01 10: 23
# pcs key: 1010
# raw key value: 0000 0000 11 01: 75
# pcs key: 0000
# filtered results: {'0000 0000 11 11': 4596, '0000 0000 10 11': 4598, '0000 0000 10 00': 4689, '0000 0000 00 00': 4590, '0000 0000 11 00': 4698, '0000 0000 00 11': 4466, '0000 0000 01 11': 4593, '0000 0000 10 01': 66, '0000 0000 01 00': 4629, '0000 0000 11 10': 104, '0000 0000 00 10': 73, '0000 0000 01 01': 83, '0000 0000 10 10': 83, '0000 0000 00 01': 76, '0000 0000 01 10': 88, '0000 0000 11 01': 75}
# raw key value: 0000 0101 10 10: 19
# pcs key: 0101
# raw key value: 0000 1010 01 01: 29
# pcs key: 1010
# raw key value: 0000 1000 00 00: 28
# pcs key: 1000
# raw key value: 0000 1000 01 00: 29
# pcs key: 1000
# raw key value: 0000 0011 11 10: 2
# pcs key: 0011
# raw key value: 0000 0010 00 10: 40
# pcs key: 0010
# raw key value: 0000 0100 11 00: 30
# pcs key: 0100
# raw key value: 0000 1000 11 00: 29
# pcs key: 1000
# raw key value: 0000 1000 01 11: 33
# pcs key: 1000
# raw key value: 0000 1000 10 11: 29
# pcs key: 1000
# raw key value: 0000 1010 10 10: 19
# pcs key: 1010
# raw key value: 0000 0001 00 00: 45
# pcs key: 0001
# raw key value: 0000 1010 01 00: 1
# pcs key: 1010
# raw key value: 0000 1010 10 11: 2
# pcs key: 1010
# raw key value: 0000 0001 01 10: 43
# pcs key: 0001
# raw key value: 0000 0101 10 01: 22
# pcs key: 0101
# raw key value: 0000 0001 11 10: 49
# pcs key: 0001
# raw key value: 0000 0011 11 00: 3
# pcs key: 0011
# raw key value: 0000 0010 01 00: 42
# pcs key: 0010
# raw key value: 0000 0100 01 00: 22
# pcs key: 0100
# raw key value: 0000 0100 00 11: 25
# pcs key: 0100
# raw key value: 0000 0110 10 10: 2
# pcs key: 0110
# raw key value: 0000 0100 10 00: 30
# pcs key: 0100
# raw key value: 0000 0101 00 10: 16
# pcs key: 0101
# raw key value: 0000 1000 01 10: 2
# pcs key: 1000
# raw key value: 0000 0100 10 11: 29
# pcs key: 0100
# raw key value: 0000 1001 11 11: 1
# pcs key: 1001
# raw key value: 0000 0111 01 01: 2
# pcs key: 0111
# raw key value: 0000 1101 00 10: 1
# pcs key: 1101
# raw key value: 0000 1100 00 11: 2
# pcs key: 1100
# raw key value: 0000 1010 00 11: 1
# pcs key: 1010
# raw key value: 0000 0100 11 10: 1
# pcs key: 0100
# raw key value: 0000 0111 00 00: 1
# pcs key: 0111
# raw key value: 0000 1011 11 10: 1
# pcs key: 1011
# ...
# pcs key: 1100
# raw key value: 0000 0011 10 10: 132
# pcs key: 0011
# raw key value: 0000 0010 01 10: 251
# pcs key: 0010
# raw key value: 0000 1010 00 00: 148
# pcs key: 1010
# raw key value: 0000 0000 10 01: 307
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307}
# raw key value: 0000 0110 11 10: 122
# pcs key: 0110
# raw key value: 0000 1111 01 01: 93
# pcs key: 1111
# raw key value: 0000 1011 00 01: 106
# pcs key: 1011
# raw key value: 0000 0101 11 01: 189
# pcs key: 0101
# raw key value: 0000 1100 11 00: 102
# pcs key: 1100
# raw key value: 0000 1110 00 01: 90
# pcs key: 1110
# raw key value: 0000 0100 00 10: 139
# pcs key: 0100
# raw key value: 0000 0010 11 01: 220
# pcs key: 0010
# raw key value: 0000 0011 00 11: 156
# pcs key: 0011
# raw key value: 0000 1000 01 11: 207
# pcs key: 1000
# raw key value: 0000 0010 10 00: 229
# pcs key: 0010
# raw key value: 0000 1010 01 10: 200
# pcs key: 1010
# raw key value: 0000 1000 10 01: 175
# pcs key: 1000
# raw key value: 0000 0001 10 11: 228
# pcs key: 0001
# raw key value: 0000 1010 11 10: 192
# pcs key: 1010
# raw key value: 0000 1011 10 11: 118
# pcs key: 1011
# raw key value: 0000 0101 01 11: 158
# pcs key: 0101
# raw key value: 0000 0011 11 01: 157
# pcs key: 0011
# raw key value: 0000 0010 00 11: 233
# pcs key: 0010
# raw key value: 0000 0100 11 10: 171
# pcs key: 0100
# raw key value: 0000 0111 00 00: 130
# pcs key: 0111
# raw key value: 0000 1100 01 00: 129
# pcs key: 1100
# raw key value: 0000 1110 11 11: 103
# pcs key: 1110
# raw key value: 0000 0000 11 00: 384
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384}
# raw key value: 0000 0000 11 10: 287
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287}
# raw key value: 0000 0100 11 00: 172
# pcs key: 0100
# raw key value: 0000 0111 01 10: 110
# pcs key: 0111
# raw key value: 0000 1100 11 11: 98
# pcs key: 1100
# raw key value: 0000 1110 01 00: 86
# pcs key: 1110
# raw key value: 0000 0011 01 10: 161
# pcs key: 0011
# raw key value: 0000 0010 10 10: 248
# pcs key: 0010
# raw key value: 0000 0001 00 10: 246
# pcs key: 0001
# raw key value: 0000 0010 01 00: 245
# pcs key: 0010
# raw key value: 0000 0011 11 00: 178
# pcs key: 0011
# raw key value: 0000 1110 10 10: 82
# pcs key: 1110
# raw key value: 0000 1100 00 11: 100
# pcs key: 1100
# raw key value: 0000 0000 11 01: 337
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337}
# raw key value: 0000 0001 11 10: 248
# pcs key: 0001
# raw key value: 0000 1001 01 10: 120
# pcs key: 1001
# raw key value: 0000 1110 10 11: 92
# pcs key: 1110
# raw key value: 0000 1100 00 00: 96
# pcs key: 1100
# raw key value: 0000 0001 10 10: 231
# pcs key: 0001
# raw key value: 0000 1001 00 11: 118
# pcs key: 1001
# raw key value: 0000 0000 10 11: 414
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414}
# raw key value: 0000 0000 01 11: 377
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377}
# raw key value: 0000 0111 11 01: 114
# pcs key: 0111
# raw key value: 0000 0100 00 01: 173
# pcs key: 0100
# raw key value: 0000 1000 10 00: 190
# pcs key: 1000
# raw key value: 0000 0001 11 00: 203
# pcs key: 0001
# raw key value: 0000 1111 10 10: 75
# pcs key: 1111
# raw key value: 0000 0110 11 11: 115
# pcs key: 0110
# raw key value: 0000 0111 10 10: 107
# pcs key: 0111
# raw key value: 0000 0100 01 00: 205
# pcs key: 0100
# raw key value: 0000 0110 10 10: 142
# pcs key: 0110
# raw key value: 0000 0001 10 01: 243
# pcs key: 0001
# raw key value: 0000 0101 01 01: 188
# pcs key: 0101
# raw key value: 0000 0000 01 10: 343
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343}
# raw key value: 0000 0011 00 01: 144
# pcs key: 0011
# raw key value: 0000 0010 11 11: 236
# pcs key: 0010
# raw key value: 0000 1000 01 10: 168
# pcs key: 1000
# raw key value: 0000 1011 11 11: 124
# pcs key: 1011
# raw key value: 0000 0101 00 11: 148
# pcs key: 0101
# raw key value: 0000 0010 00 00: 237
# pcs key: 0010
# raw key value: 0000 1000 00 10: 146
# pcs key: 1000
# raw key value: 0000 0001 01 01: 221
# pcs key: 0001
# raw key value: 0000 0011 11 11: 155
# pcs key: 0011
# raw key value: 0000 0010 00 01: 236
# pcs key: 0010
# raw key value: 0000 0100 01 10: 141
# pcs key: 0100
# raw key value: 0000 0111 11 00: 115
# pcs key: 0111
# raw key value: 0000 0001 11 01: 250
# pcs key: 0001
# raw key value: 0000 1000 10 11: 185
# pcs key: 1000
# raw key value: 0000 1010 11 11: 174
# pcs key: 1010
# raw key value: 0000 1000 11 01: 161
# pcs key: 1000
# raw key value: 0000 1011 11 00: 118
# pcs key: 1011
# raw key value: 0000 0101 01 10: 206
# pcs key: 0101
# raw key value: 0000 0011 01 00: 153
# pcs key: 0011
# raw key value: 0000 0010 11 00: 226
# pcs key: 0010
# raw key value: 0000 0000 11 11: 401
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401}
# raw key value: 0000 1101 11 11: 91
# pcs key: 1101
# raw key value: 0000 1111 01 11: 87
# pcs key: 1111
# raw key value: 0000 1011 10 10: 112
# pcs key: 1011
# raw key value: 0000 0101 01 00: 159
# pcs key: 0101
# raw key value: 0000 1010 00 10: 178
# pcs key: 1010
# raw key value: 0000 1010 00 01: 172
# pcs key: 1010
# raw key value: 0000 0000 10 00: 391
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391}
# raw key value: 0000 1010 10 01: 190
# pcs key: 1010
# raw key value: 0000 0000 00 00: 424
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391, '0000 0000 00 00': 424}
# raw key value: 0000 1101 00 10: 93
# pcs key: 1101
# raw key value: 0000 0001 01 11: 195
# pcs key: 0001
# raw key value: 0000 0111 10 00: 121
# pcs key: 0111
# raw key value: 0000 1000 11 10: 166
# pcs key: 1000
# raw key value: 0000 0110 11 00: 113
# pcs key: 0110
# raw key value: 0000 1111 10 01: 91
# pcs key: 1111
# raw key value: 0000 1011 01 00: 119
# pcs key: 1011
# raw key value: 0000 0101 10 10: 187
# pcs key: 0101
# raw key value: 0000 1001 10 00: 129
# pcs key: 1001
# raw key value: 0000 1010 11 01: 183
# pcs key: 1010
# raw key value: 0000 1100 00 10: 85
# pcs key: 1100
# raw key value: 0000 0001 00 11: 235
# pcs key: 0001
# raw key value: 0000 0101 00 01: 199
# pcs key: 0101
# raw key value: 0000 1011 11 01: 118
# pcs key: 1011
# raw key value: 0000 1011 00 00: 112
# pcs key: 1011
# raw key value: 0000 0101 11 10: 187
# pcs key: 0101
# raw key value: 0000 1001 10 01: 131
# pcs key: 1001
# raw key value: 0000 0100 10 11: 198
# pcs key: 0100
# raw key value: 0000 0111 01 11: 129
# pcs key: 0111
# raw key value: 0000 0001 00 01: 243
# pcs key: 0001
# raw key value: 0000 0111 01 00: 127
# pcs key: 0111
# raw key value: 0000 0100 10 10: 175
# pcs key: 0100
# raw key value: 0000 0011 01 11: 151
# pcs key: 0011
# raw key value: 0000 1111 01 00: 88
# pcs key: 1111
# raw key value: 0000 0111 11 11: 127
# pcs key: 0111
# raw key value: 0000 0100 00 11: 203
# pcs key: 0100
# raw key value: 0000 0110 01 10: 137
# pcs key: 0110
# raw key value: 0000 1001 01 01: 135
# pcs key: 1001
# raw key value: 0000 1110 01 01: 115
# pcs key: 1110
# raw key value: 0000 0000 10 10: 275
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391, '0000 0000 00 00': 424, '0000 0000 10 10': 275}
# raw key value: 0000 0101 10 00: 153
# pcs key: 0101
# raw key value: 0000 0001 00 00: 217
# pcs key: 0001
# raw key value: 0000 1001 10 10: 100
# pcs key: 1001
# raw key value: 0000 0111 00 11: 132
# pcs key: 0111
# raw key value: 0000 0100 11 11: 189
# pcs key: 0100
# raw key value: 0000 1001 11 10: 136
# pcs key: 1001
# raw key value: 0000 1011 00 10: 126
# pcs key: 1011
# raw key value: 0000 0000 00 01: 272
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391, '0000 0000 00 00': 424, '0000 0000 10 10': 275, '0000 0000 00 01': 272}
# raw key value: 0000 1010 10 00: 135
# pcs key: 1010
# raw key value: 0000 0001 01 00: 208
# pcs key: 0001
# raw key value: 0000 0001 11 11: 218
# pcs key: 0001
# raw key value: 0000 0000 00 11: 391
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391, '0000 0000 00 00': 424, '0000 0000 10 10': 275, '0000 0000 00 01': 272, '0000 0000 00 11': 391}
# raw key value: 0000 0011 11 10: 150
# pcs key: 0011
# raw key value: 0000 0010 00 10: 228
# pcs key: 0010
# raw key value: 0000 1010 01 00: 165
# pcs key: 1010
# raw key value: 0000 0000 01 00: 440
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391, '0000 0000 00 00': 424, '0000 0000 10 10': 275, '0000 0000 00 01': 272, '0000 0000 00 11': 391, '0000 0000 01 00': 440}
# raw key value: 0000 0101 10 01: 180
# pcs key: 0101
# raw key value: 0000 0100 11 01: 147
# pcs key: 0100
# raw key value: 0000 0111 00 01: 117
# pcs key: 0111
# raw key value: 0000 0000 00 10: 300
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391, '0000 0000 00 00': 424, '0000 0000 10 10': 275, '0000 0000 00 01': 272, '0000 0000 00 11': 391, '0000 0000 01 00': 440, '0000 0000 00 10': 300}
# raw key value: 0000 0110 01 01: 104
# pcs key: 0110
# raw key value: 0000 0110 00 00: 122
# pcs key: 0110
# raw key value: 0000 0001 01 10: 225
# pcs key: 0001
# raw key value: 0000 0111 01 01: 111
# pcs key: 0111
# raw key value: 0000 0111 11 10: 136
# pcs key: 0111
# raw key value: 0000 0100 00 00: 209
# pcs key: 0100
# raw key value: 0000 0010 01 11: 223
# pcs key: 0010
# raw key value: 0000 1111 00 01: 80
# pcs key: 1111
# raw key value: 0000 1011 10 01: 122
# pcs key: 1011
# raw key value: 0000 1110 10 01: 85
# pcs key: 1110
# raw key value: 0000 0010 10 11: 226
# pcs key: 0010
# raw key value: 0000 0011 01 01: 160
# pcs key: 0011
# raw key value: 0000 0000 01 01: 325
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 307, '0000 0000 11 00': 384, '0000 0000 11 10': 287, '0000 0000 11 01': 337, '0000 0000 10 11': 414, '0000 0000 01 11': 377, '0000 0000 01 10': 343, '0000 0000 11 11': 401, '0000 0000 10 00': 391, '0000 0000 00 00': 424, '0000 0000 10 10': 275, '0000 0000 00 01': 272, '0000 0000 00 11': 391, '0000 0000 01 00': 440, '0000 0000 00 10': 300, '0000 0000 01 01': 325}
# raw key value: 0000 1101 01 01: 80
# pcs key: 1101
# raw key value: 0000 1101 10 01: 100
# pcs key: 1101
# raw key value: 0000 0011 10 00: 149
# pcs key: 0011
# raw key value: 0000 1010 01 11: 165
# pcs key: 1010
# raw key value: 0000 1001 00 01: 111
# pcs key: 1001
# raw key value: 0000 0011 10 01: 158
# pcs key: 0011
# raw key value: 0000 1110 00 10: 98
# pcs key: 1110
# raw key value: 0000 0101 10 11: 170
# pcs key: 0101
# raw key value: 0000 1011 01 11: 106
# pcs key: 1011
# raw key value: 0000 1101 01 00: 80
# pcs key: 1101
# raw key value: 0000 0101 11 00: 173
# pcs key: 0101
# raw key value: 0000 1011 01 10: 112
# pcs key: 1011
# raw key value: 0000 1100 01 01: 87
# pcs key: 1100
# raw key value: 0000 1001 11 11: 117
# pcs key: 1001
# raw key value: 0000 0110 01 00: 129
# pcs key: 0110
# raw key value: 0000 0010 01 01: 234
# pcs key: 0010
# raw key value: 0000 0011 10 11: 158
# pcs key: 0011
# raw key value: 0000 1111 00 10: 78
# pcs key: 1111
# raw key value: 0000 1100 10 10: 68
# pcs key: 1100
# raw key value: 0000 1110 00 11: 91
# pcs key: 1110
# raw key value: 0000 1100 11 01: 83
# pcs key: 1100
# raw key value: 0000 1110 01 10: 97
# pcs key: 1110
# raw key value: 0000 1000 11 11: 172
# pcs key: 1000
# raw key value: 0000 1010 01 01: 203
# pcs key: 1010
# raw key value: 0000 0100 01 01: 166
# pcs key: 0100
# raw key value: 0000 0100 01 11: 174
# pcs key: 0100
# raw key value: 0000 0111 10 11: 122
# pcs key: 0111
# raw key value: 0000 1010 10 11: 189
# pcs key: 1010
# raw key value: 0000 1010 00 11: 160
# pcs key: 1010
# raw key value: 0000 0110 01 11: 120
# pcs key: 0110
# raw key value: 0000 1000 00 11: 184
# pcs key: 1000
# raw key value: 0000 0101 00 10: 194
# pcs key: 0101
# raw key value: 0000 1011 10 00: 119
# pcs key: 1011
# raw key value: 0000 1000 01 00: 179
# pcs key: 1000
# raw key value: 0000 0011 00 00: 175
# pcs key: 0011
# raw key value: 0000 1111 01 10: 82
# pcs key: 1111
# raw key value: 0000 0010 10 01: 225
# pcs key: 0010
# raw key value: 0000 1011 01 01: 106
# pcs key: 1011
# raw key value: 0000 0110 11 01: 114
# pcs key: 0110
# raw key value: 0000 1110 01 11: 75
# pcs key: 1110
# raw key value: 0000 1100 11 10: 94
# pcs key: 1100
# raw key value: 0000 1100 10 00: 100
# pcs key: 1100
# raw key value: 0000 1010 10 10: 173
# pcs key: 1010
# raw key value: 0000 1001 10 11: 103
# pcs key: 1001
# raw key value: 0000 1101 11 10: 98
# pcs key: 1101
# raw key value: 0000 0100 10 01: 163
# pcs key: 0100
# raw key value: 0000 1111 10 00: 77
# pcs key: 1111
# raw key value: 0000 0110 00 11: 134
# pcs key: 0110
# raw key value: 0000 1110 11 10: 91
# pcs key: 1110
# raw key value: 0000 1100 01 11: 94
# pcs key: 1100
# raw key value: 0000 1101 00 01: 87
# pcs key: 1101
# raw key value: 0000 1101 10 11: 85
# pcs key: 1101
# raw key value: 0000 0001 10 00: 194
# pcs key: 0001
# raw key value: 0000 0110 10 00: 111
# pcs key: 0110
# raw key value: 0000 1001 01 00: 114
# pcs key: 1001
# raw key value: 0000 1101 10 00: 90
# pcs key: 1101
# raw key value: 0000 1001 11 00: 116
# pcs key: 1001
# raw key value: 0000 1000 10 10: 181
# pcs key: 1000
# raw key value: 0000 1111 00 00: 80
# pcs key: 1111
# raw key value: 0000 1111 10 11: 77
# pcs key: 1111
# raw key value: 0000 1110 11 01: 87
# pcs key: 1110
# raw key value: 0000 1100 01 10: 90
# pcs key: 1100
# raw key value: 0000 0110 10 11: 131
# pcs key: 0110
# raw key value: 0000 1001 00 00: 127
# pcs key: 1001
# raw key value: 0000 1000 01 01: 181
# pcs key: 1000
# raw key value: 0000 1111 11 10: 84
# pcs key: 1111
# raw key value: 0000 1111 00 11: 97
# pcs key: 1111
# raw key value: 0000 1000 11 00: 197
# pcs key: 1000
# raw key value: 0000 0110 00 01: 111
# pcs key: 0110
# raw key value: 0000 0110 10 01: 122
# pcs key: 0110
# raw key value: 0000 1101 00 11: 69
# pcs key: 1101
# raw key value: 0000 1101 01 10: 70
# pcs key: 1101
# raw key value: 0000 0100 10 00: 190
# pcs key: 0100
# raw key value: 0000 1110 00 00: 83
# pcs key: 1110
# raw key value: 0000 1100 10 11: 105
# pcs key: 1100
# raw key value: 0000 1101 11 00: 91
# pcs key: 1101
# raw key value: 0000 1010 11 00: 165
# pcs key: 1010
# raw key value: 0000 0111 10 01: 115
# pcs key: 0111
# raw key value: 0000 1001 00 10: 131
# pcs key: 1001
# raw key value: 0000 1111 11 11: 96
# pcs key: 1111
# raw key value: 0000 1101 11 01: 77
# pcs key: 1101
# raw key value: 0000 1111 11 00: 77
# pcs key: 1111
# raw key value: 0000 0110 00 10: 122
# pcs key: 0110
# raw key value: 0000 1000 00 00: 170
# pcs key: 1000
# raw key value: 0000 1101 01 11: 83
# pcs key: 1101
# raw key value: 0000 1101 10 10: 88
# pcs key: 1101
# raw key value: 0000 1100 10 01: 73
# pcs key: 1100
# raw key value: 0000 1111 11 01: 68
# pcs key: 1111
# raw key value: 0000 0111 00 10: 104
# pcs key: 0111
# raw key value: 0000 1101 00 00: 73
# pcs key: 1101
# raw key value: 0000 1110 10 00: 71
# pcs key: 1110
# collected vals:  {'11': 1390, '00': 1426, '01': 1280, '10': 1269}
# collected vals:  {'11': 1241, '00': 1268, '01': 1406, '10': 1463}
# collected vals:  {'01': 1241, '00': 1639, '10': 1205, '11': 1583}
# 0.3134038384137179

# %%
print(pcs_fidelity)
print(pcs_post_select_rates)
# reps=2
with open(f"json\\pcsXZ_mem_unbiased.json", "w") as fxz:
        json.dump({"errors": errors.tolist(), "fidelities": pcs_all_fidelities, "postselectRates": pcs_post_select_rates}, fxz)
with open("json\\raw_unbiased.json") as fRaw:
        dataRaw=json.load(fRaw)
nopcs_all_fidelities=dataRaw["fidelities"]
plt.plot(errors, pcs_all_fidelities, label="PCS X&Z Fidelity", marker='o')
plt.plot(errors, nopcs_all_fidelities, label="No PCS Fidelity", marker='o')
plt.plot(errors, pcs_post_select_rates, label="PCS X&Z Postselection rate",  marker='^', linestyle="--")
plt.ylabel('Probability')
plt.xlabel(f"Depolarizing Error Rate")
plt.text(0.25, .75, f"Single qubit gate error: {error_gate1}\nTwo qubit gate error: {round(error_gate1*10, 4)}", color = "red")
plt.title(f"Entanglement Swapping: PCS X&Z on Memory Qubits")
plt.legend()
plt.savefig(f"images\\pcsXZ_memory_equal_depol.png")
plt.show()
# Out:
# 0.3134038384137179
# [0.9376, 0.764075, 0.62825, 0.513125, 0.419825, 0.3395, 0.2791, 0.2323, 0.1884, 0.160125, 0.134125]
