# %%
#!/usr/bin/env python3
import qiskit
from qiskit import (
    QuantumCircuit,
    QuantumRegister,
    ClassicalRegister,
    transpile
)
from qiskit.quantum_info import (
    Kraus, 
    SuperOp,
)
from qiskit_aer.noise import(
    depolarizing_error,
    phase_damping_error,
    NoiseModel,
    QuantumError,
    amplitude_damping_error,
)
# from qiskit_ibm_provider import IBMProvider
from qiskit import Aer
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np
import math
import sys
sys.path.append('../')
import utilities as utl
import importlib
import json
importlib.reload(utl)

SHOTS=40000
def _graph_pcsZ(qc, qreg):
    for idx in list(range(qreg.size)):
        if idx==1:
            continue
        qc.h(qreg[idx])
    qc.cx(qreg[0],qreg[1])
    qc.cz(qreg[2],qreg[1])
    qc.cx(qreg[3],qreg[1])
    qc.barrier()
    qc.id(qreg)
    qc.barrier()
    qc.cx(qreg[3],qreg[1])
    qc.cz(qreg[2],qreg[1])
    qc.h([qreg[3], qreg[2]])
    return qc

# %%
tot_pcs_ancillas=4
a_qreg=QuantumRegister(4, "a")
b_qreg=QuantumRegister(4, "b")
pcs_creg=ClassicalRegister(4,"pcs")
bsm_creg=ClassicalRegister(2, "bsm")
epr_creg=ClassicalRegister(2, "epr")
junk_creg=ClassicalRegister(4, "junk") #for removing and connecting nodes
qc=QuantumCircuit(a_qreg, b_qreg, epr_creg, bsm_creg, pcs_creg, junk_creg)
qc=_graph_pcsZ(qc, a_qreg)
qc=_graph_pcsZ(qc, b_qreg)
# # x and z measurement to connect and remove nodes, respectively.
# qc.barrier()
# qc.measure(a_qreg[2], junk_creg[0])
# qc.measure(b_qreg[2], junk_creg[1])
# qc.measure(a_qreg[4], junk_creg[2])
# qc.measure(b_qreg[4], junk_creg[3])

# PCS measurements.
qc.barrier()
qc.measure(a_qreg[2], pcs_creg[0])
qc.measure(b_qreg[2], pcs_creg[1])
qc.measure(a_qreg[3], pcs_creg[2])
qc.measure(b_qreg[3], pcs_creg[3])
# Convert 2 qubit graph states to bell States.
# qc.h(a_qreg[0])
# qc.h(b_qreg[0])

#BSM measurement.
qc.barrier()
qc.cx(a_qreg[1], b_qreg[1])
qc.h(a_qreg[1])
qc.measure(a_qreg[1], bsm_creg[0])
qc.measure(b_qreg[1], bsm_creg[1])
utl._add_fixing_gates(qc, a_qreg, bsm_creg, 0)
qc.draw(fold=-1)
# Out:
#         ┌───┐              ░ ┌───┐ ░                      ░       ░                 ░              ░               ░ ┌────────── ┌──────────── ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐
#    a_0: ┤ H ├──■───────────░─┤ I ├─░──────────────────────░───────░─────────────────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─
#         └───┘┌─┴─┐   ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░                 ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘
#    a_1: ─────┤ X ├─■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░─────────────────░──────────────░───■──┤ H ├┤M├─░──────╫──────────────────────────────────────────────────────────────────────────────
#         ┌───┐└───┘ │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░                 ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║
#    a_2: ┤ H ├──────■───┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░─────────────────░─┤M├──────────░───┼────────╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░                 ░ └╥┘   ┌─┐    ░   │        ║  ░      ║
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░─────────────────░──╫────┤M├────░───┼────────╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#         └───┘              ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░                 ░  ║    └╥┘    ░   │        ║  ░      ║
#    b_0: ───────────────────░───────░─┤ H ├──■─────────────░─┤ I ├─░─────────────────░──╫─────╫─────░───┼────────╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ └───┘┌─┴─┐     ┌───┐ ░ ├───┤ ░ ┌───┐           ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║
#    b_1: ───────────────────░───────░──────┤ X ├──■──┤ X ├─░─┤ I ├─░─┤ X ├──■────────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ ┌───┐└───┘  │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║
#    b_2: ───────────────────░───────░─┤ H ├───────■────┼───░─┤ I ├─░───┼────■──┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐└───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫──────────────────────────────────────────────────────────────────────────────
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘      ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║
#  epr: 2/═══════════════════════════════════════════════════════════════════════════════╬══╬══╬══╬═══════════╬═══╬═════════╬══════════════════════════════════════════════════════════════════════════════
#                                                                                        ║  ║  ║  ║           ║   ║      ┌──╨──┐
#  bsm: 2/═══════════════════════════════════════════════════════════════════════════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═══════════════════════════════════════════════════════════════════════════
#                                                                                        ║  ║  ║  ║           1   0      └─────┘
#  pcs: 4/═══════════════════════════════════════════════════════════════════════════════╩══╩══╩══╩════════════════════════════════════════════════════════════════════════════════════════════════════════
#                                                                                        0  1  2  3
# junk: 4/═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════

# %%
pcs_all_fidelities=[]
pcs_post_select_rates=[]
errors=np.linspace(0.0, stop=0.5, num=11, endpoint=True)
error_gate1=0.001
for error in errors:
        noise_model=utl.get_noise_model(error_gate1)
        print(f"depolarizing error: {error}")
        depol1=depolarizing_error(error, 1)
        noise_model.add_all_qubit_quantum_error(depol1, ["id"])
        print(noise_model)

        backend=AerSimulator(noise_model=noise_model)
        pcs_ancillas_pos=1 # the position of the classical registers that contain the pcs measurements.
        result_xx=utl.meas_xx(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_yy=utl.meas_yy(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_zz=utl.meas_zz(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)

        xx_counts=utl.post_select(result_xx.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        yy_counts=utl.post_select(result_yy.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        zz_counts=utl.post_select(result_zz.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        pcs_post_select_rates.append(min([sum(xx_counts.values()),sum(yy_counts.values()),sum(zz_counts.values())])/SHOTS)
        epr_idx=-1 #the position of the classical registers that contain measurements of the 
                #epr pair.
        expect_xx=utl.expect_of_vals(utl.to_percent(utl.collect_meas(xx_counts, epr_idx)))
        expect_yy=utl.expect_of_vals(utl.to_percent(utl.collect_meas(yy_counts, epr_idx)))
        expect_zz=utl.expect_of_vals(utl.to_percent(utl.collect_meas(zz_counts, epr_idx)))
        pcs_fidelity=utl.fidelity_phip(expect_xx, expect_yy, expect_zz)
        print(pcs_fidelity)
        pcs_all_fidelities.append(pcs_fidelity)
# Out:
# depolarizing error: 0.0
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['x', 'cx', 'cz', 'h', 'measure', 'y', 'rz', 'ccx', 'z']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure']
# xx circ:
#         ┌───┐              ░ ┌───┐ ░                      ░       ░           »
#    a_0: ┤ H ├──■───────────░─┤ I ├─░──────────────────────░───────░───────────»
#         └───┘┌─┴─┐   ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░           »
#    a_1: ─────┤ X ├─■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ┌───┐└───┘ │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├──────■───┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘              ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░           »
#    b_0: ───────────────────░───────░─┤ H ├──■─────────────░─┤ I ├─░───────────»
#                            ░       ░ └───┘┌─┴─┐     ┌───┐ ░ ├───┤ ░ ┌───┐     »
#    b_1: ───────────────────░───────░──────┤ X ├──■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                            ░       ░ ┌───┐└───┘  │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_2: ───────────────────░───────░─┤ H ├───────■────┼───░─┤ I ├─░───┼────■──»
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  bsm: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  pcs: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# junk: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «              ░              ░               ░ ┌────────── ┌──────────── ┌───┐»
# «   a_0: ──────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├»
# «              ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘»
# «   a_1: ──────░──────────────░───■──┤ H ├┤M├─░──────╫─────────────────────────»
# «              ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║                         »
# «   a_2: ──────░─┤M├──────────░───┼────────╫──░──────╫─────────────────────────»
# «              ░ └╥┘   ┌─┐    ░   │        ║  ░      ║                         »
# «   a_3: ──────░──╫────┤M├────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║    └╥┘    ░   │        ║  ░      ║                         »
# «   b_0: ──────░──╫─────╫─────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                         »
# «   b_1: ──────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫─────────────────────────»
# «        ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║                         »
# «   b_2: ┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫─────────────────────────»
# «        └───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║                         »
# «   b_3: ──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫─────────────────────────»
# «              ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║                         »
# « epr: 2/═════════╬══╬══╬══╬═══════════╬═══╬═════════╬═════════════════════════»
# «                 ║  ║  ║  ║           ║   ║      ┌──╨──┐                      »
# « bsm: 2/═════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞══════════════════════»
# «                 ║  ║  ║  ║           1   0      └─────┘                      »
# « pcs: 4/═════════╩══╩══╩══╩═══════════════════════════════════════════════════»
# «                 0  1  2  3                                                   »
# «junk: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐   ┌─┐
# «   a_0: ┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ H ├───┤M├
# «        └──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘   └╥┘
# «   a_1: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_2: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_3: ──────────────────────────────────────────────────────────────╫─
# «                                                             ┌───┐┌─┐ ║
# «   b_0: ─────────────────────────────────────────────────────┤ H ├┤M├─╫─
# «                                                             └───┘└╥┘ ║
# «   b_1: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_2: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_3: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# « epr: 2/═══════════════════════════════════════════════════════════╩══╩═
# «                                                                   1  0
# « bsm: 2/════════════════════════════════════════════════════════════════
# «
# « pcs: 4/════════════════════════════════════════════════════════════════
# «
# «junk: 4/════════════════════════════════════════════════════════════════
# «
# xx circ:  OrderedDict([('h', 13), ('id', 8), ('measure', 8), ('cx', 7), ('barrier', 7), ('cz', 4), ('switch_case', 1)])
# yy circ:
#         ┌───┐              ░ ┌───┐ ░                      ░       ░           »
#    a_0: ┤ H ├──■───────────░─┤ I ├─░──────────────────────░───────░───────────»
#         └───┘┌─┴─┐   ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░           »
#    a_1: ─────┤ X ├─■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ┌───┐└───┘ │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├──────■───┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘              ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░           »
#    b_0: ───────────────────░───────░─┤ H ├──■─────────────░─┤ I ├─░───────────»
#                            ░       ░ └───┘┌─┴─┐     ┌───┐ ░ ├───┤ ░ ┌───┐     »
#    b_1: ───────────────────░───────░──────┤ X ├──■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                            ░       ░ ┌───┐└───┘  │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_2: ───────────────────░───────░─┤ H ├───────■────┼───░─┤ I ├─░───┼────■──»
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  bsm: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  pcs: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# junk: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «              ░              ░               ░ ┌────────── ┌──────────── ┌───┐»
# «   a_0: ──────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├»
# «              ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘»
# «   a_1: ──────░──────────────░───■──┤ H ├┤M├─░──────╫─────────────────────────»
# «              ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║                         »
# «   a_2: ──────░─┤M├──────────░───┼────────╫──░──────╫─────────────────────────»
# «              ░ └╥┘   ┌─┐    ░   │        ║  ░      ║                         »
# «   a_3: ──────░──╫────┤M├────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║    └╥┘    ░   │        ║  ░      ║                         »
# «   b_0: ──────░──╫─────╫─────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                         »
# «   b_1: ──────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫─────────────────────────»
# «        ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║                         »
# «   b_2: ┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫─────────────────────────»
# «        └───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║                         »
# «   b_3: ──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫─────────────────────────»
# «              ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║                         »
# « epr: 2/═════════╬══╬══╬══╬═══════════╬═══╬═════════╬═════════════════════════»
# «                 ║  ║  ║  ║           ║   ║      ┌──╨──┐                      »
# « bsm: 2/═════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞══════════════════════»
# «                 ║  ║  ║  ║           1   0      └─────┘                      »
# « pcs: 4/═════════╩══╩══╩══╩═══════════════════════════════════════════════════»
# «                 0  1  2  3                                                   »
# «junk: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐┌───┐   ┌─┐
# «   a_0: ┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ S ├┤ H ├───┤M├
# «        └──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘└───┘   └╥┘
# «   a_1: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_2: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_3: ───────────────────────────────────────────────────────────────────╫─
# «                                                             ┌───┐┌───┐┌─┐ ║
# «   b_0: ─────────────────────────────────────────────────────┤ S ├┤ H ├┤M├─╫─
# «                                                             └───┘└───┘└╥┘ ║
# «   b_1: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_2: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_3: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# « epr: 2/════════════════════════════════════════════════════════════════╩══╩═
# «                                                                        1  0
# « bsm: 2/═════════════════════════════════════════════════════════════════════
# «
# « pcs: 4/═════════════════════════════════════════════════════════════════════
# «
# «junk: 4/═════════════════════════════════════════════════════════════════════
# «
# yy circ:  OrderedDict([('h', 13), ('id', 8), ('measure', 8), ('cx', 7), ('barrier', 7), ('cz', 4), ('s', 2), ('switch_case', 1)])
# zz circ:
#         ┌───┐              ░ ┌───┐ ░                      ░       ░           »
#    a_0: ┤ H ├──■───────────░─┤ I ├─░──────────────────────░───────░───────────»
#         └───┘┌─┴─┐   ┌───┐ ░ ├───┤ ░ ┌───┐                ░       ░           »
#    a_1: ─────┤ X ├─■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ┌───┐└───┘ │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├──────■───┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤          │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├──────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘              ░ └───┘ ░ ┌───┐└───┘           ░ ┌───┐ ░           »
#    b_0: ───────────────────░───────░─┤ H ├──■─────────────░─┤ I ├─░───────────»
#                            ░       ░ └───┘┌─┴─┐     ┌───┐ ░ ├───┤ ░ ┌───┐     »
#    b_1: ───────────────────░───────░──────┤ X ├──■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                            ░       ░ ┌───┐└───┘  │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_2: ───────────────────░───────░─┤ H ├───────■────┼───░─┤ I ├─░───┼────■──»
#                            ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ───────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                            ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  bsm: 2/══════════════════════════════════════════════════════════════════════»
#                                                                               »
#  pcs: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# junk: 4/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «              ░              ░               ░ ┌────────── ┌──────────── ┌───┐»
# «   a_0: ──────░──────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  ┤ Z ├»
# «              ░              ░      ┌───┐┌─┐ ░ └────╥───── └──────────── └───┘»
# «   a_1: ──────░──────────────░───■──┤ H ├┤M├─░──────╫─────────────────────────»
# «              ░ ┌─┐          ░   │  └───┘└╥┘ ░      ║                         »
# «   a_2: ──────░─┤M├──────────░───┼────────╫──░──────╫─────────────────────────»
# «              ░ └╥┘   ┌─┐    ░   │        ║  ░      ║                         »
# «   a_3: ──────░──╫────┤M├────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║    └╥┘    ░   │        ║  ░      ║                         »
# «   b_0: ──────░──╫─────╫─────░───┼────────╫──░──────╫─────────────────────────»
# «              ░  ║     ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                         »
# «   b_1: ──────░──╫─────╫─────░─┤ X ├─┤M├──╫──░──────╫─────────────────────────»
# «        ┌───┐ ░  ║ ┌─┐ ║     ░ └───┘ └╥┘  ║  ░      ║                         »
# «   b_2: ┤ H ├─░──╫─┤M├─╫─────░────────╫───╫──░──────╫─────────────────────────»
# «        └───┘ ░  ║ └╥┘ ║ ┌─┐ ░        ║   ║  ░      ║                         »
# «   b_3: ──────░──╫──╫──╫─┤M├─░────────╫───╫──░──────╫─────────────────────────»
# «              ░  ║  ║  ║ └╥┘ ░        ║   ║  ░      ║                         »
# « epr: 2/═════════╬══╬══╬══╬═══════════╬═══╬═════════╬═════════════════════════»
# «                 ║  ║  ║  ║           ║   ║      ┌──╨──┐                      »
# « bsm: 2/═════════╬══╬══╬══╬═══════════╩═══╩══════╡ 0x3 ╞══════════════════════»
# «                 ║  ║  ║  ║           1   0      └─────┘                      »
# « pcs: 4/═════════╩══╩══╩══╩═══════════════════════════════════════════════════»
# «                 0  1  2  3                                                   »
# «junk: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «        ┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐    ┌─┐
# «   a_0: ┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├────┤M├
# «        └──────────── └───┘└──────────── └───┘└───┘ ───────┘    └╥┘
# «   a_1: ─────────────────────────────────────────────────────────╫─
# «                                                                 ║
# «   a_2: ─────────────────────────────────────────────────────────╫─
# «                                                                 ║
# «   a_3: ─────────────────────────────────────────────────────────╫─
# «                                                             ┌─┐ ║
# «   b_0: ─────────────────────────────────────────────────────┤M├─╫─
# «                                                             └╥┘ ║
# «   b_1: ──────────────────────────────────────────────────────╫──╫─
# «                                                              ║  ║
# «   b_2: ──────────────────────────────────────────────────────╫──╫─
# «                                                              ║  ║
# «   b_3: ──────────────────────────────────────────────────────╫──╫─
# «                                                              ║  ║
# « epr: 2/══════════════════════════════════════════════════════╩══╩═
# «                                                              1  0
# « bsm: 2/═══════════════════════════════════════════════════════════
# «
# « pcs: 4/═══════════════════════════════════════════════════════════
# «
# «junk: 4/═══════════════════════════════════════════════════════════
# «
# zz circ:  OrderedDict([('h', 11), ('id', 8), ('measure', 8), ('cx', 7), ('barrier', 7), ('cz', 4), ('switch_case', 1)])
# raw key value: 0000 0100 00 01: 13
# pcs key: 0100
# raw key value: 0000 0000 01 11: 4589
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589}
# raw key value: 0000 0000 10 11: 4767
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767}
# raw key value: 0000 0000 00 00: 4662
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662}
# raw key value: 0000 1010 10 01: 16
# pcs key: 1010
# raw key value: 0000 0100 01 10: 9
# pcs key: 0100
# raw key value: 0000 1010 00 01: 16
# pcs key: 1010
# raw key value: 0000 0000 10 00: 4583
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583}
# raw key value: 0000 0100 00 10: 9
# pcs key: 0100
# raw key value: 0000 0011 00 11: 3
# pcs key: 0011
# raw key value: 0000 0010 11 01: 47
# pcs key: 0010
# raw key value: 0000 0000 01 00: 4411
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411}
# raw key value: 0000 0010 10 01: 43
# pcs key: 0010
# raw key value: 0000 0011 10 10: 1
# pcs key: 0011
# raw key value: 0000 0010 01 10: 33
# pcs key: 0010
# raw key value: 0000 0000 11 11: 4484
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484}
# raw key value: 0000 0000 00 11: 4558
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558}
# raw key value: 0000 0111 01 00: 1
# pcs key: 0111
# raw key value: 0000 0100 10 10: 17
# pcs key: 0100
# raw key value: 0000 0010 01 11: 51
# pcs key: 0010
# raw key value: 0000 0000 11 00: 4526
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526}
# raw key value: 0000 0001 00 10: 46
# pcs key: 0001
# raw key value: 0000 0000 01 01: 165
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165}
# raw key value: 0000 0010 11 10: 39
# pcs key: 0010
# raw key value: 0000 1010 01 11: 15
# pcs key: 1010
# raw key value: 0000 0100 01 11: 14
# pcs key: 0100
# raw key value: 0000 0010 10 10: 30
# pcs key: 0010
# raw key value: 0000 0011 01 10: 2
# pcs key: 0011
# raw key value: 0000 1010 10 00: 7
# pcs key: 1010
# raw key value: 0000 0000 00 01: 148
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165, '0000 0000 00 01': 148}
# raw key value: 0000 0100 11 00: 27
# pcs key: 0100
# raw key value: 0000 0010 01 01: 35
# pcs key: 0010
# raw key value: 0000 0011 10 11: 1
# pcs key: 0011
# raw key value: 0000 0000 11 10: 167
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165, '0000 0000 00 01': 148, '0000 0000 11 10': 167}
# raw key value: 0000 1011 11 11: 1
# pcs key: 1011
# raw key value: 0000 0101 00 11: 15
# pcs key: 0101
# raw key value: 0000 1000 11 01: 15
# pcs key: 1000
# raw key value: 0000 0001 00 01: 37
# pcs key: 0001
# raw key value: 0000 0010 00 01: 34
# pcs key: 0010
# raw key value: 0000 0000 10 10: 158
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165, '0000 0000 00 01': 148, '0000 0000 11 10': 167, '0000 0000 10 10': 158}
# raw key value: 0000 0000 11 01: 187
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165, '0000 0000 00 01': 148, '0000 0000 11 10': 167, '0000 0000 10 10': 158, '0000 0000 11 01': 187}
# raw key value: 0000 0111 01 11: 1
# pcs key: 0111
# raw key value: 0000 0100 10 11: 28
# pcs key: 0100
# raw key value: 0000 0101 01 01: 13
# pcs key: 0101
# raw key value: 0000 1000 10 11: 16
# pcs key: 1000
# raw key value: 0000 0001 10 01: 30
# pcs key: 0001
# raw key value: 0000 0001 00 11: 51
# pcs key: 0001
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0010 11 11: 45
# pcs key: 0010
# raw key value: 0000 0000 01 10: 129
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165, '0000 0000 00 01': 148, '0000 0000 11 10': 167, '0000 0000 10 10': 158, '0000 0000 11 01': 187, '0000 0000 01 10': 129}
# raw key value: 0000 0001 11 01: 32
# pcs key: 0001
# raw key value: 0000 1000 00 01: 11
# pcs key: 1000
# raw key value: 0000 1010 00 00: 10
# pcs key: 1010
# raw key value: 0000 0000 10 01: 147
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165, '0000 0000 00 01': 148, '0000 0000 11 10': 167, '0000 0000 10 10': 158, '0000 0000 11 01': 187, '0000 0000 01 10': 129, '0000 0000 10 01': 147}
# raw key value: 0000 0101 01 10: 15
# pcs key: 0101
# raw key value: 0000 0011 01 01: 2
# pcs key: 0011
# raw key value: 0000 0010 10 11: 48
# pcs key: 0010
# raw key value: 0000 0000 00 10: 132
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4589, '0000 0000 10 11': 4767, '0000 0000 00 00': 4662, '0000 0000 10 00': 4583, '0000 0000 01 00': 4411, '0000 0000 11 11': 4484, '0000 0000 00 11': 4558, '0000 0000 11 00': 4526, '0000 0000 01 01': 165, '0000 0000 00 01': 148, '0000 0000 11 10': 167, '0000 0000 10 10': 158, '0000 0000 11 01': 187, '0000 0000 01 10': 129, '0000 0000 10 01': 147, '0000 0000 00 10': 132}
# raw key value: 0000 0001 11 10: 37
# pcs key: 0001
# raw key value: 0000 1010 00 11: 22
# pcs key: 1010
# raw key value: 0000 0001 01 01: 29
# pcs key: 0001
# raw key value: 0000 1000 01 11: 22
# pcs key: 1000
# raw key value: 0000 0001 10 11: 50
# pcs key: 0001
# raw key value: 0000 1011 10 11: 1
# pcs key: 1011
# raw key value: 0000 0101 01 11: 16
# pcs key: 0101
# raw key value: 0000 0010 00 00: 37
# pcs key: 0010
# raw key value: 0000 0101 00 00: 10
# pcs key: 0101
# raw key value: 0000 0001 00 00: 36
# pcs key: 0001
# raw key value: 0000 1000 11 11: 14
# pcs key: 1000
# raw key value: 0000 0001 01 00: 23
# pcs key: 0001
# raw key value: 0000 0001 01 10: 31
# pcs key: 0001
# raw key value: 0000 0101 01 00: 12
# pcs key: 0101
# raw key value: 0000 1010 01 00: 20
# pcs key: 1010
# raw key value: 0000 0001 11 00: 42
# pcs key: 0001
# raw key value: 0000 1010 01 01: 15
# pcs key: 1010
# raw key value: 0000 0101 11 00: 10
# pcs key: 0101
# raw key value: 0000 0010 10 00: 51
# pcs key: 0010
# raw key value: 0000 1000 10 00: 21
# pcs key: 1000
# raw key value: 0000 1010 11 11: 10
# pcs key: 1010
# raw key value: 0000 0101 11 11: 13
# pcs key: 0101
# raw key value: 0000 0001 11 11: 55
# pcs key: 0001
# raw key value: 0000 0011 01 00: 2
# pcs key: 0011
# raw key value: 0000 0010 11 00: 43
# pcs key: 0010
# raw key value: 0000 1000 11 00: 25
# pcs key: 1000
# raw key value: 0000 0011 11 01: 2
# pcs key: 0011
# raw key value: 0000 0010 00 11: 41
# pcs key: 0010
# raw key value: 0000 0010 00 10: 31
# pcs key: 0010
# raw key value: 0000 1010 11 01: 9
# pcs key: 1010
# raw key value: 0000 1010 11 10: 10
# pcs key: 1010
# raw key value: 0000 1010 01 10: 10
# pcs key: 1010
# raw key value: 0000 0100 10 01: 14
# pcs key: 0100
# raw key value: 0000 0001 10 10: 28
# pcs key: 0001
# raw key value: 0000 1001 00 11: 2
# pcs key: 1001
# raw key value: 0000 1000 01 10: 8
# pcs key: 1000
# raw key value: 0000 0101 10 01: 8
# pcs key: 0101
# raw key value: 0000 0101 10 00: 13
# pcs key: 0101
# raw key value: 0000 0110 11 10: 1
# pcs key: 0110
# raw key value: 0000 1011 00 00: 1
# pcs key: 1011
# raw key value: 0000 0101 11 10: 10
# pcs key: 0101
# raw key value: 0000 0100 00 11: 14
# pcs key: 0100
# raw key value: 0000 0100 10 00: 17
# pcs key: 0100
# raw key value: 0000 0100 11 01: 14
# pcs key: 0100
# raw key value: 0000 0101 11 01: 12
# pcs key: 0101
# raw key value: 0000 1000 00 11: 23
# pcs key: 1000
# raw key value: 0000 0100 00 00: 10
# pcs key: 0100
# raw key value: 0000 1000 10 01: 12
# pcs key: 1000
# raw key value: 0000 1000 00 10: 12
# pcs key: 1000
# raw key value: 0000 1010 10 10: 13
# pcs key: 1010
# raw key value: 0000 1010 00 10: 18
# pcs key: 1010
# raw key value: 0000 0001 01 11: 39
# pcs key: 0001
# raw key value: 0000 0111 00 11: 1
# pcs key: 0111
# raw key value: 0000 0100 11 11: 21
# pcs key: 0100
# raw key value: 0000 1010 10 11: 15
# pcs key: 1010
# raw key value: 0000 1000 01 00: 21
# pcs key: 1000
# raw key value: 0000 1000 11 10: 11
# pcs key: 1000
# raw key value: 0000 1000 00 00: 24
# pcs key: 1000
# raw key value: 0000 0100 01 01: 8
# pcs key: 0100
# raw key value: 0000 0100 01 00: 12
# pcs key: 0100
# raw key value: 0000 1000 01 01: 14
# pcs key: 1000
# raw key value: 0000 1000 10 10: 15
# pcs key: 1000
# raw key value: 0000 0101 00 10: 11
# pcs key: 0101
# raw key value: 0000 0010 01 00: 33
# pcs key: 0010
# raw key value: 0000 0101 00 01: 12
# pcs key: 0101
# raw key value: 0000 0001 10 00: 35
# pcs key: 0001
# raw key value: 0000 0100 11 10: 12
# pcs key: 0100
# raw key value: 0000 0101 10 10: 12
# pcs key: 0101
# raw key value: 0000 0101 10 11: 13
# pcs key: 0101
# raw key value: 0000 0110 01 01: 1
# pcs key: 0110
# raw key value: 0000 1001 00 00: 1
# pcs key: 1001
# raw key value: 0000 1010 11 00: 7
# pcs key: 1010
# raw key value: 0000 1111 01 00: 1
# pcs key: 1111
# raw key value: 0000 1001 10 10: 1
# pcs key: 1001
# raw key value: 0000 0011 10 01: 1
# pcs key: 0011
# raw key value: 0000 1101 10 01: 1
# pcs key: 1101
# raw key value: 0000 0110 00 01: 1
# pcs key: 0110
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 1100 11 01: 1
# pcs key: 1100
# raw key value: 0000 0011 01 11: 1
# pcs key: 0011
# raw key value: 0000 0011 00 00: 1
# pcs key: 0011
# raw key value: 0000 0000 10 01: 4511
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511}
# raw key value: 0000 1010 00 00: 20
# pcs key: 1010
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 48
# pcs key: 0010
# raw key value: 0000 1010 10 00: 9
# pcs key: 1010
# raw key value: 0000 0000 00 01: 4535
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535}
# raw key value: 0000 0011 11 11: 1
# pcs key: 0011
# raw key value: 0000 0010 00 01: 50
# pcs key: 0010
# raw key value: 0000 0000 10 10: 4663
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663}
# raw key value: 0000 0011 10 11: 1
# pcs key: 0011
# raw key value: 0000 0010 01 01: 50
# pcs key: 0010
# raw key value: 0000 0100 11 00: 14
# pcs key: 0100
# raw key value: 0000 0000 11 10: 4529
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529}
# raw key value: 0000 0010 11 10: 57
# pcs key: 0010
# raw key value: 0000 0000 01 01: 4529
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529}
# raw key value: 0000 0000 01 10: 4594
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594}
# raw key value: 0000 0111 01 11: 1
# pcs key: 0111
# raw key value: 0000 0100 10 11: 17
# pcs key: 0100
# raw key value: 0000 0000 11 01: 4509
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509}
# raw key value: 0000 0100 11 01: 17
# pcs key: 0100
# raw key value: 0000 0010 00 10: 52
# pcs key: 0010
# raw key value: 0000 0000 10 11: 149
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149}
# raw key value: 0000 0100 01 00: 13
# pcs key: 0100
# raw key value: 0000 0000 00 10: 4527
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527}
# raw key value: 0000 1111 00 11: 1
# pcs key: 1111
# raw key value: 0000 0001 01 10: 42
# pcs key: 0001
# raw key value: 0000 0011 01 00: 1
# pcs key: 0011
# raw key value: 0000 0010 11 00: 42
# pcs key: 0010
# raw key value: 0000 0000 00 11: 181
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527, '0000 0000 00 11': 181}
# raw key value: 0000 0001 11 01: 47
# pcs key: 0001
# raw key value: 0000 0001 10 10: 39
# pcs key: 0001
# raw key value: 0000 0010 00 00: 45
# pcs key: 0010
# raw key value: 0000 0100 11 11: 6
# pcs key: 0100
# raw key value: 0000 1010 00 01: 15
# pcs key: 1010
# raw key value: 0000 0000 10 00: 167
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527, '0000 0000 00 11': 181, '0000 0000 10 00': 167}
# raw key value: 0000 0101 11 01: 15
# pcs key: 0101
# raw key value: 0000 0001 11 11: 46
# pcs key: 0001
# raw key value: 0000 0001 11 10: 38
# pcs key: 0001
# raw key value: 0000 0001 00 10: 36
# pcs key: 0001
# raw key value: 0000 0011 00 11: 1
# pcs key: 0011
# raw key value: 0000 0010 11 01: 41
# pcs key: 0010
# raw key value: 0000 0000 01 00: 185
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527, '0000 0000 00 11': 181, '0000 0000 10 00': 167, '0000 0000 01 00': 185}
# raw key value: 0000 0000 01 11: 157
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527, '0000 0000 00 11': 181, '0000 0000 10 00': 167, '0000 0000 01 00': 185, '0000 0000 01 11': 157}
# raw key value: 0000 0000 00 00: 155
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527, '0000 0000 00 11': 181, '0000 0000 10 00': 167, '0000 0000 01 00': 185, '0000 0000 01 11': 157, '0000 0000 00 00': 155}
# raw key value: 0000 1010 10 01: 19
# pcs key: 1010
# raw key value: 0000 1101 11 11: 1
# pcs key: 1101
# raw key value: 0000 0100 01 10: 23
# pcs key: 0100
# raw key value: 0000 0001 00 11: 33
# pcs key: 0001
# raw key value: 0000 0001 10 01: 50
# pcs key: 0001
# raw key value: 0000 0101 01 01: 13
# pcs key: 0101
# raw key value: 0000 0000 11 00: 161
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527, '0000 0000 00 11': 181, '0000 0000 10 00': 167, '0000 0000 01 00': 185, '0000 0000 01 11': 157, '0000 0000 00 00': 155, '0000 0000 11 00': 161}
# raw key value: 0000 0011 11 01: 2
# pcs key: 0011
# raw key value: 0000 0010 00 11: 42
# pcs key: 0010
# raw key value: 0000 1010 00 10: 10
# pcs key: 1010
# raw key value: 0000 0001 00 00: 31
# pcs key: 0001
# raw key value: 0000 0010 01 10: 54
# pcs key: 0010
# raw key value: 0000 0000 11 11: 183
# pcs key: 0000
# filtered results: {'0000 0000 10 01': 4511, '0000 0000 00 01': 4535, '0000 0000 10 10': 4663, '0000 0000 11 10': 4529, '0000 0000 01 01': 4529, '0000 0000 01 10': 4594, '0000 0000 11 01': 4509, '0000 0000 10 11': 149, '0000 0000 00 10': 4527, '0000 0000 00 11': 181, '0000 0000 10 00': 167, '0000 0000 01 00': 185, '0000 0000 01 11': 157, '0000 0000 00 00': 155, '0000 0000 11 00': 161, '0000 0000 11 11': 183}
# raw key value: 0000 1000 10 01: 16
# pcs key: 1000
# raw key value: 0000 0010 10 01: 38
# pcs key: 0010
# raw key value: 0000 0001 00 01: 36
# pcs key: 0001
# raw key value: 0000 0100 10 01: 28
# pcs key: 0100
# raw key value: 0000 1010 01 10: 11
# pcs key: 1010
# raw key value: 0000 0101 01 11: 15
# pcs key: 0101
# raw key value: 0000 1010 11 01: 11
# pcs key: 1010
# raw key value: 0000 1000 11 01: 24
# pcs key: 1000
# raw key value: 0000 0101 00 00: 10
# pcs key: 0101
# raw key value: 0000 1011 11 10: 1
# pcs key: 1011
# raw key value: 0000 1111 10 01: 1
# pcs key: 1111
# raw key value: 0000 1010 01 11: 16
# pcs key: 1010
# raw key value: 0000 1011 01 00: 1
# pcs key: 1011
# raw key value: 0000 0101 10 10: 11
# pcs key: 0101
# raw key value: 0000 1010 11 11: 14
# pcs key: 1010
# raw key value: 0000 0100 10 10: 25
# pcs key: 0100
# raw key value: 0000 0101 11 00: 11
# pcs key: 0101
# raw key value: 0000 0001 10 00: 33
# pcs key: 0001
# raw key value: 0000 0100 10 00: 13
# pcs key: 0100
# raw key value: 0000 1000 00 10: 21
# pcs key: 1000
# raw key value: 0000 0010 10 00: 43
# pcs key: 0010
# raw key value: 0000 0001 01 00: 36
# pcs key: 0001
# raw key value: 0000 0010 10 11: 39
# pcs key: 0010
# raw key value: 0000 0100 00 10: 15
# pcs key: 0100
# raw key value: 0000 0010 01 11: 39
# pcs key: 0010
# raw key value: 0000 1000 11 00: 10
# pcs key: 1000
# raw key value: 0000 1000 10 11: 18
# pcs key: 1000
# raw key value: 0000 0101 10 01: 16
# pcs key: 0101
# raw key value: 0000 0101 11 10: 15
# pcs key: 0101
# raw key value: 0000 0010 01 00: 42
# pcs key: 0010
# raw key value: 0000 1000 00 11: 12
# pcs key: 1000
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0010 11 11: 34
# pcs key: 0010
# raw key value: 0000 0001 01 11: 41
# pcs key: 0001
# raw key value: 0000 1000 00 01: 16
# pcs key: 1000
# raw key value: 0000 1010 00 11: 19
# pcs key: 1010
# raw key value: 0000 0001 01 01: 41
# pcs key: 0001
# raw key value: 0000 1000 00 00: 12
# pcs key: 1000
# raw key value: 0000 0101 00 10: 18
# pcs key: 0101
# raw key value: 0000 0100 00 11: 18
# pcs key: 0100
# raw key value: 0000 1000 10 10: 12
# pcs key: 1000
# raw key value: 0000 0101 10 11: 19
# pcs key: 0101
# raw key value: 0000 1000 01 01: 12
# pcs key: 1000
# raw key value: 0000 0101 11 11: 10
# pcs key: 0101
# raw key value: 0000 0001 10 11: 32
# pcs key: 0001
# raw key value: 0000 1010 11 10: 14
# pcs key: 1010
# raw key value: 0000 1000 10 00: 12
# pcs key: 1000
# raw key value: 0000 0001 11 00: 33
# pcs key: 0001
# raw key value: 0000 0100 11 10: 19
# pcs key: 0100
# raw key value: 0000 1001 00 10: 1
# pcs key: 1001
# raw key value: 0000 0101 01 00: 13
# pcs key: 0101
# raw key value: 0000 1000 11 10: 18
# pcs key: 1000
# raw key value: 0000 0101 00 11: 7
# pcs key: 0101
# raw key value: 0000 0100 01 01: 12
# pcs key: 0100
# raw key value: 0000 1000 01 11: 12
# pcs key: 1000
# raw key value: 0000 0101 01 10: 16
# pcs key: 0101
# raw key value: 0000 1010 01 01: 13
# pcs key: 1010
# raw key value: 0000 0101 00 01: 11
# pcs key: 0101
# raw key value: 0000 0100 01 11: 6
# pcs key: 0100
# raw key value: 0000 0111 11 01: 1
# pcs key: 0111
# raw key value: 0000 0100 00 01: 12
# pcs key: 0100
# raw key value: 0000 1010 11 00: 7
# pcs key: 1010
# raw key value: 0000 1000 11 11: 15
# pcs key: 1000
# raw key value: 0000 0100 00 00: 14
# pcs key: 0100
# raw key value: 0000 1001 01 11: 2
# pcs key: 1001
# raw key value: 0000 1010 01 00: 12
# pcs key: 1010
# raw key value: 0000 1111 11 00: 1
# pcs key: 1111
# raw key value: 0000 1000 01 10: 14
# pcs key: 1000
# raw key value: 0000 0011 10 01: 1
# pcs key: 0011
# raw key value: 0000 0101 10 00: 8
# pcs key: 0101
# raw key value: 0000 1010 10 10: 14
# pcs key: 1010
# raw key value: 0000 1010 10 11: 7
# pcs key: 1010
# raw key value: 0000 1100 11 01: 1
# pcs key: 1100
# raw key value: 0000 1001 10 11: 1
# pcs key: 1001
# raw key value: 0000 1000 01 00: 8
# pcs key: 1000
# raw key value: 0000 0110 11 10: 2
# pcs key: 0110
# raw key value: 0000 0110 01 11: 1
# pcs key: 0110
# raw key value: 0000 1111 01 00: 2
# pcs key: 1111
# raw key value: 0000 1001 01 01: 1
# pcs key: 1001
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 1100 11 00: 1
# pcs key: 1100
# raw key value: 0000 1001 11 10: 1
# pcs key: 1001
# raw key value: 0000 1100 00 10: 1
# pcs key: 1100
# raw key value: 0000 0010 10 11: 31
# pcs key: 0010
# raw key value: 0000 0000 00 10: 119
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119}
# raw key value: 0000 0010 00 10: 56
# pcs key: 0010
# raw key value: 0000 0000 10 11: 4547
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547}
# raw key value: 0000 0100 11 11: 28
# pcs key: 0100
# raw key value: 0000 0010 00 00: 36
# pcs key: 0010
# raw key value: 0000 0000 10 00: 4592
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592}
# raw key value: 0000 1010 00 01: 28
# pcs key: 1010
# raw key value: 0000 0000 00 00: 4678
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678}
# raw key value: 0000 1010 10 01: 31
# pcs key: 1010
# raw key value: 0000 0000 11 11: 4658
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658}
# raw key value: 0000 0010 00 11: 23
# pcs key: 0010
# raw key value: 0000 0000 11 00: 4574
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574}
# raw key value: 0000 0000 01 11: 4515
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515}
# raw key value: 0000 0000 01 10: 141
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141}
# raw key value: 0000 0111 11 10: 1
# pcs key: 0111
# raw key value: 0000 0100 00 00: 21
# pcs key: 0100
# raw key value: 0000 0010 11 11: 30
# pcs key: 0010
# raw key value: 0000 0010 11 01: 42
# pcs key: 0010
# raw key value: 0000 0000 01 00: 4546
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546}
# raw key value: 0000 0000 00 11: 4715
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546, '0000 0000 00 11': 4715}
# raw key value: 0000 0010 01 11: 37
# pcs key: 0010
# raw key value: 0000 1000 11 11: 36
# pcs key: 1000
# raw key value: 0000 0111 11 11: 1
# pcs key: 0111
# raw key value: 0000 0100 00 11: 24
# pcs key: 0100
# raw key value: 0000 0000 01 01: 119
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546, '0000 0000 00 11': 4715, '0000 0000 01 01': 119}
# raw key value: 0000 0010 00 01: 52
# pcs key: 0010
# raw key value: 0000 0000 10 10: 136
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546, '0000 0000 00 11': 4715, '0000 0000 01 01': 119, '0000 0000 10 10': 136}
# raw key value: 0000 0000 11 01: 137
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546, '0000 0000 00 11': 4715, '0000 0000 01 01': 119, '0000 0000 10 10': 136, '0000 0000 11 01': 137}
# raw key value: 0000 0001 11 01: 46
# pcs key: 0001
# raw key value: 0000 1000 01 11: 32
# pcs key: 1000
# raw key value: 0000 1010 01 01: 22
# pcs key: 1010
# raw key value: 0000 0101 10 01: 28
# pcs key: 0101
# raw key value: 0000 0001 01 01: 53
# pcs key: 0001
# raw key value: 0000 1010 11 01: 26
# pcs key: 1010
# raw key value: 0000 0001 00 01: 49
# pcs key: 0001
# raw key value: 0000 0011 10 11: 1
# pcs key: 0011
# raw key value: 0000 0010 01 01: 44
# pcs key: 0010
# raw key value: 0000 0100 11 00: 24
# pcs key: 0100
# raw key value: 0000 0000 11 10: 125
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546, '0000 0000 00 11': 4715, '0000 0000 01 01': 119, '0000 0000 10 10': 136, '0000 0000 11 01': 137, '0000 0000 11 10': 125}
# raw key value: 0000 1010 10 00: 1
# pcs key: 1010
# raw key value: 0000 0000 00 01: 139
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546, '0000 0000 00 11': 4715, '0000 0000 01 01': 119, '0000 0000 10 10': 136, '0000 0000 11 01': 137, '0000 0000 11 10': 125, '0000 0000 00 01': 139}
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 55
# pcs key: 0010
# raw key value: 0000 1000 00 00: 37
# pcs key: 1000
# raw key value: 0000 0000 10 01: 119
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 119, '0000 0000 10 11': 4547, '0000 0000 10 00': 4592, '0000 0000 00 00': 4678, '0000 0000 11 11': 4658, '0000 0000 11 00': 4574, '0000 0000 01 11': 4515, '0000 0000 01 10': 141, '0000 0000 01 00': 4546, '0000 0000 00 11': 4715, '0000 0000 01 01': 119, '0000 0000 10 10': 136, '0000 0000 11 01': 137, '0000 0000 11 10': 125, '0000 0000 00 01': 139, '0000 0000 10 01': 119}
# raw key value: 0000 0101 11 10: 20
# pcs key: 0101
# raw key value: 0000 1010 11 10: 20
# pcs key: 1010
# raw key value: 0000 0010 10 01: 58
# pcs key: 0010
# raw key value: 0000 0001 00 00: 32
# pcs key: 0001
# raw key value: 0000 0001 10 11: 40
# pcs key: 0001
# raw key value: 0000 0101 01 01: 13
# pcs key: 0101
# raw key value: 0000 1000 10 11: 26
# pcs key: 1000
# raw key value: 0000 0001 10 01: 47
# pcs key: 0001
# raw key value: 0000 0001 00 10: 45
# pcs key: 0001
# raw key value: 0000 1000 11 00: 29
# pcs key: 1000
# raw key value: 0000 1010 01 10: 22
# pcs key: 1010
# raw key value: 0000 0001 10 10: 51
# pcs key: 0001
# raw key value: 0000 0001 00 11: 23
# pcs key: 0001
# raw key value: 0000 1000 01 00: 34
# pcs key: 1000
# raw key value: 0000 0001 11 10: 43
# pcs key: 0001
# raw key value: 0000 1000 00 11: 33
# pcs key: 1000
# raw key value: 0000 0001 01 11: 18
# pcs key: 0001
# raw key value: 0000 0001 11 11: 35
# pcs key: 0001
# raw key value: 0000 0001 01 10: 41
# pcs key: 0001
# raw key value: 0000 0101 00 10: 19
# pcs key: 0101
# raw key value: 0000 1000 10 00: 33
# pcs key: 1000
# raw key value: 0000 0010 10 00: 25
# pcs key: 0010
# raw key value: 0000 1010 10 10: 19
# pcs key: 1010
# raw key value: 0000 0010 01 00: 34
# pcs key: 0010
# raw key value: 0000 0101 01 10: 18
# pcs key: 0101
# raw key value: 0000 0010 01 10: 54
# pcs key: 0010
# raw key value: 0000 0010 11 00: 40
# pcs key: 0010
# raw key value: 0000 0001 11 00: 25
# pcs key: 0001
# raw key value: 0000 1010 00 10: 27
# pcs key: 1010
# raw key value: 0000 0011 00 10: 1
# pcs key: 0011
# raw key value: 0000 0010 11 10: 45
# pcs key: 0010
# raw key value: 0000 0001 01 00: 32
# pcs key: 0001
# raw key value: 0000 1001 11 01: 1
# pcs key: 1001
# raw key value: 0000 0100 11 01: 3
# pcs key: 0100
# raw key value: 0000 0101 10 10: 24
# pcs key: 0101
# raw key value: 0000 0101 00 01: 19
# pcs key: 0101
# raw key value: 0000 0100 10 11: 32
# pcs key: 0100
# raw key value: 0000 0100 01 11: 27
# pcs key: 0100
# raw key value: 0000 0100 10 00: 33
# pcs key: 0100
# raw key value: 0000 0001 10 00: 34
# pcs key: 0001
# raw key value: 0000 0111 00 00: 1
# pcs key: 0111
# raw key value: 0000 0100 11 10: 2
# pcs key: 0100
# raw key value: 0000 0110 01 00: 2
# pcs key: 0110
# raw key value: 0000 0100 00 01: 2
# pcs key: 0100
# raw key value: 0000 0110 01 11: 1
# pcs key: 0110
# raw key value: 0000 0101 11 01: 10
# pcs key: 0101
# raw key value: 0000 0100 01 00: 27
# pcs key: 0100
# raw key value: 0000 1001 01 11: 1
# pcs key: 1001
# raw key value: 0000 0011 10 01: 1
# pcs key: 0011
# raw key value: 0000 1011 10 11: 1
# pcs key: 1011
# raw key value: 0000 1011 00 10: 1
# pcs key: 1011
# raw key value: 0000 1000 01 10: 1
# pcs key: 1000
# raw key value: 0000 1011 01 11: 1
# pcs key: 1011
# raw key value: 0000 0101 10 11: 1
# pcs key: 0101
# raw key value: 0000 1010 11 11: 1
# pcs key: 1010
# raw key value: 0000 0101 00 11: 2
# pcs key: 0101
# raw key value: 0000 0111 01 01: 1
# pcs key: 0111
# ...
# raw key value: 0000 0000 11 01: 303
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303}
# raw key value: 0000 1101 00 10: 109
# pcs key: 1101
# raw key value: 0000 1000 11 11: 167
# pcs key: 1000
# raw key value: 0000 1111 10 00: 83
# pcs key: 1111
# raw key value: 0000 0101 00 01: 186
# pcs key: 0101
# raw key value: 0000 1011 11 01: 115
# pcs key: 1011
# raw key value: 0000 1000 11 01: 157
# pcs key: 1000
# raw key value: 0000 1001 10 00: 111
# pcs key: 1001
# raw key value: 0000 0011 00 00: 158
# pcs key: 0011
# raw key value: 0000 0100 00 01: 155
# pcs key: 0100
# raw key value: 0000 0111 11 01: 105
# pcs key: 0111
# raw key value: 0000 0001 11 00: 227
# pcs key: 0001
# raw key value: 0000 1000 10 00: 205
# pcs key: 1000
# raw key value: 0000 0110 01 10: 129
# pcs key: 0110
# raw key value: 0000 0111 00 00: 107
# pcs key: 0111
# raw key value: 0000 0100 11 10: 168
# pcs key: 0100
# raw key value: 0000 0000 11 00: 406
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406}
# raw key value: 0000 0101 01 01: 186
# pcs key: 0101
# raw key value: 0000 1000 10 11: 200
# pcs key: 1000
# raw key value: 0000 0000 00 11: 372
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372}
# raw key value: 0000 0000 01 01: 292
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292}
# raw key value: 0000 0101 01 11: 153
# pcs key: 0101
# raw key value: 0000 1011 10 11: 105
# pcs key: 1011
# raw key value: 0000 1111 10 01: 94
# pcs key: 1111
# raw key value: 0000 1010 01 00: 153
# pcs key: 1010
# raw key value: 0000 1010 11 10: 208
# pcs key: 1010
# raw key value: 0000 0000 00 00: 385
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385}
# raw key value: 0000 1010 10 01: 169
# pcs key: 1010
# raw key value: 0000 1101 11 11: 91
# pcs key: 1101
# raw key value: 0000 0011 01 11: 170
# pcs key: 0011
# raw key value: 0000 0110 01 01: 111
# pcs key: 0110
# raw key value: 0000 0100 11 00: 187
# pcs key: 0100
# raw key value: 0000 0111 01 10: 122
# pcs key: 0111
# raw key value: 0000 0110 01 11: 111
# pcs key: 0110
# raw key value: 0000 0011 01 10: 180
# pcs key: 0011
# raw key value: 0000 0010 10 10: 233
# pcs key: 0010
# raw key value: 0000 1010 10 00: 151
# pcs key: 1010
# raw key value: 0000 0000 00 01: 315
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315}
# raw key value: 0000 0011 10 10: 137
# pcs key: 0011
# raw key value: 0000 0010 01 10: 233
# pcs key: 0010
# raw key value: 0000 1110 11 00: 87
# pcs key: 1110
# raw key value: 0000 1100 00 01: 67
# pcs key: 1100
# raw key value: 0000 0000 11 11: 376
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376}
# raw key value: 0000 0110 11 00: 112
# pcs key: 0110
# raw key value: 0000 0001 01 10: 254
# pcs key: 0001
# raw key value: 0000 0101 11 11: 191
# pcs key: 0101
# raw key value: 0000 1011 00 11: 135
# pcs key: 1011
# raw key value: 0000 1100 11 00: 81
# pcs key: 1100
# raw key value: 0000 1110 00 01: 101
# pcs key: 1110
# raw key value: 0000 0011 00 11: 153
# pcs key: 0011
# raw key value: 0000 0010 11 01: 244
# pcs key: 0010
# raw key value: 0000 1010 01 11: 159
# pcs key: 1010
# raw key value: 0000 0101 01 10: 194
# pcs key: 0101
# raw key value: 0000 1011 11 00: 130
# pcs key: 1011
# raw key value: 0000 1011 10 00: 109
# pcs key: 1011
# raw key value: 0000 0110 01 00: 144
# pcs key: 0110
# raw key value: 0000 1010 00 01: 183
# pcs key: 1010
# raw key value: 0000 0000 10 00: 408
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408}
# raw key value: 0000 0101 11 01: 195
# pcs key: 0101
# raw key value: 0000 1011 00 01: 113
# pcs key: 1011
# raw key value: 0000 0001 11 11: 204
# pcs key: 0001
# raw key value: 0000 0000 01 10: 317
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408, '0000 0000 01 10': 317}
# raw key value: 0000 0010 11 11: 212
# pcs key: 0010
# raw key value: 0000 0011 00 01: 150
# pcs key: 0011
# raw key value: 0000 0011 11 11: 181
# pcs key: 0011
# raw key value: 0000 0010 00 01: 238
# pcs key: 0010
# raw key value: 0000 0000 10 10: 292
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408, '0000 0000 01 10': 317, '0000 0000 10 10': 292}
# raw key value: 0000 1111 00 01: 90
# pcs key: 1111
# raw key value: 0000 0001 00 11: 237
# pcs key: 0001
# raw key value: 0000 0110 11 11: 127
# pcs key: 0110
# raw key value: 0000 0110 00 10: 120
# pcs key: 0110
# raw key value: 0000 0100 01 11: 181
# pcs key: 0100
# raw key value: 0000 0111 10 11: 141
# pcs key: 0111
# raw key value: 0000 0111 10 01: 113
# pcs key: 0111
# raw key value: 0000 1111 11 10: 108
# pcs key: 1111
# raw key value: 0000 1001 11 01: 106
# pcs key: 1001
# raw key value: 0000 0001 11 01: 243
# pcs key: 0001
# raw key value: 0000 0110 00 11: 124
# pcs key: 0110
# raw key value: 0000 0001 00 01: 266
# pcs key: 0001
# raw key value: 0000 0001 01 01: 250
# pcs key: 0001
# raw key value: 0000 1010 11 01: 228
# pcs key: 1010
# raw key value: 0000 0000 10 11: 405
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408, '0000 0000 01 10': 317, '0000 0000 10 10': 292, '0000 0000 10 11': 405}
# raw key value: 0000 0111 01 00: 132
# pcs key: 0111
# raw key value: 0000 0100 10 10: 147
# pcs key: 0100
# raw key value: 0000 0000 01 11: 372
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408, '0000 0000 01 10': 317, '0000 0000 10 10': 292, '0000 0000 10 11': 405, '0000 0000 01 11': 372}
# raw key value: 0000 0101 00 11: 165
# pcs key: 0101
# raw key value: 0000 1011 11 11: 119
# pcs key: 1011
# raw key value: 0000 1010 01 10: 188
# pcs key: 1010
# raw key value: 0000 1011 11 10: 128
# pcs key: 1011
# raw key value: 0000 0101 00 00: 156
# pcs key: 0101
# raw key value: 0000 1110 10 00: 94
# pcs key: 1110
# raw key value: 0000 0101 00 10: 185
# pcs key: 0101
# raw key value: 0000 0011 11 00: 180
# pcs key: 0011
# raw key value: 0000 0010 01 00: 208
# pcs key: 0010
# raw key value: 0000 0001 11 10: 242
# pcs key: 0001
# raw key value: 0000 1000 11 10: 164
# pcs key: 1000
# raw key value: 0000 0110 10 10: 128
# pcs key: 0110
# raw key value: 0000 0000 01 00: 373
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408, '0000 0000 01 10': 317, '0000 0000 10 10': 292, '0000 0000 10 11': 405, '0000 0000 01 11': 372, '0000 0000 01 00': 373}
# raw key value: 0000 0111 10 10: 98
# pcs key: 0111
# raw key value: 0000 0100 01 00: 184
# pcs key: 0100
# raw key value: 0000 1011 10 01: 111
# pcs key: 1011
# raw key value: 0000 1001 01 11: 126
# pcs key: 1001
# raw key value: 0000 0110 10 11: 101
# pcs key: 0110
# raw key value: 0000 0101 10 01: 185
# pcs key: 0101
# raw key value: 0000 0001 00 10: 235
# pcs key: 0001
# raw key value: 0000 0110 00 00: 114
# pcs key: 0110
# raw key value: 0000 1111 10 11: 108
# pcs key: 1111
# raw key value: 0000 0010 11 10: 233
# pcs key: 0010
# raw key value: 0000 0011 00 10: 149
# pcs key: 0011
# raw key value: 0000 1000 01 00: 210
# pcs key: 1000
# raw key value: 0000 1111 11 11: 89
# pcs key: 1111
# raw key value: 0000 0001 01 11: 240
# pcs key: 0001
# raw key value: 0000 1010 00 11: 171
# pcs key: 1010
# raw key value: 0000 0100 01 10: 170
# pcs key: 0100
# raw key value: 0000 0111 11 00: 125
# pcs key: 0111
# raw key value: 0000 1011 00 00: 116
# pcs key: 1011
# raw key value: 0000 0101 11 10: 208
# pcs key: 0101
# raw key value: 0000 0100 10 00: 209
# pcs key: 0100
# raw key value: 0000 1000 00 11: 174
# pcs key: 1000
# raw key value: 0000 1100 10 10: 78
# pcs key: 1100
# raw key value: 0000 1110 00 11: 85
# pcs key: 1110
# raw key value: 0000 0011 10 11: 169
# pcs key: 0011
# raw key value: 0000 0010 01 01: 256
# pcs key: 0010
# raw key value: 0000 1111 01 11: 90
# pcs key: 1111
# raw key value: 0000 0010 10 11: 227
# pcs key: 0010
# raw key value: 0000 0011 01 01: 160
# pcs key: 0011
# raw key value: 0000 0000 11 10: 278
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408, '0000 0000 01 10': 317, '0000 0000 10 10': 292, '0000 0000 10 11': 405, '0000 0000 01 11': 372, '0000 0000 01 00': 373, '0000 0000 11 10': 278}
# raw key value: 0000 1000 10 10: 177
# pcs key: 1000
# raw key value: 0000 1010 01 01: 220
# pcs key: 1010
# raw key value: 0000 1101 01 10: 98
# pcs key: 1101
# raw key value: 0000 0111 11 11: 122
# pcs key: 0111
# raw key value: 0000 0100 00 11: 168
# pcs key: 0100
# raw key value: 0000 1011 10 10: 121
# pcs key: 1011
# raw key value: 0000 0101 01 00: 154
# pcs key: 0101
# raw key value: 0000 1111 10 10: 95
# pcs key: 1111
# raw key value: 0000 0011 10 00: 150
# pcs key: 0011
# raw key value: 0000 0001 10 10: 258
# pcs key: 0001
# raw key value: 0000 1001 00 00: 113
# pcs key: 1001
# raw key value: 0000 1110 01 11: 73
# pcs key: 1110
# raw key value: 0000 1100 11 10: 94
# pcs key: 1100
# raw key value: 0000 1110 11 11: 82
# pcs key: 1110
# raw key value: 0000 1100 01 00: 102
# pcs key: 1100
# raw key value: 0000 1110 00 00: 98
# pcs key: 1110
# raw key value: 0000 1100 10 11: 76
# pcs key: 1100
# raw key value: 0000 1111 00 10: 76
# pcs key: 1111
# raw key value: 0000 0010 11 00: 218
# pcs key: 0010
# raw key value: 0000 0011 01 00: 153
# pcs key: 0011
# raw key value: 0000 1011 01 00: 105
# pcs key: 1011
# raw key value: 0000 0101 10 10: 172
# pcs key: 0101
# raw key value: 0000 1001 01 00: 128
# pcs key: 1001
# raw key value: 0000 1110 11 01: 92
# pcs key: 1110
# raw key value: 0000 1100 01 10: 96
# pcs key: 1100
# raw key value: 0000 1101 11 01: 105
# pcs key: 1101
# raw key value: 0000 0010 10 01: 241
# pcs key: 0010
# raw key value: 0000 1101 10 00: 65
# pcs key: 1101
# raw key value: 0000 0101 10 11: 166
# pcs key: 0101
# raw key value: 0000 1011 01 11: 101
# pcs key: 1011
# raw key value: 0000 1110 11 10: 71
# pcs key: 1110
# raw key value: 0000 1100 01 11: 111
# pcs key: 1100
# raw key value: 0000 1000 01 01: 157
# pcs key: 1000
# raw key value: 0000 1000 01 11: 192
# pcs key: 1000
# raw key value: 0000 1010 00 10: 185
# pcs key: 1010
# raw key value: 0000 1001 00 01: 117
# pcs key: 1001
# raw key value: 0000 0111 00 11: 119
# pcs key: 0111
# raw key value: 0000 0100 11 11: 203
# pcs key: 0100
# raw key value: 0000 1001 10 01: 131
# pcs key: 1001
# raw key value: 0000 1010 00 00: 153
# pcs key: 1010
# raw key value: 0000 0000 10 01: 280
# pcs key: 0000
# filtered results: {'0000 0000 00 10': 313, '0000 0000 11 01': 303, '0000 0000 11 00': 406, '0000 0000 00 11': 372, '0000 0000 01 01': 292, '0000 0000 00 00': 385, '0000 0000 00 01': 315, '0000 0000 11 11': 376, '0000 0000 10 00': 408, '0000 0000 01 10': 317, '0000 0000 10 10': 292, '0000 0000 10 11': 405, '0000 0000 01 11': 372, '0000 0000 01 00': 373, '0000 0000 11 10': 278, '0000 0000 10 01': 280}
# raw key value: 0000 0010 00 00: 219
# pcs key: 0010
# raw key value: 0000 1110 10 10: 103
# pcs key: 1110
# raw key value: 0000 1100 00 11: 94
# pcs key: 1100
# raw key value: 0000 1010 10 10: 188
# pcs key: 1010
# raw key value: 0000 1001 00 11: 111
# pcs key: 1001
# raw key value: 0000 1010 10 11: 184
# pcs key: 1010
# raw key value: 0000 0001 10 01: 218
# pcs key: 0001
# raw key value: 0000 0111 01 11: 108
# pcs key: 0111
# raw key value: 0000 0100 10 11: 173
# pcs key: 0100
# raw key value: 0000 1100 00 10: 86
# pcs key: 1100
# raw key value: 0000 0100 10 01: 178
# pcs key: 0100
# raw key value: 0000 1100 01 01: 82
# pcs key: 1100
# raw key value: 0000 1101 10 01: 98
# pcs key: 1101
# raw key value: 0000 1000 00 10: 156
# pcs key: 1000
# raw key value: 0000 0101 11 00: 140
# pcs key: 0101
# raw key value: 0000 1011 01 10: 114
# pcs key: 1011
# raw key value: 0000 1111 01 00: 105
# pcs key: 1111
# raw key value: 0000 1101 10 10: 108
# pcs key: 1101
# raw key value: 0000 0001 10 11: 235
# pcs key: 0001
# raw key value: 0000 0010 10 00: 250
# pcs key: 0010
# raw key value: 0000 1000 10 01: 153
# pcs key: 1000
# raw key value: 0000 1001 00 10: 107
# pcs key: 1001
# raw key value: 0000 1010 11 11: 173
# pcs key: 1010
# raw key value: 0000 1001 01 01: 119
# pcs key: 1001
# raw key value: 0000 1110 00 10: 100
# pcs key: 1110
# raw key value: 0000 0001 01 00: 231
# pcs key: 0001
# raw key value: 0000 0011 10 01: 143
# pcs key: 0011
# raw key value: 0000 1100 10 00: 86
# pcs key: 1100
# raw key value: 0000 1101 11 00: 83
# pcs key: 1101
# raw key value: 0000 0111 00 10: 134
# pcs key: 0111
# raw key value: 0000 1101 10 11: 79
# pcs key: 1101
# raw key value: 0000 0111 10 00: 117
# pcs key: 0111
# raw key value: 0000 1101 00 11: 72
# pcs key: 1101
# raw key value: 0000 1110 10 01: 105
# pcs key: 1110
# raw key value: 0000 1110 10 11: 87
# pcs key: 1110
# raw key value: 0000 1100 00 00: 72
# pcs key: 1100
# raw key value: 0000 1111 00 11: 83
# pcs key: 1111
# raw key value: 0000 1001 10 11: 117
# pcs key: 1001
# raw key value: 0000 1001 10 10: 102
# pcs key: 1001
# raw key value: 0000 1001 11 10: 115
# pcs key: 1001
# raw key value: 0000 0100 01 01: 130
# pcs key: 0100
# raw key value: 0000 0111 11 10: 114
# pcs key: 0111
# raw key value: 0000 0100 00 00: 182
# pcs key: 0100
# raw key value: 0000 0110 11 01: 127
# pcs key: 0110
# raw key value: 0000 1001 11 11: 107
# pcs key: 1001
# raw key value: 0000 1000 00 00: 184
# pcs key: 1000
# raw key value: 0000 1000 01 10: 190
# pcs key: 1000
# raw key value: 0000 1101 00 00: 81
# pcs key: 1101
# raw key value: 0000 1101 01 01: 106
# pcs key: 1101
# raw key value: 0000 1001 01 10: 114
# pcs key: 1001
# raw key value: 0000 1111 11 01: 79
# pcs key: 1111
# raw key value: 0000 0101 10 00: 166
# pcs key: 0101
# raw key value: 0000 0110 11 10: 115
# pcs key: 0110
# raw key value: 0000 1000 11 00: 184
# pcs key: 1000
# raw key value: 0000 1100 10 01: 88
# pcs key: 1100
# raw key value: 0000 1100 11 11: 107
# pcs key: 1100
# raw key value: 0000 1110 01 00: 76
# pcs key: 1110
# raw key value: 0000 1100 11 01: 85
# pcs key: 1100
# raw key value: 0000 1110 01 10: 112
# pcs key: 1110
# raw key value: 0000 1101 11 10: 93
# pcs key: 1101
# raw key value: 0000 0100 00 10: 158
# pcs key: 0100
# raw key value: 0000 1111 01 01: 72
# pcs key: 1111
# raw key value: 0000 1111 01 10: 70
# pcs key: 1111
# raw key value: 0000 1111 00 00: 87
# pcs key: 1111
# raw key value: 0000 0001 00 00: 214
# pcs key: 0001
# raw key value: 0000 1111 11 00: 84
# pcs key: 1111
# raw key value: 0000 0011 11 01: 146
# pcs key: 0011
# raw key value: 0000 0010 00 11: 226
# pcs key: 0010
# raw key value: 0000 1000 00 01: 145
# pcs key: 1000
# raw key value: 0000 1110 01 01: 90
# pcs key: 1110
# raw key value: 0000 0110 10 00: 105
# pcs key: 0110
# raw key value: 0000 1011 01 01: 121
# pcs key: 1011
# raw key value: 0000 1101 01 11: 85
# pcs key: 1101
# raw key value: 0000 1101 01 00: 84
# pcs key: 1101
# raw key value: 0000 1011 00 10: 111
# pcs key: 1011
# raw key value: 0000 0110 00 01: 125
# pcs key: 0110
# raw key value: 0000 0110 10 01: 116
# pcs key: 0110
# raw key value: 0000 0111 01 01: 122
# pcs key: 0111
# collected vals:  {'00': 1465, '10': 1271, '01': 1290, '11': 1432}
# collected vals:  {'11': 1305, '01': 1423, '00': 1292, '10': 1454}
# collected vals:  {'10': 1200, '01': 1190, '00': 1572, '11': 1525}
# 0.3103904789031462

# %%
print(pcs_fidelity)
print(pcs_post_select_rates)
# reps=2
with open(f"json\\pcsXZ_flyingq_unbiased.json", "w") as fxz:
        json.dump({"errors": errors.tolist(), "fidelities": pcs_all_fidelities, "postselectRates": pcs_post_select_rates}, fxz)
with open("json\\raw_unbiased.json") as fRaw:
        dataRaw=json.load(fRaw)
nopcs_all_fidelities=dataRaw["fidelities"]
plt.plot(errors, pcs_all_fidelities, label="PCS X&Z Fidelity", marker='o')
plt.plot(errors, nopcs_all_fidelities, label="No PCS Fidelity", marker='o')
plt.plot(errors, pcs_post_select_rates, label="PCS X&Z Postselection rate",  marker='^', linestyle="--")
plt.ylabel('Probability')
plt.xlabel(f"Depolarizing Error Rate")
plt.text(0.25, .75, f"Single qubit gate error: {error_gate1}\nTwo qubit gate error: {round(error_gate1*10, 4)}", color = "red")
plt.title(f"Entanglement Swapping: PCS X&Z on Flying Qubits")
plt.legend()
plt.savefig(f"images\\pcsXZ_flyingq_equal_depol.png")
plt.show()
# Out:
# 0.3103904789031462
# [0.943375, 0.77215, 0.632475, 0.51695, 0.424175, 0.34355, 0.283875, 0.232, 0.195025, 0.161325, 0.13645]
