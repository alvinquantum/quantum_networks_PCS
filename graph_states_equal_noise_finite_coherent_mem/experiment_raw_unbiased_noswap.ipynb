# %%
#!/usr/bin/env python3
import qiskit
from qiskit import (
    QuantumCircuit,
    QuantumRegister,
    ClassicalRegister,
    transpile
)
from qiskit.quantum_info import (
    Kraus, 
    SuperOp,
)
from qiskit_aer.noise import(
    depolarizing_error,
    phase_damping_error,
    NoiseModel,
    QuantumError,
    amplitude_damping_error,
)
# from qiskit_ibm_provider import IBMProvider
from qiskit import Aer
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np
import math
import sys
sys.path.append('../')
import utilities as utl
import importlib
import json
importlib.reload(utl)

def heralded_circ():
    '''raw entanglment swapping.'''
    qr_a=QuantumRegister(2, "alice")
    cr_epr=ClassicalRegister(2, "cr_epr")
    cr_h=ClassicalRegister(2, "cr_heralded")

    qc=QuantumCircuit(qr_a, cr_epr, cr_h)
    # Bell States
    qc.h(qr_a[1])
    qc.cx(qr_a[1], qr_a[0])
    # Channel
    qc.id(qr_a)
    # Entanglement swap
    qc.barrier()
    return qc, qr_a, cr_epr

# %%
SHOTS=10000
rawFidelities=[]
errors=np.linspace(0.0, stop=0.5, num=11, endpoint=True)
#no pcs
qc, qr_a, cr_epr = heralded_circ()
error_gate1=0.001
for idx, error in enumerate(errors):
        print(f"depolarizing error: {error}")
        noise_model=utl.get_noise_model(error_gate1)
        errorPChannel=depolarizing_error(error, 1)
        noise_model.add_all_qubit_quantum_error(errorPChannel, ["id"])
        print(noise_model)
        backend=AerSimulator(noise_model=noise_model)
       
        # print(qc)
        rawResultxx=utl.meas_xx(qc, [qr_a[1], qr_a[0]], cr_epr, backend, SHOTS)
        rawResultyy=utl.meas_yy(qc, [qr_a[1], qr_a[0]], cr_epr, backend, SHOTS)
        rawResultzz=utl.meas_zz(qc, [qr_a[1], qr_a[0]], cr_epr, backend, SHOTS)

        epr_idx=-1 #the position of the classical registers that contain measurements of the 
                #epr pair.
        rawExpectxx=utl.expect_of_vals(utl.to_percent(utl.collect_meas(rawResultxx.get_counts(), epr_idx)))
        rawExpectyy=utl.expect_of_vals(utl.to_percent(utl.collect_meas(rawResultyy.get_counts(), epr_idx)))
        rawExpectzz=utl.expect_of_vals(utl.to_percent(utl.collect_meas(rawResultzz.get_counts(), epr_idx)))
        rawFidelity=utl.fidelity_phip(rawExpectxx, rawExpectyy, rawExpectzz)
        rawFidelities.append(rawFidelity)
        print(f"noisy no pcs fidelity: {rawFidelity}")
print(f"raw fidelities: {rawFidelities}")
with open("json\\raw_unbiased_noswap.json", "w") as file:
        json.dump({"errors": errors.tolist(),"fidelities": rawFidelities}, file)
# Out:
# depolarizing error: 0.0
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'11': 5032, '00': 4879, '01': 43, '10': 46}
# collected vals:  {'01': 4891, '10': 5035, '00': 35, '11': 39}
# collected vals:  {'11': 4944, '00': 4996, '10': 29, '01': 31}
# noisy no pcs fidelity: 0.9888499999999999
# depolarizing error: 0.05
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'00': 4702, '11': 4737, '01': 274, '10': 287}
# collected vals:  {'10': 4711, '01': 4753, '11': 247, '00': 289}
# collected vals:  {'00': 4698, '11': 4731, '10': 297, '01': 274}
# noisy no pcs fidelity: 0.9166
# depolarizing error: 0.1
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'00': 4559, '10': 532, '11': 4423, '01': 486}
# collected vals:  {'01': 4477, '10': 4473, '11': 513, '00': 537}
# collected vals:  {'00': 4538, '01': 499, '11': 4494, '10': 469}
# noisy no pcs fidelity: 0.8482000000000001
# depolarizing error: 0.15000000000000002
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'00': 4286, '10': 739, '01': 738, '11': 4237}
# collected vals:  {'00': 715, '10': 4172, '01': 4365, '11': 748}
# collected vals:  {'00': 4287, '10': 708, '11': 4267, '01': 738}
# noisy no pcs fidelity: 0.7807
# depolarizing error: 0.2
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'11': 4047, '10': 942, '00': 4097, '01': 914}
# collected vals:  {'01': 4077, '11': 951, '00': 972, '10': 4000}
# collected vals:  {'00': 4157, '11': 4035, '10': 902, '01': 906}
# noisy no pcs fidelity: 0.72065
# depolarizing error: 0.25
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'11': 3884, '00': 3873, '01': 1108, '10': 1135}
# collected vals:  {'10': 3744, '11': 1142, '01': 3945, '00': 1169}
# collected vals:  {'11': 3880, '01': 1069, '10': 1102, '00': 3949}
# noisy no pcs fidelity: 0.66375
# depolarizing error: 0.30000000000000004
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'10': 1300, '00': 3732, '11': 3739, '01': 1229}
# collected vals:  {'11': 1312, '01': 3678, '10': 3694, '00': 1316}
# collected vals:  {'00': 3680, '11': 3750, '10': 1293, '01': 1277}
# noisy no pcs fidelity: 0.61365
# depolarizing error: 0.35000000000000003
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'00': 3466, '11': 3650, '01': 1472, '10': 1412}
# collected vals:  {'01': 3565, '10': 3483, '11': 1468, '00': 1484}
# collected vals:  {'00': 3498, '11': 3583, '01': 1463, '10': 1456}
# noisy no pcs fidelity: 0.56225
# depolarizing error: 0.4
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'11': 3360, '01': 1594, '10': 1631, '00': 3415}
# collected vals:  {'01': 3305, '10': 3458, '11': 1693, '00': 1544}
# collected vals:  {'00': 3403, '10': 1596, '11': 3374, '01': 1627}
# noisy no pcs fidelity: 0.5157499999999999
# depolarizing error: 0.45
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'11': 3194, '01': 1739, '00': 3300, '10': 1767}
# collected vals:  {'10': 3170, '01': 3237, '11': 1766, '00': 1827}
# collected vals:  {'00': 3218, '11': 3330, '10': 1754, '01': 1698}
# noisy no pcs fidelity: 0.47245000000000004
# depolarizing error: 0.5
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['cx', 'h', 'ccx', 'z', 'measure', 'id', 'rz', 'y', 'x', 'cz']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure', 'id']
# xx circ:
#                     ┌───┐┌───┐ ░ ┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└╥┘ ║
#      cr_epr: 2/════════════════════════╩══╩═
#                                        0  1
# cr_heralded: 2/═════════════════════════════
#
# xx circ:  OrderedDict([('h', 3), ('id', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# yy circ:
#                     ┌───┐┌───┐ ░ ┌───┐┌───┐   ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░─┤ S ├┤ H ├───┤M├
#                ┌───┐└─┬─┘├───┤ ░ ├───┤├───┤┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤ S ├┤ H ├┤M├─╫─
#                └───┘     └───┘ ░ └───┘└───┘└╥┘ ║
#      cr_epr: 2/═════════════════════════════╩══╩═
#                                             0  1
# cr_heralded: 2/══════════════════════════════════
#
# yy circ:  OrderedDict([('h', 3), ('id', 2), ('s', 2), ('measure', 2), ('cx', 1), ('barrier', 1)])
# zz circ:
#                     ┌───┐┌───┐ ░    ┌─┐
#       alice_0: ─────┤ X ├┤ I ├─░────┤M├
#                ┌───┐└─┬─┘├───┤ ░ ┌─┐└╥┘
#       alice_1: ┤ H ├──■──┤ I ├─░─┤M├─╫─
#                └───┘     └───┘ ░ └╥┘ ║
#      cr_epr: 2/═══════════════════╩══╩═
#                                   0  1
# cr_heralded: 2/════════════════════════
#
# zz circ:  OrderedDict([('id', 2), ('measure', 2), ('h', 1), ('cx', 1), ('barrier', 1)])
# collected vals:  {'01': 1910, '00': 3161, '11': 3034, '10': 1895}
# collected vals:  {'10': 3129, '01': 3053, '11': 1921, '00': 1897}
# collected vals:  {'01': 1886, '11': 3204, '00': 3018, '10': 1892}
# noisy no pcs fidelity: 0.42995
# raw fidelities: [0.9888499999999999, 0.9166, 0.8482000000000001, 0.7807, 0.72065, 0.66375, 0.61365, 0.56225, 0.5157499999999999, 0.47245000000000004, 0.42995]
