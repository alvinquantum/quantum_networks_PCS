# %%
#!/usr/bin/env python3
import qiskit
from qiskit import (
    QuantumCircuit,
    QuantumRegister,
    ClassicalRegister,
    transpile
)
from qiskit.quantum_info import (
    Kraus, 
    SuperOp,
)
from qiskit_aer.noise import(
    depolarizing_error,
    phase_damping_error,
    NoiseModel,
    QuantumError,
    amplitude_damping_error,
)
# from qiskit_ibm_provider import IBMProvider
from qiskit import Aer
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from copy import deepcopy
import numpy as np
import math
import sys
sys.path.append('../')
import utilities as utl
import importlib
import json
importlib.reload(utl)

SHOTS=40000
def _graph_pcsZ(qc, qreg):
    for idx in list(range(qreg.size)):
        qc.h(qreg[idx])
    qc.cz(qreg[0],qreg[2])
    qc.cz(qreg[0],qreg[1])
    qc.cx(qreg[3],qreg[0])
    qc.barrier()
    qc.id(qreg)
    qc.barrier()
    qc.cx(qreg[3],qreg[0])
    qc.cz(qreg[2],qreg[0])
    qc.h([qreg[3], qreg[2]])
    return qc

# %%
tot_pcs_ancillas=4
a_qreg=QuantumRegister(4, "a")
b_qreg=QuantumRegister(4, "b")
pcs_creg=ClassicalRegister(4,"pcs")
bsm_creg=ClassicalRegister(2, "bsm")
epr_creg=ClassicalRegister(2, "epr")
junk_creg=ClassicalRegister(4, "junk") #for removing and connecting nodes
qc=QuantumCircuit(a_qreg, b_qreg, epr_creg, bsm_creg, pcs_creg, junk_creg)
qc=_graph_pcsZ(qc, a_qreg)
qc=_graph_pcsZ(qc, b_qreg)
# # x and z measurement to connect and remove nodes, respectively.
# qc.barrier()
# qc.measure(a_qreg[2], junk_creg[0])
# qc.measure(b_qreg[2], junk_creg[1])
# qc.measure(a_qreg[4], junk_creg[2])
# qc.measure(b_qreg[4], junk_creg[3])

# PCS measurements.
qc.barrier()
qc.measure(a_qreg[2], pcs_creg[0])
qc.measure(b_qreg[2], pcs_creg[1])
qc.measure(a_qreg[3], pcs_creg[2])
qc.measure(b_qreg[3], pcs_creg[3])
# Convert 2 qubit graph states to bell States.
qc.h(a_qreg[0])
qc.h(b_qreg[0])

#BSM measurement.
qc.barrier()
qc.cx(a_qreg[1], b_qreg[1])
qc.h(a_qreg[1])
qc.measure(a_qreg[1], bsm_creg[0])
qc.measure(b_qreg[1], bsm_creg[1])
utl._add_fixing_gates(qc, a_qreg, bsm_creg, 0)
qc.draw(fold=-1)
# Out:
#         ┌───┐      ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░           »
#    a_0: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │  │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░           »
#    a_1: ┤ H ├─┼──■───┼───░─┤ I ├─░───┼────┼─────────────░───────░───────────»
#         ├───┤ │      │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐     »
#    b_0: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │    │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_1: ─────────────────░───────░─┤ H ├──┼────■────┼───░─┤ I ├─░───┼────┼──»
#                          ░       ░ ├───┤  │         │   ░ ├───┤ ░   │    │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘
# «   a_1: ──────────────────────────────────────────────────────────
# «
# «   a_2: ──────────────────────────────────────────────────────────
# «
# «   a_3: ──────────────────────────────────────────────────────────
# «
# «   b_0: ──────────────────────────────────────────────────────────
# «
# «   b_1: ──────────────────────────────────────────────────────────
# «
# «   b_2: ──────────────────────────────────────────────────────────
# «
# «   b_3: ──────────────────────────────────────────────────────────
# «
# « epr: 2/══════════════════════════════════════════════════════════
# «
# « bsm: 2/══════════════════════════════════════════════════════════
# «
# « pcs: 4/══════════════════════════════════════════════════════════
# «
# «junk: 4/══════════════════════════════════════════════════════════
# «

# %%
pcs_all_fidelities=[]
pcs_post_select_rates=[]
errors=np.linspace(0.0, stop=0.5, num=11, endpoint=True)
error_gate1=0.001
for error in errors:
        noise_model=utl.get_noise_model(error_gate1)
        print(f"depolarizing error: {error}")
        depol1=depolarizing_error(error, 1)
        noise_model.add_all_qubit_quantum_error(depol1, ["id"])
        print(noise_model)

        backend=AerSimulator(noise_model=noise_model)
        pcs_ancillas_pos=1 # the position of the classical registers that contain the pcs measurements.
        result_xx=utl.meas_xx(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_yy=utl.meas_yy(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)
        result_zz=utl.meas_zz(qc, [a_qreg[0], b_qreg[0]], epr_creg, backend, SHOTS)

        xx_counts=utl.post_select(result_xx.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        yy_counts=utl.post_select(result_yy.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        zz_counts=utl.post_select(result_zz.get_counts(), tot_pcs_ancillas, pcs_ancillas_pos)
        pcs_post_select_rates.append(min([sum(xx_counts.values()),sum(yy_counts.values()),sum(zz_counts.values())])/SHOTS)
        epr_idx=-1 #the position of the classical registers that contain measurements of the 
                #epr pair.
        expect_xx=utl.expect_of_vals(utl.to_percent(utl.collect_meas(xx_counts, epr_idx)))
        expect_yy=utl.expect_of_vals(utl.to_percent(utl.collect_meas(yy_counts, epr_idx)))
        expect_zz=utl.expect_of_vals(utl.to_percent(utl.collect_meas(zz_counts, epr_idx)))
        pcs_fidelity=utl.fidelity_phip(expect_xx, expect_yy, expect_zz)
        print(pcs_fidelity)
        pcs_all_fidelities.append(pcs_fidelity)
# Out:
# depolarizing error: 0.0
# NoiseModel:
#   Basis gates: ['ccx', 'cx', 'cz', 'h', 'id', 'rz', 'sx', 'x', 'y', 'z']
#   Instructions with noise: ['h', 'measure', 'z', 'y', 'rz', 'cx', 'cz', 'ccx', 'x']
#   All-qubits errors: ['cx', 'cz', 'ccx', 'h', 'x', 'y', 'z', 'rz', 'measure']
# xx circ:
#         ┌───┐      ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░           »
#    a_0: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │  │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░           »
#    a_1: ┤ H ├─┼──■───┼───░─┤ I ├─░───┼────┼─────────────░───────░───────────»
#         ├───┤ │      │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐     »
#    b_0: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │    │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_1: ─────────────────░───────░─┤ H ├──┼────■────┼───░─┤ I ├─░───┼────┼──»
#                          ░       ░ ├───┤  │         │   ░ ├───┤ ░   │    │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐   ┌─┐
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ H ├───┤M├
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘   └╥┘
# «   a_1: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_2: ───────────────────────────────────────────────────────────────────╫─
# «                                                                           ║
# «   a_3: ───────────────────────────────────────────────────────────────────╫─
# «                                                                  ┌───┐┌─┐ ║
# «   b_0: ──────────────────────────────────────────────────────────┤ H ├┤M├─╫─
# «                                                                  └───┘└╥┘ ║
# «   b_1: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_2: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# «   b_3: ────────────────────────────────────────────────────────────────╫──╫─
# «                                                                        ║  ║
# « epr: 2/════════════════════════════════════════════════════════════════╩══╩═
# «                                                                        1  0
# « bsm: 2/═════════════════════════════════════════════════════════════════════
# «
# « pcs: 4/═════════════════════════════════════════════════════════════════════
# «
# «junk: 4/═════════════════════════════════════════════════════════════════════
# «
# xx circ:  OrderedDict([('h', 17), ('id', 8), ('measure', 8), ('barrier', 7), ('cz', 6), ('cx', 5), ('switch_case', 1)])
# yy circ:
#         ┌───┐      ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░           »
#    a_0: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │  │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░           »
#    a_1: ┤ H ├─┼──■───┼───░─┤ I ├─░───┼────┼─────────────░───────░───────────»
#         ├───┤ │      │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐     »
#    b_0: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │    │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_1: ─────────────────░───────░─┤ H ├──┼────■────┼───░─┤ I ├─░───┼────┼──»
#                          ░       ░ ├───┤  │         │   ░ ├───┤ ░   │    │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐ ┌───┐┌───┐»
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├─┤ S ├┤ H ├»
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘ └───┘└───┘»
# «   a_1: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   a_2: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   a_3: ────────────────────────────────────────────────────────────────────»
# «                                                                  ┌───┐┌───┐»
# «   b_0: ──────────────────────────────────────────────────────────┤ S ├┤ H ├»
# «                                                                  └───┘└───┘»
# «   b_1: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   b_2: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «   b_3: ────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « epr: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# « bsm: 2/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# « pcs: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «junk: 4/════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «           ┌─┐
# «   a_0: ───┤M├
# «           └╥┘
# «   a_1: ────╫─
# «            ║
# «   a_2: ────╫─
# «            ║
# «   a_3: ────╫─
# «        ┌─┐ ║
# «   b_0: ┤M├─╫─
# «        └╥┘ ║
# «   b_1: ─╫──╫─
# «         ║  ║
# «   b_2: ─╫──╫─
# «         ║  ║
# «   b_3: ─╫──╫─
# «         ║  ║
# « epr: 2/═╩══╩═
# «         1  0
# « bsm: 2/══════
# «
# « pcs: 4/══════
# «
# «junk: 4/══════
# «
# yy circ:  OrderedDict([('h', 17), ('id', 8), ('measure', 8), ('barrier', 7), ('cz', 6), ('cx', 5), ('s', 2), ('switch_case', 1)])
# zz circ:
#         ┌───┐      ┌───┐ ░ ┌───┐ ░ ┌───┐                ░       ░           »
#    a_0: ┤ H ├─■──■─┤ X ├─░─┤ I ├─░─┤ X ├──■─────────────░───────░───────────»
#         ├───┤ │  │ └─┬─┘ ░ ├───┤ ░ └─┬─┘  │             ░       ░           »
#    a_1: ┤ H ├─┼──■───┼───░─┤ I ├─░───┼────┼─────────────░───────░───────────»
#         ├───┤ │      │   ░ ├───┤ ░   │    │  ┌───┐      ░       ░           »
#    a_2: ┤ H ├─■──────┼───░─┤ I ├─░───┼────■──┤ H ├──────░───────░───────────»
#         ├───┤        │   ░ ├───┤ ░   │  ┌───┐└───┘      ░       ░           »
#    a_3: ┤ H ├────────■───░─┤ I ├─░───■──┤ H ├───────────░───────░───────────»
#         └───┘            ░ └───┘ ░ ┌───┐└───┘     ┌───┐ ░ ┌───┐ ░ ┌───┐     »
#    b_0: ─────────────────░───────░─┤ H ├──■────■──┤ X ├─░─┤ I ├─░─┤ X ├──■──»
#                          ░       ░ ├───┤  │    │  └─┬─┘ ░ ├───┤ ░ └─┬─┘  │  »
#    b_1: ─────────────────░───────░─┤ H ├──┼────■────┼───░─┤ I ├─░───┼────┼──»
#                          ░       ░ ├───┤  │         │   ░ ├───┤ ░   │    │  »
#    b_2: ─────────────────░───────░─┤ H ├──■─────────┼───░─┤ I ├─░───┼────■──»
#                          ░       ░ ├───┤            │   ░ ├───┤ ░   │  ┌───┐»
#    b_3: ─────────────────░───────░─┤ H ├────────────■───░─┤ I ├─░───■──┤ H ├»
#                          ░       ░ └───┘                ░ └───┘ ░      └───┘»
#  epr: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  bsm: 2/════════════════════════════════════════════════════════════════════»
#                                                                             »
#  pcs: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# junk: 4/════════════════════════════════════════════════════════════════════»
#                                                                             »
# «              ░ ┌───┐            ░               ░ ┌────────── ┌──────────── »
# «   a_0: ──────░─┤ H ├────────────░───────────────░─┤ Switch-0  ┤ Case-0 (1)  »
# «              ░ └───┘            ░      ┌───┐┌─┐ ░ └────╥───── └──────────── »
# «   a_1: ──────░──────────────────░───■──┤ H ├┤M├─░──────╫────────────────────»
# «              ░  ┌─┐             ░   │  └───┘└╥┘ ░      ║                    »
# «   a_2: ──────░──┤M├─────────────░───┼────────╫──░──────╫────────────────────»
# «              ░  └╥┘      ┌─┐    ░   │        ║  ░      ║                    »
# «   a_3: ──────░───╫───────┤M├────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  ┌───┐└╥┘    ░   │        ║  ░      ║                    »
# «   b_0: ──────░───╫──┤ H ├─╫─────░───┼────────╫──░──────╫────────────────────»
# «              ░   ║  └───┘ ║     ░ ┌─┴─┐ ┌─┐  ║  ░      ║                    »
# «   b_1: ──────░───╫────────╫─────░─┤ X ├─┤M├──╫──░──────╫────────────────────»
# «        ┌───┐ ░   ║   ┌─┐  ║     ░ └───┘ └╥┘  ║  ░      ║                    »
# «   b_2: ┤ H ├─░───╫───┤M├──╫─────░────────╫───╫──░──────╫────────────────────»
# «        └───┘ ░   ║   └╥┘  ║ ┌─┐ ░        ║   ║  ░      ║                    »
# «   b_3: ──────░───╫────╫───╫─┤M├─░────────╫───╫──░──────╫────────────────────»
# «              ░   ║    ║   ║ └╥┘ ░        ║   ║  ░      ║                    »
# « epr: 2/══════════╬════╬═══╬══╬═══════════╬═══╬═════════╬════════════════════»
# «                  ║    ║   ║  ║           ║   ║      ┌──╨──┐                 »
# « bsm: 2/══════════╬════╬═══╬══╬═══════════╩═══╩══════╡ 0x3 ╞═════════════════»
# «                  ║    ║   ║  ║           1   0      └─────┘                 »
# « pcs: 4/══════════╩════╩═══╩══╩══════════════════════════════════════════════»
# «                  0    1   2  3                                              »
# «junk: 4/═════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «        ┌───┐┌──────────── ┌───┐┌──────────── ┌───┐┌───┐ ───────┐    ┌─┐
# «   a_0: ┤ Z ├┤ Case-0 (2)  ┤ X ├┤ Case-0 (3)  ┤ X ├┤ Z ├  End-0 ├────┤M├
# «        └───┘└──────────── └───┘└──────────── └───┘└───┘ ───────┘    └╥┘
# «   a_1: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_2: ──────────────────────────────────────────────────────────────╫─
# «                                                                      ║
# «   a_3: ──────────────────────────────────────────────────────────────╫─
# «                                                                  ┌─┐ ║
# «   b_0: ──────────────────────────────────────────────────────────┤M├─╫─
# «                                                                  └╥┘ ║
# «   b_1: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_2: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# «   b_3: ───────────────────────────────────────────────────────────╫──╫─
# «                                                                   ║  ║
# « epr: 2/═══════════════════════════════════════════════════════════╩══╩═
# «                                                                   1  0
# « bsm: 2/════════════════════════════════════════════════════════════════
# «
# « pcs: 4/════════════════════════════════════════════════════════════════
# «
# «junk: 4/════════════════════════════════════════════════════════════════
# «
# zz circ:  OrderedDict([('h', 15), ('id', 8), ('measure', 8), ('barrier', 7), ('cz', 6), ('cx', 5), ('switch_case', 1)])
# raw key value: 0000 0000 01 11: 4608
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608}
# raw key value: 0000 0010 00 10: 47
# pcs key: 0010
# raw key value: 0000 0000 10 11: 4530
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530}
# raw key value: 0000 0000 11 11: 4592
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592}
# raw key value: 0000 1010 00 01: 18
# pcs key: 1010
# raw key value: 0000 0000 10 00: 4619
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619}
# raw key value: 0000 0000 00 00: 4535
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535}
# raw key value: 0000 1010 10 01: 22
# pcs key: 1010
# raw key value: 0000 0011 01 00: 1
# pcs key: 0011
# raw key value: 0000 0010 11 00: 55
# pcs key: 0010
# raw key value: 0000 0000 00 11: 4680
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680}
# raw key value: 0000 0011 11 01: 2
# pcs key: 0011
# raw key value: 0000 0010 00 11: 52
# pcs key: 0010
# raw key value: 0000 0000 11 00: 4633
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633}
# raw key value: 0000 0001 01 00: 64
# pcs key: 0001
# raw key value: 0000 0011 00 11: 1
# pcs key: 0011
# raw key value: 0000 0010 11 01: 42
# pcs key: 0010
# raw key value: 0000 0000 01 00: 4568
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568}
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 48
# pcs key: 0010
# raw key value: 0000 0100 01 11: 30
# pcs key: 0100
# raw key value: 0000 1010 10 00: 1
# pcs key: 1010
# raw key value: 0000 0000 00 01: 96
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96}
# raw key value: 0000 0001 00 11: 44
# pcs key: 0001
# raw key value: 0000 0010 10 11: 50
# pcs key: 0010
# raw key value: 0000 0100 01 00: 24
# pcs key: 0100
# raw key value: 0000 0000 00 10: 98
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96, '0000 0000 00 10': 98}
# raw key value: 0000 0100 00 00: 25
# pcs key: 0100
# raw key value: 0000 0000 01 10: 97
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96, '0000 0000 00 10': 98, '0000 0000 01 10': 97}
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0010 11 11: 47
# pcs key: 0010
# raw key value: 0000 1000 11 00: 32
# pcs key: 1000
# raw key value: 0000 0001 10 00: 48
# pcs key: 0001
# raw key value: 0000 0011 10 11: 4
# pcs key: 0011
# raw key value: 0000 0010 01 01: 57
# pcs key: 0010
# raw key value: 0000 0000 11 10: 91
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96, '0000 0000 00 10': 98, '0000 0000 01 10': 97, '0000 0000 11 10': 91}
# raw key value: 0000 0111 01 10: 1
# pcs key: 0111
# raw key value: 0000 0100 11 00: 21
# pcs key: 0100
# raw key value: 0000 0001 00 10: 41
# pcs key: 0001
# raw key value: 0000 0101 10 01: 24
# pcs key: 0101
# raw key value: 0000 0001 01 01: 53
# pcs key: 0001
# raw key value: 0000 0010 00 00: 57
# pcs key: 0010
# raw key value: 0000 0000 11 01: 98
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96, '0000 0000 00 10': 98, '0000 0000 01 10': 97, '0000 0000 11 10': 91, '0000 0000 11 01': 98}
# raw key value: 0000 0011 11 00: 1
# pcs key: 0011
# raw key value: 0000 0010 01 00: 66
# pcs key: 0010
# raw key value: 0000 1010 00 10: 27
# pcs key: 1010
# raw key value: 0000 1000 10 00: 34
# pcs key: 1000
# raw key value: 0000 0001 11 00: 57
# pcs key: 0001
# raw key value: 0000 0010 11 10: 49
# pcs key: 0010
# raw key value: 0000 0000 01 01: 117
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96, '0000 0000 00 10': 98, '0000 0000 01 10': 97, '0000 0000 11 10': 91, '0000 0000 11 01': 98, '0000 0000 01 01': 117}
# raw key value: 0000 0001 00 01: 42
# pcs key: 0001
# raw key value: 0000 0001 10 11: 49
# pcs key: 0001
# raw key value: 0000 0011 11 11: 1
# pcs key: 0011
# raw key value: 0000 0010 00 01: 56
# pcs key: 0010
# raw key value: 0000 0000 10 10: 95
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96, '0000 0000 00 10': 98, '0000 0000 01 10': 97, '0000 0000 11 10': 91, '0000 0000 11 01': 98, '0000 0000 01 01': 117, '0000 0000 10 10': 95}
# raw key value: 0000 1000 01 11: 23
# pcs key: 1000
# raw key value: 0000 1000 10 11: 23
# pcs key: 1000
# raw key value: 0000 0101 01 01: 30
# pcs key: 0101
# raw key value: 0000 1010 10 10: 28
# pcs key: 1010
# raw key value: 0000 0001 11 11: 51
# pcs key: 0001
# raw key value: 0000 1011 01 00: 1
# pcs key: 1011
# raw key value: 0000 0101 10 10: 26
# pcs key: 0101
# raw key value: 0000 0001 11 10: 57
# pcs key: 0001
# raw key value: 0000 1010 11 01: 29
# pcs key: 1010
# raw key value: 0000 1000 00 00: 30
# pcs key: 1000
# raw key value: 0000 0001 10 10: 44
# pcs key: 0001
# raw key value: 0000 0001 01 10: 39
# pcs key: 0001
# raw key value: 0000 0001 01 11: 62
# pcs key: 0001
# raw key value: 0000 0001 00 00: 33
# pcs key: 0001
# raw key value: 0000 1011 00 01: 1
# pcs key: 1011
# raw key value: 0000 0101 11 01: 23
# pcs key: 0101
# raw key value: 0000 1000 00 11: 32
# pcs key: 1000
# raw key value: 0000 1010 01 10: 26
# pcs key: 1010
# raw key value: 0000 0010 01 11: 35
# pcs key: 0010
# raw key value: 0000 1010 11 10: 21
# pcs key: 1010
# raw key value: 0000 0100 10 00: 33
# pcs key: 0100
# raw key value: 0000 0000 10 01: 108
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4608, '0000 0000 10 11': 4530, '0000 0000 11 11': 4592, '0000 0000 10 00': 4619, '0000 0000 00 00': 4535, '0000 0000 00 11': 4680, '0000 0000 11 00': 4633, '0000 0000 01 00': 4568, '0000 0000 00 01': 96, '0000 0000 00 10': 98, '0000 0000 01 10': 97, '0000 0000 11 10': 91, '0000 0000 11 01': 98, '0000 0000 01 01': 117, '0000 0000 10 10': 95, '0000 0000 10 01': 108}
# raw key value: 0000 1010 00 00: 3
# pcs key: 1010
# raw key value: 0000 0011 10 01: 4
# pcs key: 0011
# raw key value: 0000 0010 10 01: 48
# pcs key: 0010
# raw key value: 0000 0001 11 01: 39
# pcs key: 0001
# raw key value: 0000 0101 01 10: 21
# pcs key: 0101
# raw key value: 0000 1011 11 01: 1
# pcs key: 1011
# raw key value: 0000 0101 00 01: 26
# pcs key: 0101
# raw key value: 0000 0011 10 10: 1
# pcs key: 0011
# raw key value: 0000 0010 01 10: 40
# pcs key: 0010
# raw key value: 0000 1010 01 01: 19
# pcs key: 1010
# raw key value: 0000 0111 11 11: 1
# pcs key: 0111
# raw key value: 0000 0100 00 11: 24
# pcs key: 0100
# raw key value: 0000 0010 10 00: 40
# pcs key: 0010
# raw key value: 0000 0001 10 01: 38
# pcs key: 0001
# raw key value: 0000 1000 11 11: 22
# pcs key: 1000
# raw key value: 0000 0101 00 10: 23
# pcs key: 0101
# raw key value: 0000 1000 01 00: 26
# pcs key: 1000
# raw key value: 0000 1001 01 10: 2
# pcs key: 1001
# raw key value: 0000 1000 10 10: 1
# pcs key: 1000
# raw key value: 0000 0100 10 11: 25
# pcs key: 0100
# raw key value: 0000 1101 00 01: 1
# pcs key: 1101
# raw key value: 0000 0100 10 01: 3
# pcs key: 0100
# raw key value: 0000 0111 00 11: 1
# pcs key: 0111
# raw key value: 0000 0100 11 11: 30
# pcs key: 0100
# raw key value: 0000 1011 00 00: 1
# pcs key: 1011
# raw key value: 0000 0101 11 10: 25
# pcs key: 0101
# raw key value: 0000 1101 00 10: 1
# pcs key: 1101
# raw key value: 0000 0100 11 10: 1
# pcs key: 0100
# raw key value: 0000 0100 10 10: 1
# pcs key: 0100
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 0100 00 10: 2
# pcs key: 0100
# raw key value: 0000 1010 01 11: 1
# pcs key: 1010
# raw key value: 0000 0101 10 11: 2
# pcs key: 0101
# raw key value: 0000 0100 01 01: 2
# pcs key: 0100
# raw key value: 0000 1111 00 00: 1
# pcs key: 1111
# raw key value: 0000 0110 01 00: 1
# pcs key: 0110
# raw key value: 0000 1100 11 11: 1
# pcs key: 1100
# raw key value: 0000 1110 00 10: 1
# pcs key: 1110
# raw key value: 0000 0110 00 00: 1
# pcs key: 0110
# raw key value: 0000 1010 00 11: 1
# pcs key: 1010
# raw key value: 0000 1010 01 00: 1
# pcs key: 1010
# raw key value: 0000 1001 00 11: 1
# pcs key: 1001
# raw key value: 0000 1011 00 11: 1
# pcs key: 1011
# raw key value: 0000 0111 00 10: 1
# pcs key: 0111
# raw key value: 0000 1011 10 11: 1
# pcs key: 1011
# raw key value: 0000 0011 00 00: 1
# pcs key: 0011
# raw key value: 0000 1001 00 00: 1
# pcs key: 1001
# raw key value: 0000 0110 10 01: 1
# pcs key: 0110
# raw key value: 0000 1000 00 01: 1
# pcs key: 1000
# raw key value: 0000 0110 01 11: 1
# pcs key: 0110
# raw key value: 0000 1001 11 00: 1
# pcs key: 1001
# raw key value: 0000 0100 11 00: 9
# pcs key: 0100
# raw key value: 0000 0011 10 11: 2
# pcs key: 0011
# raw key value: 0000 0010 01 01: 73
# pcs key: 0010
# raw key value: 0000 0000 11 10: 4570
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570}
# raw key value: 0000 0011 00 10: 2
# pcs key: 0011
# raw key value: 0000 0010 11 10: 55
# pcs key: 0010
# raw key value: 0000 0000 01 01: 4548
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548}
# raw key value: 0000 0011 00 11: 2
# pcs key: 0011
# raw key value: 0000 0010 11 01: 53
# pcs key: 0010
# raw key value: 0000 0000 01 00: 170
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170}
# raw key value: 0000 0011 11 00: 1
# pcs key: 0011
# raw key value: 0000 0010 01 00: 53
# pcs key: 0010
# raw key value: 0000 0100 10 11: 17
# pcs key: 0100
# raw key value: 0000 0000 11 01: 4485
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485}
# raw key value: 0000 0011 00 01: 2
# pcs key: 0011
# raw key value: 0000 0010 11 11: 56
# pcs key: 0010
# raw key value: 0000 0000 01 10: 4505
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505}
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 39
# pcs key: 0010
# raw key value: 0000 1010 10 00: 14
# pcs key: 1010
# raw key value: 0000 0000 00 01: 4547
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547}
# raw key value: 0000 0011 11 11: 2
# pcs key: 0011
# raw key value: 0000 0010 00 01: 56
# pcs key: 0010
# raw key value: 0000 0000 10 10: 4594
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594}
# raw key value: 0000 0011 01 01: 3
# pcs key: 0011
# raw key value: 0000 0010 10 11: 52
# pcs key: 0010
# raw key value: 0000 0000 00 10: 4434
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434}
# raw key value: 0000 0000 10 01: 4603
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603}
# raw key value: 0000 1010 00 00: 18
# pcs key: 1010
# raw key value: 0000 0011 00 00: 1
# pcs key: 0011
# raw key value: 0000 0000 01 11: 139
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603, '0000 0000 01 11': 139}
# raw key value: 0000 0100 10 10: 31
# pcs key: 0100
# raw key value: 0000 0010 01 11: 51
# pcs key: 0010
# raw key value: 0000 0001 01 01: 54
# pcs key: 0001
# raw key value: 0000 0101 10 01: 13
# pcs key: 0101
# raw key value: 0000 1010 10 01: 12
# pcs key: 1010
# raw key value: 0000 0000 00 00: 139
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603, '0000 0000 01 11': 139, '0000 0000 00 00': 139}
# raw key value: 0000 0001 00 01: 48
# pcs key: 0001
# raw key value: 0000 0100 11 10: 24
# pcs key: 0100
# raw key value: 0000 0000 11 00: 142
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603, '0000 0000 01 11': 139, '0000 0000 00 00': 139, '0000 0000 11 00': 142}
# raw key value: 0000 0011 11 01: 1
# pcs key: 0011
# raw key value: 0000 0010 00 11: 35
# pcs key: 0010
# raw key value: 0000 0010 01 10: 62
# pcs key: 0010
# raw key value: 0000 0000 11 11: 131
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603, '0000 0000 01 11': 139, '0000 0000 00 00': 139, '0000 0000 11 00': 142, '0000 0000 11 11': 131}
# raw key value: 0000 0011 11 10: 2
# pcs key: 0011
# raw key value: 0000 0010 00 10: 57
# pcs key: 0010
# raw key value: 0000 0100 11 01: 17
# pcs key: 0100
# raw key value: 0000 0000 10 11: 121
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603, '0000 0000 01 11': 139, '0000 0000 00 00': 139, '0000 0000 11 00': 142, '0000 0000 11 11': 131, '0000 0000 10 11': 121}
# raw key value: 0000 0001 11 10: 64
# pcs key: 0001
# raw key value: 0000 0001 11 01: 51
# pcs key: 0001
# raw key value: 0000 0001 10 00: 48
# pcs key: 0001
# raw key value: 0000 0101 01 10: 18
# pcs key: 0101
# raw key value: 0000 1000 10 10: 22
# pcs key: 1000
# raw key value: 0000 0010 11 00: 47
# pcs key: 0010
# raw key value: 0000 0000 00 11: 126
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603, '0000 0000 01 11': 139, '0000 0000 00 00': 139, '0000 0000 11 00': 142, '0000 0000 11 11': 131, '0000 0000 10 11': 121, '0000 0000 00 11': 126}
# raw key value: 0000 0001 11 00: 41
# pcs key: 0001
# raw key value: 0000 1000 10 00: 12
# pcs key: 1000
# raw key value: 0000 0001 01 11: 53
# pcs key: 0001
# raw key value: 0000 0010 10 00: 58
# pcs key: 0010
# raw key value: 0000 1010 00 01: 8
# pcs key: 1010
# raw key value: 0000 0000 10 00: 146
# pcs key: 0000
# filtered results: {'0000 0000 11 10': 4570, '0000 0000 01 01': 4548, '0000 0000 01 00': 170, '0000 0000 11 01': 4485, '0000 0000 01 10': 4505, '0000 0000 00 01': 4547, '0000 0000 10 10': 4594, '0000 0000 00 10': 4434, '0000 0000 10 01': 4603, '0000 0000 01 11': 139, '0000 0000 00 00': 139, '0000 0000 11 00': 142, '0000 0000 11 11': 131, '0000 0000 10 11': 121, '0000 0000 00 11': 126, '0000 0000 10 00': 146}
# raw key value: 0000 1000 11 01: 20
# pcs key: 1000
# raw key value: 0000 0010 00 00: 41
# pcs key: 0010
# raw key value: 0000 0100 11 11: 10
# pcs key: 0100
# raw key value: 0000 0001 10 01: 48
# pcs key: 0001
# raw key value: 0000 0100 10 00: 15
# pcs key: 0100
# raw key value: 0000 1010 01 11: 10
# pcs key: 1010
# raw key value: 0000 0001 10 10: 52
# pcs key: 0001
# raw key value: 0000 1000 10 01: 29
# pcs key: 1000
# raw key value: 0000 0001 10 11: 40
# pcs key: 0001
# raw key value: 0000 1010 11 10: 12
# pcs key: 1010
# raw key value: 0000 0101 11 01: 12
# pcs key: 0101
# raw key value: 0000 1010 00 11: 11
# pcs key: 1010
# raw key value: 0000 0101 10 00: 8
# pcs key: 0101
# raw key value: 0000 1010 01 01: 11
# pcs key: 1010
# raw key value: 0000 0001 11 11: 46
# pcs key: 0001
# raw key value: 0000 0001 00 00: 47
# pcs key: 0001
# raw key value: 0000 0001 01 10: 64
# pcs key: 0001
# raw key value: 0000 1000 00 11: 13
# pcs key: 1000
# raw key value: 0000 0101 01 01: 14
# pcs key: 0101
# raw key value: 0000 0101 00 00: 15
# pcs key: 0101
# raw key value: 0000 0100 01 01: 17
# pcs key: 0100
# raw key value: 0000 0101 00 11: 14
# pcs key: 0101
# raw key value: 0000 0001 00 10: 46
# pcs key: 0001
# raw key value: 0000 0100 10 01: 16
# pcs key: 0100
# raw key value: 0000 1000 00 01: 13
# pcs key: 1000
# raw key value: 0000 1011 01 00: 1
# pcs key: 1011
# raw key value: 0000 0101 10 10: 11
# pcs key: 0101
# raw key value: 0000 0010 10 01: 50
# pcs key: 0010
# raw key value: 0000 0001 00 11: 48
# pcs key: 0001
# raw key value: 0000 1010 11 00: 17
# pcs key: 1010
# raw key value: 0000 0100 00 11: 18
# pcs key: 0100
# raw key value: 0000 1011 00 11: 1
# pcs key: 1011
# raw key value: 0000 0101 11 11: 15
# pcs key: 0101
# raw key value: 0000 1000 11 10: 18
# pcs key: 1000
# raw key value: 0000 1000 00 10: 11
# pcs key: 1000
# raw key value: 0000 1010 01 10: 17
# pcs key: 1010
# raw key value: 0000 1011 00 00: 1
# pcs key: 1011
# raw key value: 0000 0101 11 10: 13
# pcs key: 0101
# raw key value: 0000 0100 00 10: 18
# pcs key: 0100
# raw key value: 0000 0001 01 00: 57
# pcs key: 0001
# raw key value: 0000 1000 01 01: 16
# pcs key: 1000
# raw key value: 0000 0110 00 10: 1
# pcs key: 0110
# raw key value: 0000 1000 01 10: 26
# pcs key: 1000
# raw key value: 0000 0111 11 01: 2
# pcs key: 0111
# raw key value: 0000 0100 00 01: 20
# pcs key: 0100
# raw key value: 0000 0101 01 11: 9
# pcs key: 0101
# raw key value: 0000 1010 10 10: 15
# pcs key: 1010
# raw key value: 0000 1010 10 11: 10
# pcs key: 1010
# raw key value: 0000 0100 01 10: 18
# pcs key: 0100
# raw key value: 0000 1000 01 00: 10
# pcs key: 1000
# raw key value: 0000 0100 00 00: 11
# pcs key: 0100
# raw key value: 0000 0011 01 11: 1
# pcs key: 0011
# raw key value: 0000 1010 11 11: 10
# pcs key: 1010
# raw key value: 0000 1000 11 11: 14
# pcs key: 1000
# raw key value: 0000 1000 10 11: 10
# pcs key: 1000
# raw key value: 0000 0111 10 10: 1
# pcs key: 0111
# raw key value: 0000 0100 01 00: 9
# pcs key: 0100
# raw key value: 0000 0101 00 01: 13
# pcs key: 0101
# raw key value: 0000 1010 01 00: 13
# pcs key: 1010
# raw key value: 0000 1000 01 11: 14
# pcs key: 1000
# raw key value: 0000 0101 11 00: 12
# pcs key: 0101
# raw key value: 0000 1000 00 00: 8
# pcs key: 1000
# raw key value: 0000 0100 01 11: 9
# pcs key: 0100
# raw key value: 0000 0101 10 11: 14
# pcs key: 0101
# raw key value: 0000 1010 11 01: 14
# pcs key: 1010
# raw key value: 0000 0101 01 00: 10
# pcs key: 0101
# raw key value: 0000 1000 11 00: 8
# pcs key: 1000
# raw key value: 0000 1010 00 10: 8
# pcs key: 1010
# raw key value: 0000 0101 00 10: 12
# pcs key: 0101
# raw key value: 0000 0110 11 01: 1
# pcs key: 0110
# raw key value: 0000 1100 00 11: 1
# pcs key: 1100
# raw key value: 0000 0011 10 01: 4
# pcs key: 0011
# raw key value: 0000 1110 10 01: 1
# pcs key: 1110
# raw key value: 0000 1110 11 01: 1
# pcs key: 1110
# raw key value: 0000 1001 11 01: 1
# pcs key: 1001
# raw key value: 0000 1011 00 10: 1
# pcs key: 1011
# raw key value: 0000 1100 00 01: 1
# pcs key: 1100
# raw key value: 0000 0110 00 00: 1
# pcs key: 0110
# raw key value: 0000 0110 10 01: 1
# pcs key: 0110
# raw key value: 0000 1110 01 10: 1
# pcs key: 1110
# raw key value: 0000 1100 01 00: 1
# pcs key: 1100
# raw key value: 0000 0110 01 11: 1
# pcs key: 0110
# raw key value: 0000 1001 10 01: 1
# pcs key: 1001
# raw key value: 0000 1001 11 11: 1
# pcs key: 1001
# raw key value: 0000 1001 00 01: 1
# pcs key: 1001
# raw key value: 0000 0011 10 00: 1
# pcs key: 0011
# raw key value: 0000 1001 11 10: 1
# pcs key: 1001
# raw key value: 0000 0110 00 11: 1
# pcs key: 0110
# raw key value: 0000 0000 01 11: 4513
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513}
# raw key value: 0000 0000 10 11: 4584
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584}
# raw key value: 0000 0011 01 10: 1
# pcs key: 0011
# raw key value: 0000 0010 10 10: 54
# pcs key: 0010
# raw key value: 0000 1010 10 00: 6
# pcs key: 1010
# raw key value: 0000 0000 00 01: 123
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123}
# raw key value: 0000 0111 10 11: 1
# pcs key: 0111
# raw key value: 0000 0100 01 11: 13
# pcs key: 0100
# raw key value: 0000 0010 00 11: 49
# pcs key: 0010
# raw key value: 0000 0000 11 00: 4473
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473}
# raw key value: 0000 0011 01 00: 3
# pcs key: 0011
# raw key value: 0000 0010 11 00: 66
# pcs key: 0010
# raw key value: 0000 0000 00 11: 4522
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522}
# raw key value: 0000 1010 00 01: 15
# pcs key: 1010
# raw key value: 0000 0000 10 00: 4571
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571}
# raw key value: 0000 1010 10 01: 20
# pcs key: 1010
# raw key value: 0000 0000 00 00: 4585
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585}
# raw key value: 0000 0011 10 10: 1
# pcs key: 0011
# raw key value: 0000 0010 01 10: 49
# pcs key: 0010
# raw key value: 0000 0000 11 11: 4497
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497}
# raw key value: 0000 0011 11 00: 2
# pcs key: 0011
# raw key value: 0000 0010 01 00: 56
# pcs key: 0010
# raw key value: 0000 0000 11 01: 136
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136}
# raw key value: 0000 0010 11 01: 41
# pcs key: 0010
# raw key value: 0000 0100 00 10: 15
# pcs key: 0100
# raw key value: 0000 0000 01 00: 4592
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136, '0000 0000 01 00': 4592}
# raw key value: 0000 0000 01 10: 126
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136, '0000 0000 01 00': 4592, '0000 0000 01 10': 126}
# raw key value: 0000 1000 11 00: 27
# pcs key: 1000
# raw key value: 0000 0101 01 10: 10
# pcs key: 0101
# raw key value: 0000 0010 10 00: 57
# pcs key: 0010
# raw key value: 0000 0011 01 01: 1
# pcs key: 0011
# raw key value: 0000 0010 10 11: 67
# pcs key: 0010
# raw key value: 0000 0000 00 10: 146
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136, '0000 0000 01 00': 4592, '0000 0000 01 10': 126, '0000 0000 00 10': 146}
# raw key value: 0000 1010 01 01: 20
# pcs key: 1010
# raw key value: 0000 0101 11 00: 15
# pcs key: 0101
# raw key value: 0000 0000 10 10: 139
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136, '0000 0000 01 00': 4592, '0000 0000 01 10': 126, '0000 0000 00 10': 146, '0000 0000 10 10': 139}
# raw key value: 0000 1010 00 00: 7
# pcs key: 1010
# raw key value: 0000 0000 10 01: 124
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136, '0000 0000 01 00': 4592, '0000 0000 01 10': 126, '0000 0000 00 10': 146, '0000 0000 10 10': 139, '0000 0000 10 01': 124}
# raw key value: 0000 0010 01 11: 59
# pcs key: 0010
# raw key value: 0000 0100 10 10: 10
# pcs key: 0100
# raw key value: 0000 1000 00 11: 22
# pcs key: 1000
# raw key value: 0000 0000 01 01: 132
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136, '0000 0000 01 00': 4592, '0000 0000 01 10': 126, '0000 0000 00 10': 146, '0000 0000 10 10': 139, '0000 0000 10 01': 124, '0000 0000 01 01': 132}
# raw key value: 0000 0101 00 10: 19
# pcs key: 0101
# raw key value: 0000 1000 01 01: 12
# pcs key: 1000
# raw key value: 0000 0011 10 11: 2
# pcs key: 0011
# raw key value: 0000 0010 01 01: 59
# pcs key: 0010
# raw key value: 0000 0000 11 10: 127
# pcs key: 0000
# filtered results: {'0000 0000 01 11': 4513, '0000 0000 10 11': 4584, '0000 0000 00 01': 123, '0000 0000 11 00': 4473, '0000 0000 00 11': 4522, '0000 0000 10 00': 4571, '0000 0000 00 00': 4585, '0000 0000 11 11': 4497, '0000 0000 11 01': 136, '0000 0000 01 00': 4592, '0000 0000 01 10': 126, '0000 0000 00 10': 146, '0000 0000 10 10': 139, '0000 0000 10 01': 124, '0000 0000 01 01': 132, '0000 0000 11 10': 127}
# raw key value: 0000 0001 00 11: 53
# pcs key: 0001
# raw key value: 0000 0101 10 00: 10
# pcs key: 0101
# raw key value: 0000 0001 00 00: 50
# pcs key: 0001
# raw key value: 0000 1011 10 11: 1
# pcs key: 1011
# raw key value: 0000 0101 01 11: 10
# pcs key: 0101
# raw key value: 0000 1010 10 11: 11
# pcs key: 1010
# raw key value: 0000 0100 11 11: 24
# pcs key: 0100
# raw key value: 0000 0010 00 00: 69
# pcs key: 0010
# raw key value: 0000 0001 10 10: 56
# pcs key: 0001
# raw key value: 0000 0001 01 11: 48
# pcs key: 0001
# raw key value: 0000 0001 10 11: 49
# pcs key: 0001
# raw key value: 0000 1000 00 01: 13
# pcs key: 1000
# raw key value: 0000 0001 11 10: 45
# pcs key: 0001
# raw key value: 0000 1010 00 10: 13
# pcs key: 1010
# raw key value: 0000 0001 11 00: 60
# pcs key: 0001
# raw key value: 0000 1010 11 10: 15
# pcs key: 1010
# raw key value: 0000 1000 11 11: 16
# pcs key: 1000
# raw key value: 0000 0101 00 01: 10
# pcs key: 0101
# raw key value: 0000 0001 01 10: 45
# pcs key: 0001
# raw key value: 0000 1010 11 00: 10
# pcs key: 1010
# raw key value: 0000 1000 01 11: 22
# pcs key: 1000
# raw key value: 0000 0001 10 01: 49
# pcs key: 0001
# raw key value: 0000 0101 01 01: 16
# pcs key: 0101
# raw key value: 0000 0101 00 00: 13
# pcs key: 0101
# raw key value: 0000 1010 01 10: 18
# pcs key: 1010
# raw key value: 0000 0100 10 00: 17
# pcs key: 0100
# raw key value: 0000 0001 11 11: 53
# pcs key: 0001
# raw key value: 0000 0001 00 01: 46
# pcs key: 0001
# raw key value: 0000 0001 01 01: 47
# pcs key: 0001
# raw key value: 0000 0011 11 10: 1
# pcs key: 0011
# raw key value: 0000 0010 00 10: 48
# pcs key: 0010
# raw key value: 0000 0011 00 10: 1
# pcs key: 0011
# raw key value: 0000 0010 11 10: 54
# pcs key: 0010
# raw key value: 0000 1010 01 11: 14
# pcs key: 1010
# raw key value: 0000 1000 10 11: 24
# pcs key: 1000
# raw key value: 0000 0100 11 10: 9
# pcs key: 0100
# raw key value: 0000 1000 00 00: 16
# pcs key: 1000
# raw key value: 0000 1000 11 10: 20
# pcs key: 1000
# raw key value: 0000 0100 00 01: 10
# pcs key: 0100
# raw key value: 0000 0101 10 11: 9
# pcs key: 0101
# raw key value: 0000 0100 00 11: 19
# pcs key: 0100
# raw key value: 0000 0001 01 00: 47
# pcs key: 0001
# raw key value: 0000 0011 00 01: 1
# pcs key: 0011
# raw key value: 0000 0010 11 11: 47
# pcs key: 0010
# raw key value: 0000 0011 10 01: 2
# pcs key: 0011
# raw key value: 0000 0100 01 00: 15
# pcs key: 0100
# raw key value: 0000 0010 10 01: 42
# pcs key: 0010
# raw key value: 0000 0101 00 11: 15
# pcs key: 0101
# raw key value: 0000 0100 10 01: 14
# pcs key: 0100
# raw key value: 0000 0001 10 00: 47
# pcs key: 0001
# raw key value: 0000 1011 10 10: 2
# ...
# pcs key: 0100
# raw key value: 0000 0011 00 10: 158
# pcs key: 0011
# raw key value: 0000 0010 11 10: 240
# pcs key: 0010
# raw key value: 0000 0110 11 01: 125
# pcs key: 0110
# raw key value: 0000 0011 11 11: 147
# pcs key: 0011
# raw key value: 0000 0010 00 01: 225
# pcs key: 0010
# raw key value: 0000 0111 00 10: 122
# pcs key: 0111
# raw key value: 0000 1100 01 10: 103
# pcs key: 1100
# raw key value: 0000 1110 11 01: 87
# pcs key: 1110
# raw key value: 0000 0000 10 10: 323
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323}
# raw key value: 0000 1111 11 01: 99
# pcs key: 1111
# raw key value: 0000 1011 10 00: 107
# pcs key: 1011
# raw key value: 0000 0100 00 10: 182
# pcs key: 0100
# raw key value: 0000 0010 11 01: 211
# pcs key: 0010
# raw key value: 0000 0011 00 11: 180
# pcs key: 0011
# raw key value: 0000 1100 11 00: 95
# pcs key: 1100
# raw key value: 0000 1110 00 01: 90
# pcs key: 1110
# raw key value: 0000 0000 01 00: 350
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350}
# raw key value: 0000 1010 00 00: 162
# pcs key: 1010
# raw key value: 0000 0000 10 01: 352
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352}
# raw key value: 0000 0101 01 00: 179
# pcs key: 0101
# raw key value: 0000 1011 10 10: 129
# pcs key: 1011
# raw key value: 0000 1000 11 00: 185
# pcs key: 1000
# raw key value: 0000 1101 01 10: 88
# pcs key: 1101
# raw key value: 0000 0011 01 01: 169
# pcs key: 0011
# raw key value: 0000 0010 10 11: 238
# pcs key: 0010
# raw key value: 0000 0000 00 10: 342
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342}
# raw key value: 0000 1100 11 10: 92
# pcs key: 1100
# raw key value: 0000 1110 01 11: 96
# pcs key: 1110
# raw key value: 0000 0100 10 00: 161
# pcs key: 0100
# raw key value: 0000 0011 10 01: 147
# pcs key: 0011
# raw key value: 0000 0101 00 00: 165
# pcs key: 0101
# raw key value: 0000 1011 11 10: 110
# pcs key: 1011
# raw key value: 0000 1111 10 01: 109
# pcs key: 1111
# raw key value: 0000 1011 10 01: 125
# pcs key: 1011
# raw key value: 0000 0110 01 01: 122
# pcs key: 0110
# raw key value: 0000 1000 00 11: 179
# pcs key: 1000
# raw key value: 0000 1001 10 11: 108
# pcs key: 1001
# raw key value: 0000 0010 11 00: 256
# pcs key: 0010
# raw key value: 0000 0011 01 00: 151
# pcs key: 0011
# raw key value: 0000 0000 00 11: 371
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371}
# raw key value: 0000 0010 00 10: 241
# pcs key: 0010
# raw key value: 0000 0011 11 10: 170
# pcs key: 0011
# raw key value: 0000 1010 01 00: 169
# pcs key: 1010
# raw key value: 0000 0111 10 00: 102
# pcs key: 0111
# raw key value: 0000 1010 00 01: 179
# pcs key: 1010
# raw key value: 0000 0000 10 00: 366
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366}
# raw key value: 0000 0001 11 10: 224
# pcs key: 0001
# raw key value: 0000 0000 00 00: 372
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372}
# raw key value: 0000 1010 10 01: 165
# pcs key: 1010
# raw key value: 0000 0011 01 11: 156
# pcs key: 0011
# raw key value: 0000 0101 10 01: 148
# pcs key: 0101
# raw key value: 0000 1011 01 01: 124
# pcs key: 1011
# raw key value: 0000 0011 10 00: 176
# pcs key: 0011
# raw key value: 0000 1101 10 01: 84
# pcs key: 1101
# raw key value: 0000 0110 11 10: 110
# pcs key: 0110
# raw key value: 0000 0000 01 11: 379
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379}
# raw key value: 0000 1001 11 11: 127
# pcs key: 1001
# raw key value: 0000 1010 11 00: 163
# pcs key: 1010
# raw key value: 0000 0000 11 11: 326
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326}
# raw key value: 0000 0000 11 00: 376
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326, '0000 0000 11 00': 376}
# raw key value: 0000 0001 10 11: 246
# pcs key: 0001
# raw key value: 0000 0101 11 10: 176
# pcs key: 0101
# raw key value: 0000 1011 00 00: 133
# pcs key: 1011
# raw key value: 0000 1011 11 00: 101
# pcs key: 1011
# raw key value: 0000 0101 01 10: 184
# pcs key: 0101
# raw key value: 0000 0001 00 11: 253
# pcs key: 0001
# raw key value: 0000 1000 01 10: 188
# pcs key: 1000
# raw key value: 0000 1101 00 11: 100
# pcs key: 1101
# raw key value: 0000 0010 11 11: 244
# pcs key: 0010
# raw key value: 0000 0011 00 01: 159
# pcs key: 0011
# raw key value: 0000 0000 00 01: 311
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326, '0000 0000 11 00': 376, '0000 0000 00 01': 311}
# raw key value: 0000 1010 10 00: 177
# pcs key: 1010
# raw key value: 0000 1001 00 00: 127
# pcs key: 1001
# raw key value: 0000 0001 10 01: 230
# pcs key: 0001
# raw key value: 0000 0111 11 01: 106
# pcs key: 0111
# raw key value: 0000 0100 00 01: 163
# pcs key: 0100
# raw key value: 0000 0110 01 11: 103
# pcs key: 0110
# raw key value: 0000 0011 11 00: 157
# pcs key: 0011
# raw key value: 0000 0010 01 00: 237
# pcs key: 0010
# raw key value: 0000 1011 01 11: 121
# pcs key: 1011
# raw key value: 0000 0101 10 11: 160
# pcs key: 0101
# raw key value: 0000 1111 10 10: 98
# pcs key: 1111
# raw key value: 0000 1100 00 01: 87
# pcs key: 1100
# raw key value: 0000 1110 11 00: 108
# pcs key: 1110
# raw key value: 0000 0000 11 10: 331
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326, '0000 0000 11 00': 376, '0000 0000 00 01': 311, '0000 0000 11 10': 331}
# raw key value: 0000 1000 01 11: 189
# pcs key: 1000
# raw key value: 0000 1000 01 00: 170
# pcs key: 1000
# raw key value: 0000 1111 11 00: 70
# pcs key: 1111
# raw key value: 0000 1011 00 10: 116
# pcs key: 1011
# raw key value: 0000 1110 10 01: 86
# pcs key: 1110
# raw key value: 0000 1111 10 00: 81
# pcs key: 1111
# raw key value: 0000 0100 01 01: 185
# pcs key: 0100
# raw key value: 0000 0001 01 00: 223
# pcs key: 0001
# raw key value: 0000 1010 01 01: 168
# pcs key: 1010
# raw key value: 0000 1000 10 00: 179
# pcs key: 1000
# raw key value: 0000 0100 11 01: 176
# pcs key: 0100
# raw key value: 0000 0111 00 01: 120
# pcs key: 0111
# raw key value: 0000 1000 10 01: 155
# pcs key: 1000
# raw key value: 0000 0101 01 11: 180
# pcs key: 0101
# raw key value: 0000 1011 10 11: 133
# pcs key: 1011
# raw key value: 0000 0010 01 11: 237
# pcs key: 0010
# raw key value: 0000 0101 10 10: 190
# pcs key: 0101
# raw key value: 0000 1011 01 00: 121
# pcs key: 1011
# raw key value: 0000 0000 10 11: 395
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326, '0000 0000 11 00': 376, '0000 0000 00 01': 311, '0000 0000 11 10': 331, '0000 0000 10 11': 395}
# raw key value: 0000 1010 00 10: 201
# pcs key: 1010
# raw key value: 0000 0100 10 01: 173
# pcs key: 0100
# raw key value: 0000 1001 11 10: 116
# pcs key: 1001
# raw key value: 0000 0110 00 11: 124
# pcs key: 0110
# raw key value: 0000 0100 00 00: 178
# pcs key: 0100
# raw key value: 0000 0111 11 10: 117
# pcs key: 0111
# raw key value: 0000 0000 11 01: 335
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326, '0000 0000 11 00': 376, '0000 0000 00 01': 311, '0000 0000 11 10': 331, '0000 0000 10 11': 395, '0000 0000 11 01': 335}
# raw key value: 0000 1001 00 01: 114
# pcs key: 1001
# raw key value: 0000 1000 00 00: 181
# pcs key: 1000
# raw key value: 0000 0101 00 01: 178
# pcs key: 0101
# raw key value: 0000 1011 11 01: 117
# pcs key: 1011
# raw key value: 0000 0001 00 00: 231
# pcs key: 0001
# raw key value: 0000 0111 11 00: 135
# pcs key: 0111
# raw key value: 0000 0100 01 10: 168
# pcs key: 0100
# raw key value: 0000 0010 10 01: 200
# pcs key: 0010
# raw key value: 0000 1011 11 11: 121
# pcs key: 1011
# raw key value: 0000 0101 00 11: 179
# pcs key: 0101
# raw key value: 0000 0111 10 10: 128
# pcs key: 0111
# raw key value: 0000 0100 01 00: 160
# pcs key: 0100
# raw key value: 0000 1100 11 01: 73
# pcs key: 1100
# raw key value: 0000 1110 01 10: 88
# pcs key: 1110
# raw key value: 0000 1010 00 11: 181
# pcs key: 1010
# raw key value: 0000 0000 01 10: 338
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326, '0000 0000 11 00': 376, '0000 0000 00 01': 311, '0000 0000 11 10': 331, '0000 0000 10 11': 395, '0000 0000 11 01': 335, '0000 0000 01 10': 338}
# raw key value: 0000 0111 01 10: 127
# pcs key: 0111
# raw key value: 0000 0100 11 00: 171
# pcs key: 0100
# raw key value: 0000 1010 11 10: 177
# pcs key: 1010
# raw key value: 0000 1110 10 11: 84
# pcs key: 1110
# raw key value: 0000 1100 00 00: 79
# pcs key: 1100
# raw key value: 0000 1000 00 01: 182
# pcs key: 1000
# raw key value: 0000 0110 10 00: 124
# pcs key: 0110
# raw key value: 0000 1010 01 11: 180
# pcs key: 1010
# raw key value: 0000 1100 11 11: 102
# pcs key: 1100
# raw key value: 0000 1110 01 00: 83
# pcs key: 1110
# raw key value: 0000 1101 00 01: 94
# pcs key: 1101
# raw key value: 0000 0010 01 10: 213
# pcs key: 0010
# raw key value: 0000 0011 10 10: 182
# pcs key: 0011
# raw key value: 0000 0110 00 10: 121
# pcs key: 0110
# raw key value: 0000 0110 00 01: 135
# pcs key: 0110
# raw key value: 0000 0010 10 10: 228
# pcs key: 0010
# raw key value: 0000 0011 01 10: 148
# pcs key: 0011
# raw key value: 0000 1110 10 00: 97
# pcs key: 1110
# raw key value: 0000 0111 10 01: 102
# pcs key: 0111
# raw key value: 0000 1100 10 11: 90
# pcs key: 1100
# raw key value: 0000 1110 00 00: 100
# pcs key: 1110
# raw key value: 0000 0010 10 00: 265
# pcs key: 0010
# raw key value: 0000 1110 01 01: 93
# pcs key: 1110
# raw key value: 0000 1000 00 10: 180
# pcs key: 1000
# raw key value: 0000 1001 10 10: 118
# pcs key: 1001
# raw key value: 0000 0001 10 10: 217
# pcs key: 0001
# raw key value: 0000 1100 00 11: 104
# pcs key: 1100
# raw key value: 0000 1110 10 10: 86
# pcs key: 1110
# raw key value: 0000 1101 00 00: 86
# pcs key: 1101
# raw key value: 0000 1101 10 00: 96
# pcs key: 1101
# raw key value: 0000 1001 01 01: 145
# pcs key: 1001
# raw key value: 0000 0001 11 01: 242
# pcs key: 0001
# raw key value: 0000 1100 01 01: 99
# pcs key: 1100
# raw key value: 0000 0001 00 10: 192
# pcs key: 0001
# raw key value: 0000 0001 01 01: 236
# pcs key: 0001
# raw key value: 0000 0110 00 00: 122
# pcs key: 0110
# raw key value: 0000 1101 10 11: 84
# pcs key: 1101
# raw key value: 0000 1100 01 00: 100
# pcs key: 1100
# raw key value: 0000 1110 11 11: 85
# pcs key: 1110
# raw key value: 0000 0100 11 10: 171
# pcs key: 0100
# raw key value: 0000 0111 00 00: 107
# pcs key: 0111
# raw key value: 0000 1000 10 11: 163
# pcs key: 1000
# raw key value: 0000 1110 00 11: 97
# pcs key: 1110
# raw key value: 0000 1100 10 10: 83
# pcs key: 1100
# raw key value: 0000 0100 01 11: 183
# pcs key: 0100
# raw key value: 0000 0111 10 11: 134
# pcs key: 0111
# raw key value: 0000 0001 00 01: 208
# pcs key: 0001
# raw key value: 0000 0000 01 01: 348
# pcs key: 0000
# filtered results: {'0000 0000 10 10': 323, '0000 0000 01 00': 350, '0000 0000 10 01': 352, '0000 0000 00 10': 342, '0000 0000 00 11': 371, '0000 0000 10 00': 366, '0000 0000 00 00': 372, '0000 0000 01 11': 379, '0000 0000 11 11': 326, '0000 0000 11 00': 376, '0000 0000 00 01': 311, '0000 0000 11 10': 331, '0000 0000 10 11': 395, '0000 0000 11 01': 335, '0000 0000 01 10': 338, '0000 0000 01 01': 348}
# raw key value: 0000 1111 00 00: 84
# pcs key: 1111
# raw key value: 0000 0001 10 00: 228
# pcs key: 0001
# raw key value: 0000 1001 01 00: 117
# pcs key: 1001
# raw key value: 0000 1001 00 10: 119
# pcs key: 1001
# raw key value: 0000 1011 01 10: 125
# pcs key: 1011
# raw key value: 0000 0101 11 00: 178
# pcs key: 0101
# raw key value: 0000 1101 11 01: 90
# pcs key: 1101
# raw key value: 0000 1010 10 11: 153
# pcs key: 1010
# raw key value: 0000 1001 11 00: 113
# pcs key: 1001
# raw key value: 0000 1010 11 11: 177
# pcs key: 1010
# raw key value: 0000 1111 01 01: 75
# pcs key: 1111
# raw key value: 0000 0111 01 11: 110
# pcs key: 0111
# raw key value: 0000 0100 10 11: 189
# pcs key: 0100
# raw key value: 0000 1111 01 11: 90
# pcs key: 1111
# raw key value: 0000 1000 10 10: 173
# pcs key: 1000
# raw key value: 0000 0110 10 11: 122
# pcs key: 0110
# raw key value: 0000 1111 00 01: 78
# pcs key: 1111
# raw key value: 0000 1101 00 10: 76
# pcs key: 1101
# raw key value: 0000 1100 01 11: 85
# pcs key: 1100
# raw key value: 0000 1110 11 10: 76
# pcs key: 1110
# raw key value: 0000 0011 00 00: 153
# pcs key: 0011
# raw key value: 0000 1000 11 10: 180
# pcs key: 1000
# raw key value: 0000 0001 01 11: 232
# pcs key: 0001
# raw key value: 0000 1011 00 11: 105
# pcs key: 1011
# raw key value: 0000 0101 11 11: 189
# pcs key: 0101
# raw key value: 0000 1001 01 10: 114
# pcs key: 1001
# raw key value: 0000 0001 11 11: 222
# pcs key: 0001
# raw key value: 0000 1000 11 11: 164
# pcs key: 1000
# raw key value: 0000 1000 01 01: 164
# pcs key: 1000
# raw key value: 0000 1100 00 10: 104
# pcs key: 1100
# raw key value: 0000 0010 00 00: 253
# pcs key: 0010
# raw key value: 0000 0101 11 01: 170
# pcs key: 0101
# raw key value: 0000 1011 00 01: 131
# pcs key: 1011
# raw key value: 0000 1111 00 10: 90
# pcs key: 1111
# raw key value: 0000 1111 11 11: 90
# pcs key: 1111
# raw key value: 0000 1101 10 10: 85
# pcs key: 1101
# raw key value: 0000 1010 10 10: 148
# pcs key: 1010
# raw key value: 0000 0100 11 11: 180
# pcs key: 0100
# raw key value: 0000 0111 00 11: 116
# pcs key: 0111
# raw key value: 0000 1101 01 11: 92
# pcs key: 1101
# raw key value: 0000 1000 11 01: 163
# pcs key: 1000
# raw key value: 0000 1101 11 00: 86
# pcs key: 1101
# raw key value: 0000 0110 11 11: 118
# pcs key: 0110
# raw key value: 0000 1001 01 11: 104
# pcs key: 1001
# raw key value: 0000 1010 01 10: 167
# pcs key: 1010
# raw key value: 0000 1100 10 01: 80
# pcs key: 1100
# raw key value: 0000 1111 10 11: 79
# pcs key: 1111
# raw key value: 0000 0011 11 01: 160
# pcs key: 0011
# raw key value: 0000 0010 00 11: 230
# pcs key: 0010
# raw key value: 0000 0110 01 00: 91
# pcs key: 0110
# raw key value: 0000 1111 01 00: 79
# pcs key: 1111
# raw key value: 0000 1001 10 00: 126
# pcs key: 1001
# raw key value: 0000 1001 00 11: 111
# pcs key: 1001
# raw key value: 0000 1111 01 10: 103
# pcs key: 1111
# raw key value: 0000 1001 10 01: 114
# pcs key: 1001
# raw key value: 0000 1010 11 01: 169
# pcs key: 1010
# raw key value: 0000 0110 11 00: 104
# pcs key: 0110
# raw key value: 0000 0101 01 01: 159
# pcs key: 0101
# raw key value: 0000 0001 01 10: 226
# pcs key: 0001
# raw key value: 0000 1101 01 00: 90
# pcs key: 1101
# raw key value: 0000 1101 11 10: 84
# pcs key: 1101
# raw key value: 0000 1101 11 11: 115
# pcs key: 1101
# raw key value: 0000 1001 11 01: 107
# pcs key: 1001
# raw key value: 0000 1110 00 10: 76
# pcs key: 1110
# raw key value: 0000 1111 11 10: 93
# pcs key: 1111
# raw key value: 0000 0110 10 01: 111
# pcs key: 0110
# raw key value: 0000 1101 01 01: 87
# pcs key: 1101
# raw key value: 0000 0111 01 01: 110
# pcs key: 0111
# raw key value: 0000 1111 00 11: 91
# pcs key: 1111
# raw key value: 0000 1100 10 00: 90
# pcs key: 1100
# collected vals:  {'00': 1636, '10': 1216, '11': 1645, '01': 1239}
# collected vals:  {'01': 1413, '00': 1375, '10': 1485, '11': 1304}
# collected vals:  {'10': 1334, '00': 1464, '01': 1346, '11': 1471}
# 0.3071713206852249

# %%
print(pcs_fidelity)
print(pcs_post_select_rates)
# reps=2
with open(f"json\\graph_pcsXZ_mem_unbiased.json", "w") as fxz:
        json.dump({"errors": errors.tolist(), "fidelities": pcs_all_fidelities, "postselectRates": pcs_post_select_rates}, fxz)
with open("json\\raw_unbiased.json") as fRaw:
        dataRaw=json.load(fRaw)
nopcs_all_fidelities=dataRaw["fidelities"]
plt.plot(errors, pcs_all_fidelities, label="PCS X&Z Fidelity", marker='o')
plt.plot(errors, nopcs_all_fidelities, label="No PCS Fidelity", marker='o')
plt.plot(errors, pcs_post_select_rates, label="PCS X&Z Postselection rate",  marker='^', linestyle="--")
plt.ylabel('Probability')
plt.xlabel(f"Depolarizing Error Rate")
plt.text(0.25, .7, f"Single qubit gate error: {error_gate1}\nTwo qubit gate error: {round(error_gate1*10, 4)}", color = "red")
plt.title(f"Entanglement Swapping: PCS X&Z on Memory Qubits")
plt.legend()
plt.savefig(f"images\\graph_pcsXZ_memory_equal_depol.png")
plt.show()
# Out:
# 0.3071713206852249
# [0.93475, 0.765, 0.623775, 0.510725, 0.417025, 0.341275, 0.2801, 0.2332, 0.193475, 0.162425, 0.139425]
